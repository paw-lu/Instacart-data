# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
products = pd.read_csv('products.csv')
order_products_smol = pd.read_csv('order_products__train.csv')
aisles = pd.read_csv('aisles.csv')

products = products[['product_id', 'aisle_id']]
order_products_smol = order_products_smol[['order_id', 'product_id']]

products.set_index('product_id', inplace=True, drop=False)
aisles.set_index('aisle_id', inplace=True, drop=False)
order_ids = order_products_smol['order_id'].unique()
aisle_names = aisles['aisle'].values

# %%
orders_by_aisles = pd.DataFrame(columns=aisles['aisle'].values, index=order_ids)

# %%
total_orders = len(order_ids)
total_orders
# Out:
# 131209

# %%
for order_id in order_ids:
    is_order = order_products_smol['order_id'] == order_id
    products_purchased = order_products_smol[is_order]
    aisle_dic = {}
    for product_id in products_purchased['product_id']:
        aisle_id = products.loc[product_id]['aisle_id']
        aisle_name = aisles.loc[aisle_id]['aisle']
        
        if aisle_name in aisle_dic:
            aisle_dic[aisle_name] += 1
        else:
            aisle_dic[aisle_name] = 1

  
    
    for aisle_key in aisle_dic:
        orders_by_aisles.loc[order_id][aisle_key] = aisle_dic[aisle_key]

# %%
orders_by_aisles = orders_by_aisles.fillna(0)

# %%
average_order = {}
for aisle_name in aisle_names:
    average_order[aisle_name] = orders_by_aisles[aisle_name].mean()
average_order
# Out:
# {'air fresheners candles': 0.00813206411145577,
#  'asian foods': 0.053403348855642525,
#  'baby accessories': 0.002332157092882348,
#  'baby bath body care': 0.0024998285178608175,
#  'baby food formula': 0.10058761213026546,
#  'bakery desserts': 0.011439764040576485,
#  'baking ingredients': 0.09974925500537311,
#  'baking supplies decor': 0.0083378426784748,
#  'beauty': 0.002187349953128215,
#  'beers coolers': 0.014015806842518425,
#  'body lotions soap': 0.016286992508135874,
#  'bread': 0.180132460425733,
#  'breakfast bakery': 0.07507869124831376,
#  'breakfast bars pastries': 0.02396177091510491,
#  'bulk dried fruits vegetables': 0.0055255355958813805,
#  'bulk grains rice dried goods': 0.004831985610743166,
#  'buns rolls': 0.038518699174599304,
#  'butter': 0.08059660541578703,
#  'candy chocolate': 0.08728821955810959,
#  'canned fruit applesauce': 0.030455227918816545,
#  'canned jarred vegetables': 0.0966320907864552,
#  'canned meals beans': 0.08973469807711361,
#  'canned meat seafood': 0.024701049470691797,
#  'cat food care': 0.021987820957403835,
#  'cereal': 0.12347476163982654,
#  'chips pretzels': 0.2383144448932619,
#  'cleaning products': 0.044920699037413594,
#  'cocoa drink mixes': 0.008093956969415207,
#  'coffee': 0.06395902720087798,
#  'cold flu allergy': 0.010258442637319086,
#  'condiments': 0.07425557698023763,
#  'cookies cakes': 0.07606185551296024,
#  'crackers': 0.14931902537173516,
#  'cream': 0.09417036941063495,
#  'deodorants': 0.006539185574160309,
#  'diapers wipes': 0.008452164104596484,
#  'digestion': 0.009183821231775259,
#  'dish detergents': 0.0294949279393944,
#  'dog food care': 0.012285742593876945,
#  'doughs gelatins bake mixes': 0.03626275636579808,
#  'dry pasta': 0.08610689815485219,
#  'eggs': 0.15147588961123093,
#  'energy granola bars': 0.13298630429315061,
#  'energy sports drinks': 0.03614081351126828,
#  'eye ear care': 0.004176542767645512,
#  'facial care': 0.005685585592451737,
#  'feminine care': 0.007987256971701636,
#  'first aid': 0.0041079499119725015,
#  'food storage': 0.022147870953974195,
#  'fresh dips tapenades': 0.11540366895563567,
#  'fresh fruits': 1.1468191968538743,
#  'fresh herbs': 0.12233916880701781,
#  'fresh pasta': 0.01240768544840674,
#  'fresh vegetables': 1.1478557111173777,
#  'frozen appetizers sides': 0.06760206997995565,
#  'frozen breads doughs': 0.011676028321227964,
#  'frozen breakfast': 0.07414887698252406,
#  'frozen dessert': 0.007026956992279493,
#  'frozen juice': 0.002240699951985001,
#  'frozen meals': 0.13887004702421327,
#  'frozen meat seafood': 0.02546319231150302,
#  'frozen pizza': 0.058387763034547936,
#  'frozen produce': 0.1711239320473443,
#  'frozen vegan vegetarian': 0.0360264920851466,
#  'fruit vegetable snacks': 0.05137604889908467,
#  'grains rice dried goods': 0.04674984185536053,
#  'granola': 0.028984292236050882,
#  'hair care': 0.011195878331516893,
#  'honeys syrups nectars': 0.02182777096083348,
#  'hot cereal pancake mixes': 0.048411313248329,
#  'hot dogs bacon sausage': 0.09765336219314223,
#  'ice cream ice': 0.17282351058235335,
#  'ice cream toppings': 0.003841199917688573,
#  'indian foods': 0.005479807025432707,
#  'instant foods': 0.07558170552324917,
#  'juice nectars': 0.10936749765641077,
#  'kitchen supplies': 0.003414399926834287,
#  'kosher foods': 0.004786257040294492,
#  'latino foods': 0.027040827991982257,
#  'laundry': 0.03533294210000838,
#  'lunch meat': 0.1292365615163594,
#  'marinades meat preparation': 0.02214024952556608,
#  'meat counter': 0.024076092341226592,
#  'milk': 0.24879390895441625,
#  'mint gum': 0.007331814128603983,
#  'missing': 0.06288440579533416,
#  'more household': 0.0067906927116280135,
#  'muscles joints pain relief': 0.006836421282076687,
#  'nuts seeds dried fruit': 0.0955117408104627,
#  'oils vinegars': 0.08093956969415207,
#  'oral hygiene': 0.0233977852129046,
#  'other': 0.013680463992561486,
#  'other creams cheeses': 0.09770671219199903,
#  'packaged cheese': 0.31780594318987265,
#  'packaged meat': 0.011630299750779291,
#  'packaged poultry': 0.04274097051269349,
#  'packaged produce': 0.10258442637319086,
#  'packaged seafood': 0.0069278784229740336,
#  'packaged vegetables fruits': 0.5982287800379548,
#  'paper goods': 0.09674641221257688,
#  'pasta sauce': 0.07420222698138085,
#  'pickled goods olives': 0.037207813488404,
#  'plates bowls cups flatware': 0.014930378251491894,
#  'popcorn jerky': 0.052717420298912424,
#  'poultry counter': 0.03969239914944859,
#  'prepared meals': 0.03149936361072792,
#  'prepared soups salads': 0.022376513806217562,
#  'preserved dips spreads': 0.039539970581286346,
#  'protein meal replacements': 0.012285742593876945,
#  'red wines': 0.009473435511283525,
#  'refrigerated': 0.1770305390636313,
#  'refrigerated pudding desserts': 0.013177449717626077,
#  'salad dressing toppings': 0.0359655206578817,
#  'seafood counter': 0.008261628394393677,
#  'shave needs': 0.004054599913115716,
#  'skin care': 0.004069842769931941,
#  'soap': 0.021134220975695266,
#  'soft drinks': 0.1240692330556593,
#  'soup broth bouillon': 0.11515216181816797,
#  'soy lactosefree': 0.1999862814288654,
#  'specialty cheeses': 0.029517792224618738,
#  'specialty wines champagnes': 0.0035134784961397465,
#  'spices seasonings': 0.07071923419887355,
#  'spirits': 0.007369921270644544,
#  'spreads': 0.09223452659497443,
#  'tea': 0.07145851275446044,
#  'tofu meat alternatives': 0.03904457773475905,
#  'tortillas flat bread': 0.06366179149296161,
#  'trail mix snack mix': 0.011150149761068219,
#  'trash bags liners': 0.012354335449549954,
#  'vitamins supplements': 0.015006592535573017,
#  'water seltzer sparkling water': 0.2790738440198462,
#  'white wines': 0.008292114108026126,
#  'yogurt': 0.4210077052641206}

# %%
def profile_by_aisle(aisle):
    is_aisle = orders_by_aisles[aisle] > 0
    aisle_orders = orders_by_aisles[is_aisle]
    
    typical_order_by_profile = {}
    for aisle_name in aisle_names:
        typical_order_by_profile[aisle_name] = aisle_orders[aisle_name].mean()
    
    return typical_order_by_profile

# %%
def compare(profile):
    relative_purchases = {}
    for aisle in profile:
        relative_purchases[aisle] = profile[aisle] / average_order[aisle]
        
    return relative_purchases

# %%
def sorter(comparison):
    return sorted(comparison, key=comparison.get)

# %%
aisle_names
# Out:
# array(['prepared soups salads', 'specialty cheeses',
#        'energy granola bars', 'instant foods',
#        'marinades meat preparation', 'other', 'packaged meat',
#        'bakery desserts', 'pasta sauce', 'kitchen supplies',
#        'cold flu allergy', 'fresh pasta', 'prepared meals',
#        'tofu meat alternatives', 'packaged seafood', 'fresh herbs',
#        'baking ingredients', 'bulk dried fruits vegetables',
#        'oils vinegars', 'oral hygiene', 'packaged cheese', 'hair care',
#        'popcorn jerky', 'fresh fruits', 'soap', 'coffee', 'beers coolers',
#        'red wines', 'honeys syrups nectars', 'latino foods',
#        'refrigerated', 'packaged produce', 'kosher foods',
#        'frozen meat seafood', 'poultry counter', 'butter',
#        'ice cream ice', 'frozen meals', 'seafood counter',
#        'dog food care', 'cat food care', 'frozen vegan vegetarian',
#        'buns rolls', 'eye ear care', 'candy chocolate', 'mint gum',
#        'vitamins supplements', 'breakfast bars pastries',
#        'packaged poultry', 'fruit vegetable snacks',
#        'preserved dips spreads', 'frozen breakfast', 'cream',
#        'paper goods', 'shave needs', 'diapers wipes', 'granola',
#        'frozen breads doughs', 'canned meals beans', 'trash bags liners',
#        'cookies cakes', 'white wines', 'grains rice dried goods',
#        'energy sports drinks', 'protein meal replacements', 'asian foods',
#        'fresh dips tapenades', 'bulk grains rice dried goods',
#        'soup broth bouillon', 'digestion',
#        'refrigerated pudding desserts', 'condiments', 'facial care',
#        'dish detergents', 'laundry', 'indian foods', 'soft drinks',
#        'crackers', 'frozen pizza', 'deodorants',
#        'canned jarred vegetables', 'baby accessories', 'fresh vegetables',
#        'milk', 'food storage', 'eggs', 'more household', 'spreads',
#        'salad dressing toppings', 'cocoa drink mixes', 'soy lactosefree',
#        'baby food formula', 'breakfast bakery', 'tea',
#        'canned meat seafood', 'lunch meat', 'baking supplies decor',
#        'juice nectars', 'canned fruit applesauce', 'missing',
#        'air fresheners candles', 'baby bath body care',
#        'ice cream toppings', 'spices seasonings',
#        'doughs gelatins bake mixes', 'hot dogs bacon sausage',
#        'chips pretzels', 'other creams cheeses', 'skin care',
#        'pickled goods olives', 'plates bowls cups flatware', 'bread',
#        'frozen juice', 'cleaning products',
#        'water seltzer sparkling water', 'frozen produce',
#        'nuts seeds dried fruit', 'first aid', 'frozen dessert', 'yogurt',
#        'cereal', 'meat counter', 'packaged vegetables fruits', 'spirits',
#        'trail mix snack mix', 'feminine care', 'body lotions soap',
#        'tortillas flat bread', 'frozen appetizers sides',
#        'hot cereal pancake mixes', 'dry pasta', 'beauty',
#        'muscles joints pain relief', 'specialty wines champagnes'],
#       dtype=object)

# %%
yogurt_compare = compare(profile_by_aisle('yogurt'))

# %%
sorter(yogurt_compare)
# Out:
# ['spirits',
#  'beers coolers',
#  'specialty wines champagnes',
#  'red wines',
#  'white wines',
#  'packaged produce',
#  'cold flu allergy',
#  'muscles joints pain relief',
#  'first aid',
#  'more household',
#  'eye ear care',
#  'kitchen supplies',
#  'feminine care',
#  'air fresheners candles',
#  'mint gum',
#  'baking supplies decor',
#  'cocoa drink mixes',
#  'plates bowls cups flatware',
#  'facial care',
#  'soft drinks',
#  'bakery desserts',
#  'shave needs',
#  'cat food care',
#  'cleaning products',
#  'trash bags liners',
#  'beauty',
#  'dog food care',
#  'body lotions soap',
#  'laundry',
#  'food storage',
#  'deodorants',
#  'paper goods',
#  'hair care',
#  'energy sports drinks',
#  'frozen dessert',
#  'water seltzer sparkling water',
#  'spices seasonings',
#  'ice cream toppings',
#  'trail mix snack mix',
#  'kosher foods',
#  'candy chocolate',
#  'skin care',
#  'oils vinegars',
#  'baking ingredients',
#  'oral hygiene',
#  'condiments',
#  'marinades meat preparation',
#  'other',
#  'tea',
#  'canned meat seafood',
#  'vitamins supplements',
#  'salad dressing toppings',
#  'prepared soups salads',
#  'digestion',
#  'diapers wipes',
#  'coffee',
#  'asian foods',
#  'pickled goods olives',
#  'buns rolls',
#  'frozen meat seafood',
#  'frozen juice',
#  'fresh herbs',
#  'cookies cakes',
#  'dish detergents',
#  'frozen vegan vegetarian',
#  'doughs gelatins bake mixes',
#  'soup broth bouillon',
#  'protein meal replacements',
#  'hot dogs bacon sausage',
#  'ice cream ice',
#  'popcorn jerky',
#  'preserved dips spreads',
#  'honeys syrups nectars',
#  'canned jarred vegetables',
#  'juice nectars',
#  'meat counter',
#  'packaged meat',
#  'butter',
#  'cream',
#  'soap',
#  'frozen meals',
#  'chips pretzels',
#  'specialty cheeses',
#  'soy lactosefree',
#  'prepared meals',
#  'bulk dried fruits vegetables',
#  'packaged seafood',
#  'nuts seeds dried fruit',
#  'latino foods',
#  'refrigerated',
#  'fresh vegetables',
#  'tofu meat alternatives',
#  'frozen appetizers sides',
#  'frozen pizza',
#  'packaged poultry',
#  'grains rice dried goods',
#  'poultry counter',
#  'eggs',
#  'spreads',
#  'frozen breads doughs',
#  'canned meals beans',
#  'dry pasta',
#  'pasta sauce',
#  'tortillas flat bread',
#  'fresh dips tapenades',
#  'breakfast bars pastries',
#  'packaged vegetables fruits',
#  'other creams cheeses',
#  'indian foods',
#  'bread',
#  'bulk grains rice dried goods',
#  'frozen produce',
#  'crackers',
#  'seafood counter',
#  'baby accessories',
#  'fresh fruits',
#  'lunch meat',
#  'instant foods',
#  'breakfast bakery',
#  'refrigerated pudding desserts',
#  'packaged cheese',
#  'missing',
#  'fresh pasta',
#  'milk',
#  'hot cereal pancake mixes',
#  'cereal',
#  'energy granola bars',
#  'baby bath body care',
#  'fruit vegetable snacks',
#  'frozen breakfast',
#  'canned fruit applesauce',
#  'baby food formula',
#  'granola',
#  'yogurt']

# %%
yogurt_compare['beers coolers']
# Out:
# 0.4227362928044821

# %%
from numpy import arange
def plot_comparison(profile_name, select_aisles, aisle_lists):
    plot_list = []
    tick_titles = []
    for aisle in select_aisles:
        plot_list.append(aisle_lists[aisle])
        tick_titles.append(aisle.capitalize())
    fig, ax = plt.subplots(figsize=(20, 20))
    plt.xlabel('Aisles', fontsize=30, labelpad=50)
    plt.ylabel('Relative aisle purchases compared to average order', fontsize=30, labelpad=50)
    ax.set_title(profile_name, fontsize=50, color='#424242', loc='left')
    ax.xaxis.label.set_color('#424242')
    ax.yaxis.label.set_color('#424242')
    ax.tick_params(colors='#616161')
    plt.xticks(fontsize=30, rotation=45)
    plt.yticks(fontsize=30)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    plt.tick_params(bottom="off", top="off", left="off", right="off")
    colors = ['#e57373', '#ba68c8', '#64b5f6', '#4db6ac', '#81c784', '#fff176', '#ffb74d', '#90a4ae', '#a1887f']
    
    ax.set_xticks(range(2,(2*len(select_aisles)) + 2,2))
    bar_positions = (arange(len(select_aisles))  + 1)*2
    ax.set_xticklabels(tick_titles)
    
    ax.bar(bar_positions, plot_list, 1.5, color='#4285f4')
    ax.set_facecolor('#f5f5f5')
    fig.patch.set_facecolor('#f5f5f5')
    plt.show()

# %%
yogurt_isles = ['beers coolers', 'granola', 'baby food formula', 'fruit vegetable snacks', 'muscles joints pain relief', 'soft drinks']

# %%
plot_comparison('Orders that contain a product from the yogurt aisle', yogurt_isles, yogurt_compare)

# %%
beers_compare = compare(profile_by_aisle('beers coolers'))

# %%
sorter(beers_compare)
# Out:
# ['bulk grains rice dried goods',
#  'beauty',
#  'seafood counter',
#  'tofu meat alternatives',
#  'bulk dried fruits vegetables',
#  'digestion',
#  'packaged produce',
#  'refrigerated pudding desserts',
#  'soap',
#  'baby accessories',
#  'soy lactosefree',
#  'spices seasonings',
#  'frozen juice',
#  'baby food formula',
#  'fresh vegetables',
#  'fresh fruits',
#  'skin care',
#  'ice cream toppings',
#  'vitamins supplements',
#  'packaged vegetables fruits',
#  'frozen produce',
#  'fruit vegetable snacks',
#  'indian foods',
#  'poultry counter',
#  'grains rice dried goods',
#  'meat counter',
#  'canned jarred vegetables',
#  'granola',
#  'hair care',
#  'trail mix snack mix',
#  'fresh herbs',
#  'frozen vegan vegetarian',
#  'missing',
#  'soup broth bouillon',
#  'pasta sauce',
#  'baking ingredients',
#  'energy granola bars',
#  'spreads',
#  'diapers wipes',
#  'yogurt',
#  'packaged seafood',
#  'protein meal replacements',
#  'packaged poultry',
#  'oils vinegars',
#  'canned meals beans',
#  'frozen breads doughs',
#  'dry pasta',
#  'prepared meals',
#  'frozen breakfast',
#  'butter',
#  'milk',
#  'hot cereal pancake mixes',
#  'kosher foods',
#  'packaged meat',
#  'cold flu allergy',
#  'kitchen supplies',
#  'dog food care',
#  'nuts seeds dried fruit',
#  'canned fruit applesauce',
#  'asian foods',
#  'eye ear care',
#  'packaged cheese',
#  'refrigerated',
#  'juice nectars',
#  'latino foods',
#  'cereal',
#  'fresh dips tapenades',
#  'eggs',
#  'popcorn jerky',
#  'doughs gelatins bake mixes',
#  'specialty cheeses',
#  'cream',
#  'baking supplies decor',
#  'tortillas flat bread',
#  'ice cream ice',
#  'frozen meat seafood',
#  'frozen appetizers sides',
#  'tea',
#  'crackers',
#  'feminine care',
#  'lunch meat',
#  'other creams cheeses',
#  'hot dogs bacon sausage',
#  'muscles joints pain relief',
#  'bread',
#  'frozen meals',
#  'baby bath body care',
#  'fresh pasta',
#  'first aid',
#  'breakfast bakery',
#  'air fresheners candles',
#  'facial care',
#  'shave needs',
#  'water seltzer sparkling water',
#  'instant foods',
#  'salad dressing toppings',
#  'canned meat seafood',
#  'laundry',
#  'oral hygiene',
#  'breakfast bars pastries',
#  'condiments',
#  'energy sports drinks',
#  'honeys syrups nectars',
#  'dish detergents',
#  'cookies cakes',
#  'candy chocolate',
#  'cleaning products',
#  'prepared soups salads',
#  'food storage',
#  'marinades meat preparation',
#  'preserved dips spreads',
#  'mint gum',
#  'pickled goods olives',
#  'chips pretzels',
#  'bakery desserts',
#  'deodorants',
#  'buns rolls',
#  'frozen dessert',
#  'coffee',
#  'paper goods',
#  'frozen pizza',
#  'body lotions soap',
#  'plates bowls cups flatware',
#  'soft drinks',
#  'trash bags liners',
#  'more household',
#  'cat food care',
#  'cocoa drink mixes',
#  'other',
#  'specialty wines champagnes',
#  'white wines',
#  'spirits',
#  'red wines',
#  'beers coolers']

# %%
beers_isles = ['beauty', 'tofu meat alternatives', 'bulk dried fruits vegetables', 'soft drinks', 'frozen pizza']

# %%
plot_comparison('Orders that contain a product from the beers and coolers aisle', beers_isles, beers_compare)

# %%
vegetables_compare = compare(profile_by_aisle('fresh vegetables'))

# %%
sorter(vegetables_compare)
# Out:
# ['beers coolers',
#  'mint gum',
#  'specialty wines champagnes',
#  'first aid',
#  'cold flu allergy',
#  'spirits',
#  'eye ear care',
#  'trail mix snack mix',
#  'facial care',
#  'energy sports drinks',
#  'body lotions soap',
#  'plates bowls cups flatware',
#  'red wines',
#  'feminine care',
#  'muscles joints pain relief',
#  'white wines',
#  'shave needs',
#  'soft drinks',
#  'cat food care',
#  'breakfast bars pastries',
#  'cleaning products',
#  'air fresheners candles',
#  'trash bags liners',
#  'diapers wipes',
#  'more household',
#  'laundry',
#  'deodorants',
#  'beauty',
#  'candy chocolate',
#  'cookies cakes',
#  'cocoa drink mixes',
#  'packaged produce',
#  'paper goods',
#  'bakery desserts',
#  'ice cream toppings',
#  'oral hygiene',
#  'water seltzer sparkling water',
#  'hair care',
#  'popcorn jerky',
#  'coffee',
#  'tea',
#  'digestion',
#  'frozen meals',
#  'baking supplies decor',
#  'dog food care',
#  'food storage',
#  'frozen juice',
#  'protein meal replacements',
#  'refrigerated pudding desserts',
#  'frozen dessert',
#  'cereal',
#  'energy granola bars',
#  'ice cream ice',
#  'kitchen supplies',
#  'other',
#  'chips pretzels',
#  'frozen pizza',
#  'fruit vegetable snacks',
#  'vitamins supplements',
#  'baby accessories',
#  'dish detergents',
#  'baby bath body care',
#  'crackers',
#  'prepared soups salads',
#  'frozen meat seafood',
#  'juice nectars',
#  'refrigerated',
#  'doughs gelatins bake mixes',
#  'breakfast bakery',
#  'prepared meals',
#  'skin care',
#  'granola',
#  'cream',
#  'frozen appetizers sides',
#  'frozen breakfast',
#  'milk',
#  'spreads',
#  'canned fruit applesauce',
#  'honeys syrups nectars',
#  'nuts seeds dried fruit',
#  'bulk dried fruits vegetables',
#  'instant foods',
#  'kosher foods',
#  'hot cereal pancake mixes',
#  'soap',
#  'buns rolls',
#  'baking ingredients',
#  'yogurt',
#  'bread',
#  'baby food formula',
#  'frozen vegan vegetarian',
#  'soy lactosefree',
#  'fresh pasta',
#  'fresh dips tapenades',
#  'lunch meat',
#  'hot dogs bacon sausage',
#  'missing',
#  'butter',
#  'preserved dips spreads',
#  'canned meat seafood',
#  'condiments',
#  'frozen breads doughs',
#  'other creams cheeses',
#  'packaged cheese',
#  'eggs',
#  'salad dressing toppings',
#  'oils vinegars',
#  'indian foods',
#  'soup broth bouillon',
#  'packaged meat',
#  'specialty cheeses',
#  'tortillas flat bread',
#  'frozen produce',
#  'fresh fruits',
#  'marinades meat preparation',
#  'pasta sauce',
#  'asian foods',
#  'pickled goods olives',
#  'dry pasta',
#  'packaged poultry',
#  'packaged seafood',
#  'packaged vegetables fruits',
#  'spices seasonings',
#  'tofu meat alternatives',
#  'canned meals beans',
#  'latino foods',
#  'grains rice dried goods',
#  'bulk grains rice dried goods',
#  'poultry counter',
#  'canned jarred vegetables',
#  'meat counter',
#  'seafood counter',
#  'fresh herbs',
#  'fresh vegetables']

# %%
vegetables_aisles = ['beers coolers', 'soft drinks', 'cookies cakes', 'fresh herbs', 'seafood counter', 'latino foods']

# %%
plot_comparison('Orders that contain a product from the fresh vegetables aisle', vegetables_aisles, vegetables_compare)

# %%
tofu_compare = compare(profile_by_aisle('tofu meat alternatives'))

# %%
sorter(tofu_compare)
# Out:
# ['specialty wines champagnes',
#  'beers coolers',
#  'more household',
#  'red wines',
#  'white wines',
#  'spirits',
#  'eye ear care',
#  'facial care',
#  'body lotions soap',
#  'plates bowls cups flatware',
#  'mint gum',
#  'muscles joints pain relief',
#  'first aid',
#  'shave needs',
#  'packaged produce',
#  'cold flu allergy',
#  'energy sports drinks',
#  'soft drinks',
#  'frozen dessert',
#  'diapers wipes',
#  'cleaning products',
#  'air fresheners candles',
#  'cocoa drink mixes',
#  'baking supplies decor',
#  'ice cream toppings',
#  'frozen juice',
#  'laundry',
#  'poultry counter',
#  'trash bags liners',
#  'feminine care',
#  'trail mix snack mix',
#  'food storage',
#  'lunch meat',
#  'packaged poultry',
#  'canned fruit applesauce',
#  'packaged meat',
#  'kosher foods',
#  'hot dogs bacon sausage',
#  'meat counter',
#  'beauty',
#  'deodorants',
#  'paper goods',
#  'breakfast bars pastries',
#  'cream',
#  'hair care',
#  'popcorn jerky',
#  'water seltzer sparkling water',
#  'cat food care',
#  'frozen meat seafood',
#  'kitchen supplies',
#  'cookies cakes',
#  'digestion',
#  'candy chocolate',
#  'butter',
#  'oral hygiene',
#  'milk',
#  'coffee',
#  'canned meat seafood',
#  'doughs gelatins bake mixes',
#  'juice nectars',
#  'refrigerated pudding desserts',
#  'prepared soups salads',
#  'bakery desserts',
#  'tea',
#  'marinades meat preparation',
#  'chips pretzels',
#  'ice cream ice',
#  'buns rolls',
#  'honeys syrups nectars',
#  'crackers',
#  'dog food care',
#  'cereal',
#  'other',
#  'breakfast bakery',
#  'frozen pizza',
#  'refrigerated',
#  'specialty cheeses',
#  'fruit vegetable snacks',
#  'baby accessories',
#  'eggs',
#  'baking ingredients',
#  'other creams cheeses',
#  'energy granola bars',
#  'frozen appetizers sides',
#  'frozen breakfast',
#  'fresh pasta',
#  'yogurt',
#  'salad dressing toppings',
#  'latino foods',
#  'vitamins supplements',
#  'dish detergents',
#  'hot cereal pancake mixes',
#  'bread',
#  'nuts seeds dried fruit',
#  'spreads',
#  'instant foods',
#  'fresh fruits',
#  'granola',
#  'prepared meals',
#  'frozen breads doughs',
#  'frozen meals',
#  'bulk dried fruits vegetables',
#  'packaged cheese',
#  'oils vinegars',
#  'baby food formula',
#  'protein meal replacements',
#  'spices seasonings',
#  'packaged vegetables fruits',
#  'soap',
#  'preserved dips spreads',
#  'packaged seafood',
#  'missing',
#  'fresh herbs',
#  'skin care',
#  'condiments',
#  'seafood counter',
#  'tortillas flat bread',
#  'canned jarred vegetables',
#  'soup broth bouillon',
#  'fresh dips tapenades',
#  'dry pasta',
#  'pasta sauce',
#  'pickled goods olives',
#  'fresh vegetables',
#  'frozen produce',
#  'soy lactosefree',
#  'baby bath body care',
#  'grains rice dried goods',
#  'canned meals beans',
#  'bulk grains rice dried goods',
#  'asian foods',
#  'indian foods',
#  'frozen vegan vegetarian',
#  'tofu meat alternatives']

# %%
tofu_compare['poultry counter']
# Out:
# 0.7557517518414195

# %%
tofu_aisles = ['beers coolers', 'soft drinks', 'frozen vegan vegetarian', 'indian foods', 'asian foods', 'soy lactosefree', 'poultry counter']

# %%
plot_comparison('Orders that contain products from the tofu meat alternatives aisle', tofu_aisles, tofu_compare)
