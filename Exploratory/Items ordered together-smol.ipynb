# %% [markdown]
# # Data and import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
products = pd.read_csv('instacart_2017_05_01/products.csv')
order_products = pd.read_csv('instacart_2017_05_01/order_products__train.csv')
aisles = pd.read_csv('instacart_2017_05_01/aisles.csv')

# %%
order_products = order_products[['order_id', 'product_id']]

# %%
order_products.head()
# Out:
#    order_id  product_id
# 0         1       49302
# 1         1       11109
# 2         1       10246
# 3         1       49683
# 4         1       43633

# %% [markdown]
# ### Merging data

# %%
order_products = order_products.merge(products, on='product_id', how='inner')

# %%
order_products.head()
# Out:
#    order_id  product_id      product_name  aisle_id  department_id
# 0         1       49302  Bulgarian Yogurt       120             16
# 1    816049       49302  Bulgarian Yogurt       120             16
# 2   1242203       49302  Bulgarian Yogurt       120             16
# 3   1383349       49302  Bulgarian Yogurt       120             16
# 4   1787378       49302  Bulgarian Yogurt       120             16

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
order_products = order_products.merge(aisles, on='aisle_id', how='inner')

# %%
order_products.head()
# Out:
#    order_id  product_id      product_name  aisle_id  department_id   aisle
# 0         1       49302  Bulgarian Yogurt       120             16  yogurt
# 1    816049       49302  Bulgarian Yogurt       120             16  yogurt
# 2   1242203       49302  Bulgarian Yogurt       120             16  yogurt
# 3   1383349       49302  Bulgarian Yogurt       120             16  yogurt
# 4   1787378       49302  Bulgarian Yogurt       120             16  yogurt

# %% [markdown]
# # Find the most paired items

# %%
order_products.head(20)
# Out:
#     order_id  product_id                                  product_name  \
# 0          1       49302                              Bulgarian Yogurt
# 1     816049       49302                              Bulgarian Yogurt
# 2    1242203       49302                              Bulgarian Yogurt
# 3    1383349       49302                              Bulgarian Yogurt
# 4    1787378       49302                              Bulgarian Yogurt
# 5    2445303       49302                              Bulgarian Yogurt
# 6    2853065       49302                              Bulgarian Yogurt
# 7    3231517       49302                              Bulgarian Yogurt
# 8         98       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 9      13746       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 10     55207       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 11     55435       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 12     82318       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 13    118143       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 14    121618       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 15    142429       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 16    146599       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 17    221481       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 18    243031       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
# 19    267982       43654  Whole Milk Greek Blended Vanilla Bean Yogurt
#
#     aisle_id  department_id   aisle
# 0        120             16  yogurt
# 1        120             16  yogurt
# 2        120             16  yogurt
# 3        120             16  yogurt
# 4        120             16  yogurt
# 5        120             16  yogurt
# 6        120             16  yogurt
# 7        120             16  yogurt
# 8        120             16  yogurt
# 9        120             16  yogurt
# 10       120             16  yogurt
# 11       120             16  yogurt
# 12       120             16  yogurt
# 13       120             16  yogurt
# 14       120             16  yogurt
# 15       120             16  yogurt
# 16       120             16  yogurt
# 17       120             16  yogurt
# 18       120             16  yogurt
# 19       120             16  yogurt

# %%
order_products = order_products[['order_id', 'aisle']]
order_products.head(10)
# Out:
#    order_id   aisle
# 0         1  yogurt
# 1    816049  yogurt
# 2   1242203  yogurt
# 3   1383349  yogurt
# 4   1787378  yogurt
# 5   2445303  yogurt
# 6   2853065  yogurt
# 7   3231517  yogurt
# 8        98  yogurt
# 9     13746  yogurt

# %%
order_products.to_pickle("./order_products_smol.pkl")
order_products.shape[0]
# Out:
# 1384617

# %%
order_products = pd.read_pickle("./order_products_smol.pkl")
order_products.shape[0]
# Out:
# 32434489

# %%
import itertools
def find_pairings(aisles):
    if len(aisles) == 1:
        return None
    else:
        return [list(pairs) for pairs in itertools.combinations(aisles, 2)]

# %%
def row_count(df_list):
    rows = 0
    for df in df_list:
        rows += df.shape[0]
    return rows

# %%
import itertools
product_pairings = order_products.groupby('order_id').agg(find_pairings)
product_pairings.dropna(inplace=True)
product_pairings.head()
# Out:
#                                                       aisle
# order_id
# 1         [[yogurt, other creams cheeses], [yogurt, fres...
# 36        [[fresh vegetables, fresh vegetables], [fresh ...
# 38        [[fresh vegetables, packaged vegetables fruits...
# 96        [[fresh vegetables, packaged vegetables fruits...
# 98        [[yogurt, fresh vegetables], [yogurt, fresh ve...

# %%
product_pairings.shape[0]
# Out:
# 124364

# %%
product_pairings.to_pickle("pp_smol.pkl")

# %%
product_pairings.read_picle("pp_smol.pkl")

# %%
all_aisles = order_products['aisle'].unique()

# %%
import networkx as nx

g = nx.MultiGraph()
g.add_nodes_from(all_aisles)

for pairs in product_pairings['aisle']:
    g.add_edges_from(pairs)

# %%
M = nx.Graph()
for u,v,data in g.edges(data=True):
    w = data['weight'] if 'weight' in data else 1.0
    if M.has_edge(u,v):
        M[u][v]['weight'] += w
    else:
        M.add_edge(u, v, weight=w)

# %%
M.edges(data=True)
# Out:
# EdgeDataView([('yogurt', 'other creams cheeses', {'weight': 8576.0}), ('yogurt', 'fresh vegetables', {'weight': 87211.0}), ('yogurt', 'canned meat seafood', {'weight': 1663.0}), ('yogurt', 'fresh fruits', {'weight': 101020.0}), ('yogurt', 'packaged cheese', {'weight': 29156.0}), ('yogurt', 'specialty cheeses', {'weight': 2272.0}), ('yogurt', 'water seltzer sparkling water', {'weight': 18640.0}), ('yogurt', 'packaged vegetables fruits', {'weight': 50196.0}), ('yogurt', 'lunch meat', {'weight': 11884.0}), ('yogurt', 'oils vinegars', {'weight': 5039.0}), ('yogurt', 'fresh herbs', {'weight': 8181.0}), ('yogurt', 'refrigerated', {'weight': 15031.0}), ('yogurt', 'refrigerated pudding desserts', {'weight': 1246.0}), ('yogurt', 'canned jarred vegetables', {'weight': 7174.0}), ('yogurt', 'soy lactosefree', {'weight': 15993.0}), ('yogurt', 'crackers', {'weight': 13512.0}), ('yogurt', 'hot dogs bacon sausage', {'weight': 7327.0}), ('yogurt', 'frozen appetizers sides', {'weight': 5510.0}), ('yogurt', 'butter', {'weight': 6108.0}), ('yogurt', 'fresh dips tapenades', {'weight': 10030.0}), ('yogurt', 'canned meals beans', {'weight': 7324.0}), ('yogurt', 'ice cream ice', {'weight': 13743.0}), ('yogurt', 'dish detergents', {'weight': 2170.0}), ('yogurt', 'milk', {'weight': 23360.0}), ('yogurt', 'canned fruit applesauce', {'weight': 3436.0}), ('yogurt', 'frozen meat seafood', {'weight': 1905.0}), ('yogurt', 'baking ingredients', {'weight': 6337.0}), ('yogurt', 'laundry', {'weight': 2092.0}), ('yogurt', 'soup broth bouillon', {'weight': 8619.0}), ('yogurt', 'condiments', {'weight': 4978.0}), ('yogurt', 'juice nectars', {'weight': 8777.0}), ('yogurt', 'tortillas flat bread', {'weight': 5201.0}), ('yogurt', 'soap', {'weight': 1602.0}), ('yogurt', 'plates bowls cups flatware', {'weight': 777.0}), ('yogurt', 'food storage', {'weight': 1292.0}), ('yogurt', 'paper goods', {'weight': 5954.0}), ('yogurt', 'bread', {'weight': 15711.0}), ('yogurt', 'grains rice dried goods', {'weight': 3710.0}), ('yogurt', 'spreads', {'weight': 7811.0}), ('yogurt', 'popcorn jerky', {'weight': 4282.0}), ('yogurt', 'yogurt', {'weight': 43234.0}), ('yogurt', 'missing', {'weight': 6567.0}), ('yogurt', 'spices seasonings', {'weight': 4143.0}), ('yogurt', 'latino foods', {'weight': 2201.0}), ('yogurt', 'preserved dips spreads', {'weight': 2953.0}), ('yogurt', 'asian foods', {'weight': 3699.0}), ('yogurt', 'cream', {'weight': 7794.0}), ('yogurt', 'frozen produce', {'weight': 14444.0}), ('yogurt', 'energy granola bars', {'weight': 14165.0}), ('yogurt', 'hot cereal pancake mixes', {'weight': 4543.0}), ('yogurt', 'packaged meat', {'weight': 866.0}), ('yogurt', 'chips pretzels', {'weight': 19995.0}), ('yogurt', 'soft drinks', {'weight': 6894.0}), ('yogurt', 'cookies cakes', {'weight': 6083.0}), ('yogurt', 'frozen pizza', {'weight': 4673.0}), ('yogurt', 'tea', {'weight': 5484.0}), ('yogurt', 'instant foods', {'weight': 7113.0}), ('yogurt', 'energy sports drinks', {'weight': 2561.0}), ('yogurt', 'prepared meals', {'weight': 2462.0}), ('yogurt', 'pasta sauce', {'weight': 6327.0}), ('yogurt', 'frozen breakfast', {'weight': 7821.0}), ('yogurt', 'dry pasta', {'weight': 7223.0}), ('yogurt', 'frozen meals', {'weight': 11661.0}), ('yogurt', 'cereal', {'weight': 12281.0}), ('yogurt', 'breakfast bakery', {'weight': 6984.0}), ('yogurt', 'eggs', {'weight': 11859.0}), ('yogurt', 'fruit vegetable snacks', {'weight': 5332.0}), ('yogurt', 'doughs gelatins bake mixes', {'weight': 2783.0}), ('yogurt', 'nuts seeds dried fruit', {'weight': 7883.0}), ('yogurt', 'bulk grains rice dried goods', {'weight': 366.0}), ('yogurt', 'poultry counter', {'weight': 3023.0}), ('yogurt', 'packaged poultry', {'weight': 3372.0}), ('yogurt', 'fresh pasta', {'weight': 1187.0}), ('yogurt', 'tofu meat alternatives', {'weight': 2934.0}), ('yogurt', 'dog food care', {'weight': 686.0}), ('yogurt', 'pickled goods olives', {'weight': 2593.0}), ('yogurt', 'baby food formula', {'weight': 13057.0}), ('yogurt', 'packaged produce', {' ...

# %%
weight_list = sorted(M.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)
weight_list
# Out:
# [('fresh vegetables', 'fresh fruits', {'weight': 308105.0}),
#  ('fresh vegetables', 'fresh vegetables', {'weight': 224647.0}),
#  ('fresh vegetables', 'packaged vegetables fruits', {'weight': 169766.0}),
#  ('fresh fruits', 'packaged vegetables fruits', {'weight': 158522.0}),
#  ('fresh fruits', 'fresh fruits', {'weight': 147079.0}),
#  ('yogurt', 'fresh fruits', {'weight': 101020.0}),
#  ('yogurt', 'fresh vegetables', {'weight': 87211.0}),
#  ('fresh vegetables', 'packaged cheese', {'weight': 73818.0}),
#  ('fresh fruits', 'packaged cheese', {'weight': 69250.0}),
#  ('fresh vegetables', 'fresh herbs', {'weight': 53544.0}),
#  ('fresh fruits', 'milk', {'weight': 53092.0}),
#  ('yogurt', 'packaged vegetables fruits', {'weight': 50196.0}),
#  ('fresh vegetables', 'milk', {'weight': 46253.0}),
#  ('fresh fruits', 'water seltzer sparkling water', {'weight': 45582.0}),
#  ('fresh fruits', 'chips pretzels', {'weight': 45322.0}),
#  ('fresh vegetables', 'soy lactosefree', {'weight': 45295.0}),
#  ('fresh fruits', 'soy lactosefree', {'weight': 44034.0}),
#  ('fresh vegetables', 'frozen produce', {'weight': 43945.0}),
#  ('yogurt', 'yogurt', {'weight': 43234.0}),
#  ('packaged vegetables fruits',
#   'packaged vegetables fruits',
#   {'weight': 41718.0}),
#  ('fresh fruits', 'frozen produce', {'weight': 40511.0}),
#  ('fresh vegetables', 'water seltzer sparkling water', {'weight': 40130.0}),
#  ('fresh vegetables', 'chips pretzels', {'weight': 39960.0}),
#  ('packaged cheese', 'packaged vegetables fruits', {'weight': 39294.0}),
#  ('fresh fruits', 'bread', {'weight': 38799.0}),
#  ('fresh vegetables', 'bread', {'weight': 37027.0}),
#  ('fresh vegetables', 'eggs', {'weight': 35955.0}),
#  ('fresh fruits', 'refrigerated', {'weight': 35660.0}),
#  ('fresh fruits', 'eggs', {'weight': 32481.0}),
#  ('fresh vegetables', 'canned jarred vegetables', {'weight': 32446.0}),
#  ('fresh fruits', 'fresh herbs', {'weight': 31861.0}),
#  ('fresh vegetables', 'refrigerated', {'weight': 31532.0}),
#  ('fresh fruits', 'crackers', {'weight': 30509.0}),
#  ('fresh vegetables', 'soup broth bouillon', {'weight': 29873.0}),
#  ('fresh fruits', 'ice cream ice', {'weight': 29788.0}),
#  ('fresh fruits', 'energy granola bars', {'weight': 29319.0}),
#  ('yogurt', 'packaged cheese', {'weight': 29156.0}),
#  ('fresh fruits', 'lunch meat', {'weight': 28733.0}),
#  ('fresh vegetables', 'canned meals beans', {'weight': 27839.0}),
#  ('fresh vegetables', 'ice cream ice', {'weight': 27579.0}),
#  ('fresh vegetables', 'lunch meat', {'weight': 27297.0}),
#  ('baby food formula', 'baby food formula', {'weight': 26444.0}),
#  ('packaged vegetables fruits', 'milk', {'weight': 25999.0}),
#  ('fresh vegetables', 'crackers', {'weight': 25988.0}),
#  ('fresh vegetables', 'fresh dips tapenades', {'weight': 25731.0}),
#  ('fresh fruits', 'fresh dips tapenades', {'weight': 25621.0}),
#  ('fresh fruits', 'baby food formula', {'weight': 25306.0}),
#  ('fresh fruits', 'cereal', {'weight': 24233.0}),
#  ('packaged vegetables fruits', 'chips pretzels', {'weight': 24152.0}),
#  ('water seltzer sparkling water',
#   'packaged vegetables fruits',
#   {'weight': 23608.0}),
#  ('packaged vegetables fruits', 'frozen produce', {'weight': 23602.0}),
#  ('packaged vegetables fruits', 'soy lactosefree', {'weight': 23537.0}),
#  ('yogurt', 'milk', {'weight': 23360.0}),
#  ('fresh vegetables', 'dry pasta', {'weight': 22716.0}),
#  ('fresh vegetables', 'energy granola bars', {'weight': 22361.0}),
#  ('other creams cheeses', 'fresh vegetables', {'weight': 22278.0}),
#  ('fresh fruits', 'frozen meals', {'weight': 22119.0}),
#  ('fresh vegetables', 'spices seasonings', {'weight': 21709.0}),
#  ('fresh vegetables', 'baking ingredients', {'weight': 21702.0}),
#  ('fresh vegetables', 'oils vinegars', {'weight': 21614.0}),
#  ('fresh fruits', 'nuts seeds dried fruit', {'weight': 21404.0}),
#  ('fresh fruits', 'juice nectars', {'weight': 21374.0}),
#  ('fresh fruits', 'soup broth bouillon', {'weight': 21367.0}),
#  ('fresh vegetables', 'baby food formula', {'weight': 20635.0}),
#  ('fresh vegetables', 'hot dogs bacon sausage', {'weight': 20540.0}),
#  ('fresh vegetables', 'nuts seeds dried fruit', {'weight': 20319.0}),
#  ('packaged vegetables fruits', 'bread', {'weight': 20076.0}),
#  ('yogurt', 'chips pretzels', {'weight': 19995.0}),
#  ('fresh fruits', 'canned meals beans', {'weight': 19962.0}),
#  ('fresh vegetables', 'cereal', {'weight': 19919.0}),
#  ('fresh fruits', 'canned jarred vegetables', {'weight': 19896.0}),
#  ('fresh fruits', 'packaged produce', {'weight': 19860.0}),
#  ('other creams cheeses', 'fresh fruits', {'weight': 19794.0}),
#  ('fresh fruits', 'spreads', {'weight': 19477.0}),
#  ('fresh vegetables', 'frozen meals', {'weight': 19328.0}),
#  ('fresh fruits', 'hot dogs bacon sausage', {'weight': 18980.0}),
#  ('fresh vegetables', 'pasta sauce', {'weight': 18749.0}),
#  ('fresh vegetables', 'juice nectars', {'weight': 18676.0}),
#  ('yogurt', 'water seltzer sparkling water', {'weight': 18640.0}),
#  ('fresh vegetables', 'butter', {'weight': 18550.0}),
#  ('fresh fruits', 'dry pasta', {'weight': 18461.0}),
#  ('packaged vegetables fruits', 'eggs', {'weight': 18410.0}),
#  ('packaged vegetables fruits', 'refrigerated', {'weight': 18261.0}),
#  ('fresh fruits', 'cream', {'weight': 17789.0}),
#  ('fresh vegetables', 'cream', {'weight': 17757.0}),
#  ('fresh fruits', 'baking ingredients', {'weight': 17722.0}),
#  ('packaged vegetables fruits', 'fresh herbs', {'weight': 17618.0}),
#  ('fresh vegetables', 'condiments', {'weight': 17599.0}),
#  ('fresh vegetables', 'spreads', {'weight': 17527.0}),
#  ('packaged cheese', 'chips pretzels', {'weight': 16610.0}),
#  ('fresh vegetables', 'tortillas flat bread', {'weight': 16257.0}),
#  ('packaged vegetables fruits', 'crackers', {'weight': 16222.0}),
#  ('frozen meals', 'frozen meals', {'weight': 16189.0}),
#  ('packaged vegetables fruits', 'lunch meat', {'weight': 16143.0}),
#  ('fresh fruits', 'butter', {'weight': 16048.0}),
#  ('packaged cheese', 'milk', {'weight': 16042.0}),
#  ('yogurt', 'soy lactosefree', {'weight': 15993.0}),
#  ('water seltzer sparkling water',
#   'water seltzer sparkling water',
#   {'weight': 15911.0}),
#  ('fresh fruits', 'oils vinegars', {'weight': 15834.0}),
#  ('yogurt', 'bread', {'weight': 15711.0}),
#  ('fresh fruits', 'frozen breakfast', {'weight': 15654.0}),
#  ('packaged vegetables fruits', 'ice cream ice', {'weight': 15576.0}),
#  ('fresh fruits', 'pasta sauce', {'weight': 15559.0}),
#  ('packaged vegetables fruits', 'fresh dips tapenades', {'weight': 15477.0}),
#  ('fresh vegetables', 'asian foods', {'weight': 15316.0}),
#  ('yogurt', 'refrigerated', {'weight': 15031.0}),
#  ('fresh fruits', 'breakfast bakery', {'weight': 15020.0}),
#  ('fresh vegetables', 'grains rice dried goods', {'weight': 14963.0}),
#  ('fresh vegetables', 'missing', {'weight': 14799.0}),
#  ('fresh fruits', 'soft drinks', {'weight': 14445.0}),
#  ('yogurt', 'frozen produce', {'weight': 14444.0}),
#  ('fresh fruits', 'instant foods', {'weight': 14366.0}),
#  ('yogurt', 'energy granola bars', {'weight': 14165.0}),
#  ('fresh fruits', 'tortillas flat bread', {'weight': 14133.0}),
#  ('packaged vegetables fruits', 'energy granola bars', {'weight': 14097.0}),
#  ('fresh vegetables', 'instant foods', {'weight': 14021.0}),
#  ('fresh fruits', 'candy chocolate', {'weight': 14016.0}),
#  ('packaged cheese', 'packaged cheese', {'weight': 14006.0}),
#  ('yogurt', 'ice cream ice', {'weight': 13743.0}),
#  ('fresh fruits', 'missing', {'weight': 13743.0}),
#  ('energy granola bars', 'energy granola bars', {'weight': 13523.0}),
#  ('yogurt', 'crackers', {'weight': 13512.0}),
#  ('fresh fruits', 'spices seasonings', {'weight': 13354.0}),
#  ('packaged cheese', 'bread', {'weight': 13288.0}),
#  ('fresh fruits', 'condiments', {'weight': 13252.0}),
#  ('yogurt', 'baby food formula', {'weight': 13057.0}),
#  ('fresh vegetables', 'soft drinks', {'weight': 13046.0}),
#  ('packaged cheese', 'water seltzer sparkling water', {'weight': 13036.0}),
#  ('packaged vegetables fruits', 'frozen meals', {'weight': 13014.0}),
#  ('fresh vegetables', 'frozen breakfast', {'weight': 12984.0}),
#  ('fresh fruits', 'paper goods', {'weight': 12917.0}),
#  ('packaged vegetables fruits', 'soup broth bouillon', {'weight': 12895.0}),
#  ('fresh fruits', 'frozen appetizers sides', {'weight': 12836.0}),
#  ('fresh vegetables', 'breakfast bakery', {'weight': 12785.0}),
#  ('fresh vegetables', 'poultry counter', {'weight': 12704.0}),
#  ('fresh vegetables', 'paper goods', {'weight': 12676.0}),
#  ('fresh fruits', 'cookies cakes', {'weight': 12595.0}),
#  ('fresh fruits', 'tea', {'weight': 12527.0}),
#  ('packaged vegetables fruits', 'cereal', {'weight': 12475.0}),
#  ('water seltzer sparkling water', 'chips pretzels', {'weight': 12438.0}),
#  ('packaged cheese', 'lunch meat', {'weight': 12350.0}),
#  ('yogurt', 'cereal', {'weight': 12281.0}),
#  ('fresh vegetables', 'packaged produce', {'weight': 12260.0}),
#  ('fresh vegetables', 'tofu meat alternatives', {'weight': 12169.0}),
#  ('fresh vegetables', 'frozen appetizers sides', {'weight': 12095.0}),
#  ('packaged vegetables fruits',
#   'canned jarred vegetables',
#   {'weight': 12095.0}),
#  ('fresh fruits', 'fruit vegetable snacks', {'weight': 12065.0}),
#  ('packaged vegetables fruits', 'baby food formula', {'weight': 12055.0}),
#  ('packaged cheese', 'crackers', {'weight': 11965.0}),
#  ('chips pretzels', 'chips pretzels', {'weight': 11902.0}),
#  ('yogurt', 'lunch meat', {'weight': 11884.0}),
#  ('yogurt', 'eggs', {'weight': 11859.0}),
#  ('yogurt', 'frozen meals', {'weight': 11661.0}),
#  ('fresh vegetables', 'candy chocolate', {'weight': 11661.0}),
#  ('packaged vegetables fruits', 'nuts seeds dried fruit', {'weight': 11423.0}),
#  ('fresh vegetables', 'packaged poultry', {'weight': 11391.0}),
#  ('fresh vegetables', 'tea', {'weight': 11277.0}),
#  ('packaged vegetables fruits', 'canned meals beans', {'weight': 11216.0}),
#  ('packaged vegetables fruits', 'hot dogs bacon sausage', {'weight': 10888.0}),
#  ('crackers', 'chips pretzels', {'weight': 10881.0}),
#  ('packaged vegetables fruits', 'juice nectars', {'weight': 10840.0}),
#  ('other creams cheeses', 'packaged vegetables fruits', {'weight': 10739.0}),
#  ('packaged cheese', 'frozen produce', {'weight': 10665.0}),
#  ('fresh fruits', 'grains rice dried goods', {'weight': 10618.0}),
#  ('fresh fruits', 'hot cereal pancake mixes', {'weight': 10618.0}),
#  ('packaged vegetables fruits', 'dry pasta', {'weight': 10532.0}),
#  ('fresh fruits', 'asian foods', {'weight': 10481.0}),
#  ('fresh fruits', 'frozen pizza', {'weight': 10444.0}),
#  ('packaged cheese', 'soy lactosefree', {'weight': 10311.0}),
#  ('ice cream ice', 'ice cream ice', {'weight': 10298.0}),
#  ('fresh vegetables', 'pickled goods olives', {'weight': 10108.0}),
#  ('packaged vegetables fruits', 'spreads', {'weight': 10057.0}),
#  ('fresh fruits', 'coffee', {'weight': 10050.0}),
#  ('milk', 'chips pretzels', {'weight': 10046.0}),
#  ('packaged cheese', 'ice cream ice', {'weight': 10033.0}),
#  ('yogurt', 'fresh dips tapenades', {'weight': 10030.0}),
#  ('packaged cheese', 'eggs', {'weight': 9851.0}),
#  ('packaged vegetables fruits', 'packaged produce', {'weight': 9806.0}),
#  ('fresh fruits', 'popcorn jerky', {'weight': 9787.0}),
#  ('fresh vegetables', 'hot cereal pancake mixes', {'weight': 9775.0}),
#  ('fresh vegetables', 'cookies cakes', {'weight': 9730.0}),
#  ('water seltzer sparkling water', 'milk', {'weight': 9620.0}),
#  ('packaged cheese', 'refrigerated', {'weight': 9606.0}),
#  ('energy granola bars', 'chips pretzels', {'weight': 9582.0}),
#  ('milk', 'bread', {'weight': 9504.0}),
#  ('refrigerated', 'refrigerated', {'weight': 9326.0}),
#  ('fresh fruits', 'poultry counter', {'weight': 9325.0}),
#  ('fresh vegetables', 'frozen pizza', {'weight': 9318.0}),
#  ('packaged vegetables fruits', 'pasta sauce', {'weight': 9316.0}),
#  ('packaged vegetables fruits', 'baking ingredients', {'weight': 9300.0}),
#  ('packaged vegetables fruits', 'cream', {'weight': 9104.0}),
#  ('bread', 'chips pretzels', {'weight': 9086.0}),
#  ('packaged vegetables fruits', 'oils vinegars', {'weight': 9076.0}),
#  ('other creams cheeses', 'packaged cheese', {'weight': 9032.0}),
#  ('fresh dips tapenades', 'chips pretzels', {'weight': 9031.0}),
#  ('fresh vegetables', 'fruit vegetable snacks', {'weight': 8997.0}),
#  ('ice cream ice', 'chips pretzels', {'weight': 8994.0}),
#  ('fresh vegetables', 'coffee', {'weight': 8956.0}),
#  ('water seltzer sparkling water', 'refrigerated', {'weight': 8919.0}),
#  ('refrigerated', 'chips pretzels', {'weight': 8916.0}),
#  ('packaged cheese', 'frozen meals', {'weight': 8804.0}),
#  ('yogurt', 'juice nectars', {'weight': 8777.0}),
#  ('fresh vegetables', 'preserved dips spreads', {'weight': 8680.0}),
#  ('fresh fruits', 'packaged poultry', {'weight': 8629.0}),
#  ('yogurt', 'soup broth bouillon', {'weight': 8619.0}),
#  ('fresh fruits', 'tofu meat alternatives', {'weight': 8613.0}),
#  ('yogurt', 'other creams cheeses', {'weight': 8576.0}),
#  ('water seltzer sparkling water', 'soy lactosefree', {'weight': 8482.0}),
#  ('fresh vegetables', 'salad dressing toppings', {'weight': 8447.0}),
#  ('packaged vegetables fruits', 'frozen breakfast', {'weight': 8407.0}),
#  ('soy lactosefree', 'frozen produce', {'weight': 8371.0}),
#  ('packaged vegetables fruits', 'instant foods', {'weight': 8290.0}),
#  ('packaged vegetables fruits', 'butter', {'weight': 8254.0}),
#  ('yogurt', 'fresh herbs', {'weight': 8181.0}),
#  ('packaged cheese', 'cereal', {'weight': 8066.0}),
#  ('fresh vegetables', 'frozen vegan vegetarian', {'weight': 8017.0}),
#  ('packaged vegetables fruits', 'spices seasonings', {'weight': 7988.0}),
#  ('water seltzer sparkling water', 'soft drinks', {'weight': 7972.0}),
#  ('soy lactosefree', 'chips pretzels', {'weight': 7967.0}),
#  ('packaged cheese', 'fresh dips tapenades', {'weight': 7963.0}),
#  ('frozen produce', 'frozen produce', {'weight': 7943.0}),
#  ('packaged vegetables fruits', 'condiments', {'weight': 7933.0}),
#  ('packaged cheese', 'energy granola bars', {'weight': 7930.0}),
#  ('yogurt', 'nuts seeds dried fruit', {'weight': 7883.0}),
#  ('water seltzer sparkling water', 'energy granola bars', {'weight': 7839.0}),
#  ('yogurt', 'frozen breakfast', {'weight': 7821.0}),
#  ('packaged cheese', 'fresh herbs', {'weight': 7813.0}),
#  ('yogurt', 'spreads', {'weight': 7811.0}),
#  ('yogurt', 'cream', {'weight': 7794.0}),
#  ('packaged vegetables fruits', 'breakfast bakery', {'weight': 7790.0}),
#  ('packaged vegetables fruits', 'tortillas flat bread', {'weight': 7779.0}),
#  ('packaged vegetables fruits', 'missing', {'weight': 7769.0}),
#  ('fresh vegetables', 'meat counter', {'weight': 7755.0}),
#  ('packaged cheese', 'hot dogs bacon sausage', {'weight': 7729.0}),
#  ('fresh vegetables', 'latino foods', {'weight': 7665.0}),
#  ('packaged cheese', 'baby food formula', {'weight': 7654.0}),
#  ('refrigerated', 'milk', {'weight': 7626.0}),
#  ('packaged cheese', 'dry pasta', {'weight': 7578.0}),
#  ('packaged vegetables fruits', 'soft drinks', {'weight': 7559.0}),
#  ('packaged cheese', 'canned jarred vegetables', {'weight': 7557.0}),
#  ('fresh vegetables', 'popcorn jerky', {'weight': 7552.0}),
#  ('fresh fruits', 'preserved dips spreads', {'weight': 7473.0}),
#  ('chips pretzels', 'frozen meals', {'weight': 7470.0}),
#  ('fresh vegetables', 'specialty cheeses', {'weight': 7438.0}),
#  ('chips pretzels', 'cereal', {'weight': 7381.0}),
#  ('lunch meat', 'chips pretzels', {'weight': 7355.0}),
#  ('packaged cheese', 'soup broth bouillon', {'weight': 7335.0}),
#  ('yogurt', 'hot dogs bacon sausage', {'weight': 7327.0}),
#  ('yogurt', 'canned meals beans', {'weight': 7324.0}),
#  ('fresh fruits', 'pickled goods olives', {'weight': 7286.0}),
#  ('packaged vegetables fruits', 'frozen appetizers sides', {'weight': 7281.0}),
#  ('fresh vegetables', 'buns rolls', {'weight': 7272.0}),
#  ('milk', 'eggs', {'weight': 7264.0}),
#  ('yogurt', 'dry pasta', {'weight': 7223.0}),
#  ('milk', 'cereal', {'weight': 7220.0}),
#  ('yogurt', 'canned jarred vegetables', {'weight': 7174.0}),
#  ('water seltzer sparkling water', 'ice cream ice', {'weight': 7157.0}),
#  ('packaged vegetables fruits', 'paper goods', {'weight': 7151.0}),
#  ('yogurt', 'instant foods', {'weight': 7113.0}),
#  ('water seltzer sparkling water', 'crackers', {'weight': 7105.0}),
#  ('milk', 'frozen produce', {'weight': 7066.0}),
#  ('packaged vegetables fruits', 'candy chocolate', {'weight': 7038.0}),
#  ('fresh fruits', 'buns rolls', {'weight': 7030.0}),
#  ('yogurt', 'breakfast bakery', {'weight': 6984.0}),
#  ('ice cream ice', 'milk', {'weight': 6949.0}),
#  ('refrigerated', 'soy lactosefree', {'weight': 6933.0}),
#  ('chips pretzels', 'soft drinks', {'weight': 6905.0}),
#  ('yogurt', 'soft drinks', {'weight': 6894.0}),
#  ('yogurt', 'candy chocolate', {'weight': 6856.0}),
#  ('packaged cheese', 'pasta sauce', {'weight': 6816.0}),
#  ('water seltzer sparkling water', 'bread', {'weight': 6797.0}),
#  ('crackers', 'milk', {'weight': 6754.0}),
#  ('packaged cheese', 'canned meals beans', {'weight': 6742.0}),
#  ('fresh fruits', 'granola', {'weight': 6702.0}),
#  ('fresh fruits', 'frozen vegan vegetarian', {'weight': 6681.0}),
#  ('lunch meat', 'bread', {'weight': 6624.0}),
#  ('fresh fruits', 'canned fruit applesauce', {'weight': 6586.0}),
#  ('soy lactosefree', 'milk', {'weight': 6571.0}),
#  ('yogurt', 'missing', {'weight': 6567.0}),
#  ('frozen produce', 'chips pretzels', {'weight': 6509.0}),
#  ('milk', 'baby food formula', {'weight': 6496.0}),
#  ('lunch meat', 'milk', {'weight': 6479.0}),
#  ('fresh fruits', 'specialty cheeses', {'weight': 6446.0}),
#  ('chips pretzels', 'cookies cakes', {'weight': 6434.0}),
#  ('packaged vegetables fruits', 'cookies cakes', {'weight': 6389.0}),
#  ('fresh fruits', 'salad dressing toppings', {'weight': 6377.0}),
#  ('yogurt', 'baking ingredients', {'weight': 6337.0}),
#  ('yogurt', 'pasta sauce', {'weight': 6327.0}),
#  ('soy lactosefree', 'bread', {'weight': 6311.0}),
#  ('fresh fruits', 'prepared meals', {'weight': 6292.0}),
#  ('packaged cheese', 'juice nectars', {'weight': 6264.0}),
#  ('packaged vegetables fruits', 'tea', {'weight': 6253.0}),
#  ('packaged cheese', 'instant foods', {'weight': 6232.0}),
#  ('packaged vegetables fruits', 'asian foods', {'weight': 6181.0}),
#  ('packaged cheese', 'cream', {'weight': 6150.0}),
#  ('yogurt', 'butter', {'weight': 6108.0}),
#  ('yogurt', 'cookies cakes', {'weight': 6083.0}),
#  ('fresh fruits', 'doughs gelatins bake mixes', {'weight': 6076.0}),
#  ('packaged vegetables fruits', 'grains rice dried goods', {'weight': 6076.0}),
#  ('packaged cheese', 'soft drinks', {'weight': 6022.0}),
#  ('packaged vegetables fruits', 'fruit vegetable snacks', {'weight': 6021.0}),
#  ('refrigerated', 'ice cream ice', {'weight': 6005.0}),
#  ('crackers', 'bread', {'weight': 5997.0}),
#  ('bread', 'eggs', {'weight': 5985.0}),
#  ('chips pretzels', 'candy chocolate', {'weight': 5979.0}),
#  ('yogurt', 'paper goods', {'weight': 5954.0}),
#  ('water seltzer sparkling water', 'frozen produce', {'weight': 5943.0}),
#  ('fresh vegetables', 'doughs gelatins bake mixes', {'weight': 5942.0}),
#  ('chips pretzels', 'eggs', {'weight': 5940.0}),
#  ('packaged cheese', 'tortillas flat bread', {'weight': 5937.0}),
#  ('packaged produce', 'packaged produce', {'weight': 5921.0}),
#  ('soy lactosefree', 'ice cream ice', {'weight': 5906.0}),
#  ('water seltzer sparkling water', 'eggs', {'weight': 5883.0}),
#  ('fresh fruits', 'latino foods', {'weight': 5874.0}),
#  ('packaged cheese', 'nuts seeds dried fruit', {'weight': 5873.0}),
#  ('water seltzer sparkling water', 'frozen meals', {'weight': 5871.0}),
#  ('fresh vegetables', 'canned meat seafood', {'weight': 5867.0}),
#  ('packaged cheese', 'spreads', {'weight': 5865.0}),
#  ('ice cream ice', 'frozen meals', {'weight': 5828.0}),
#  ('refrigerated', 'bread', {'weight': 5803.0}),
#  ('packaged cheese', 'butter', {'weight': 5747.0}),
#  ('packaged cheese', 'baking ingredients', {'weight': 5709.0}),
#  ('milk', 'energy granola bars', {'weight': 5685.0}),
#  ('water seltzer sparkling water', 'juice nectars', {'weight': 5669.0}),
#  ('soy lactosefree', 'energy granola bars', {'weight': 5651.0}),
#  ('refrigerated', 'energy granola bars', {'weight': 5647.0}),
#  ('refrigerated', 'juice nectars', {'weight': 5628.0}),
#  ('juice nectars', 'chips pretzels', {'weight': 5624.0}),
#  ('packaged vegetables fruits', 'frozen pizza', {'weight': 5621.0}),
#  ('fresh vegetables', 'marinades meat preparation', {'weight': 5556.0}),
#  ('packaged cheese', 'breakfast bakery', {'weight': 5545.0}),
#  ('packaged vegetables fruits', 'packaged poultry', {'weight': 5522.0}),
#  ('soy lactosefree', 'eggs', {'weight': 5521.0}),
#  ('water seltzer sparkling water', 'cereal', {'weight': 5518.0}),
#  ('crackers', 'energy granola bars', {'weight': 5518.0}),
#  ('yogurt', 'frozen appetizers sides', {'weight': 5510.0}),
#  ('soup broth bouillon', 'soup broth bouillon', {'weight': 5500.0}),
#  ('yogurt', 'tea', {'weight': 5484.0}),
#  ('milk', 'frozen meals', {'weight': 5477.0}),
#  ('ice cream ice', 'bread', {'weight': 5475.0}),
#  ('packaged cheese', 'frozen breakfast', {'weight': 5458.0}),
#  ('packaged cheese', 'frozen appetizers sides', {'weight': 5446.0}),
#  ('fresh vegetables', 'granola', {'weight': 5444.0}),
#  ('packaged vegetables fruits', 'coffee', {'weight': 5436.0}),
#  ('packaged vegetables fruits',
#   'hot cereal pancake mixes',
#   {'weight': 5410.0}),
#  ('fresh fruits', 'cleaning products', {'weight': 5394.0}),
#  ('bread', 'frozen produce', {'weight': 5387.0}),
#  ('fresh fruits', 'meat counter', {'weight': 5368.0}),
#  ('crackers', 'cereal', {'weight': 5364.0}),
#  ('packaged vegetables fruits', 'poultry counter', {'weight': 5359.0}),
#  ('yogurt', 'fruit vegetable snacks', {'weight': 5332.0}),
#  ('bread', 'cereal', {'weight': 5326.0}),
#  ('soy lactosefree', 'cereal', {'weight': 5316.0}),
#  ('fresh vegetables', 'canned fruit applesauce', {'weight': 5308.0}),
#  ('water seltzer sparkling water', 'lunch meat', {'weight': 5299.0}),
#  ('water seltzer sparkling water', 'paper goods', {'weight': 5281.0}),
#  ('fresh vegetables', 'prepared meals', {'weight': 5264.0}),
#  ('soft drinks', 'soft drinks', {'weight': 5256.0}),
#  ('packaged cheese', 'condiments', {'weight': 5252.0}),
#  ('water seltzer sparkling water', 'fresh dips tapenades', {'weight': 5229.0}),
#  ('yogurt', 'tortillas flat bread', {'weight': 5201.0}),
#  ('packaged vegetables fruits', 'popcorn jerky', {'weight': 5185.0}),
#  ('packaged vegetables fruits', 'salad dressing toppings', {'weight': 5165.0}),
#  ('packaged vegetables fruits', 'tofu meat alternatives', {'weight': 5145.0}),
#  ('fresh vegetables', 'dish detergents', {'weight': 5142.0}),
#  ('hot dogs bacon sausage', 'chips pretzels', {'weight': 5127.0}),
#  ('crackers', 'crackers', {'weight': 5110.0}),
#  ('fresh fruits', 'dish detergents', {'weight': 5090.0}),
#  ('packaged cheese', 'paper goods', {'weight': 5073.0}),
#  ('refrigerated', 'frozen produce', {'weight': 5070.0}),
#  ('other creams cheeses', 'chips pretzels', {'weight': 5061.0}),
#  ('fresh vegetables', 'cleaning products', {'weight': 5046.0}),
#  ('yogurt', 'oils vinegars', {'weight': 5039.0}),
#  ('soy lactosefree', 'crackers', {'weight': 5037.0}),
#  ('crackers', 'ice cream ice', {'weight': 5001.0}),
#  ('yogurt', 'condiments', {'weight': 4978.0}),
#  ('milk', 'cream', {'weight': 4972.0}),
#  ('soup broth bouillon', 'chips pretzels', {'weight': 4959.0}),
#  ('other creams cheeses', 'milk', {'weight': 4953.0}),
#  ('lunch meat', 'crackers', {'weight': 4944.0}),
#  ('chips pretzels', 'nuts seeds dried fruit', {'weight': 4939.0}),
#  ('candy chocolate', 'candy chocolate', {'weight': 4924.0}),
#  ('bread', 'frozen meals', {'weight': 4911.0}),
#  ('milk', 'juice nectars', {'weight': 4896.0}),
#  ('refrigerated', 'crackers', {'weight': 4837.0}),
#  ('frozen produce', 'eggs', {'weight': 4837.0}),
#  ('yogurt', 'coffee', {'weight': 4820.0}),
#  ('canned jarred vegetables', 'canned meals beans', {'weight': 4803.0}),
#  ('ice cream ice', 'frozen produce', {'weight': 4794.0}),
#  ('cereal', 'cereal', {'weight': 4776.0}),
#  ('frozen produce', 'frozen meals', {'weight': 4775.0}),
#  ('fresh herbs', 'soy lactosefree', {'weight': 4763.0}),
#  ('baking ingredients', 'baking ingredients', {'weight': 4753.0}),
#  ('refrigerated', 'frozen meals', {'weight': 4752.0}),
#  ('packaged cheese', 'oils vinegars', {'weight': 4732.0}),
#  ('refrigerated', 'eggs', {'weight': 4717.0}),
#  ('packaged cheese', 'cookies cakes', {'weight': 4692.0}),
#  ('chips pretzels', 'instant foods', {'weight': 4683.0}),
#  ('yogurt', 'frozen pizza', {'weight': 4673.0}),
#  ('water seltzer sparkling water', 'candy chocolate', {'weight': 4671.0}),
#  ('crackers', 'frozen meals', {'weight': 4667.0}),
#  ('fresh fruits', 'laundry', {'weight': 4658.0}),
#  ('crackers', 'frozen produce', {'weight': 4657.0}),
#  ('crackers', 'fresh dips tapenades', {'weight': 4640.0}),
#  ('soy lactosefree', 'soy lactosefree', {'weight': 4620.0}),
#  ('fresh herbs', 'milk', {'weight': 4611.0}),
#  ('soup broth bouillon', 'frozen produce', {'weight': 4554.0}),
#  ('yogurt', 'hot cereal pancake mixes', {'weight': 4543.0}),
#  ('fresh fruits', 'frozen meat seafood', {'weight': 4542.0}),
#  ('fresh dips tapenades', 'milk', {'weight': 4531.0}),
#  ('soy lactosefree', 'fresh dips tapenades', {'weight': 4520.0}),
#  ('packaged cheese', 'spices seasonings', {'weight': 4509.0}),
#  ('packaged vegetables fruits', 'pickled goods olives', {'weight': 4493.0}),
#  ('packaged vegetables fruits', 'preserved dips spreads', {'weight': 4480.0}),
#  ('ice cream ice', 'soft drinks', {'weight': 4474.0}),
#  ('hot dogs bacon sausage', 'milk', {'weight': 4470.0}),
#  ('water seltzer sparkling water', 'tea', {'weight': 4468.0}),
#  ('fresh herbs', 'frozen produce', {'weight': 4464.0}),
#  ('fresh fruits', 'energy sports drinks', {'weight': 4450.0}),
#  ('lunch meat', 'refrigerated', {'weight': 4446.0}),
#  ('fresh vegetables', 'soap', {'weight': 4435.0}),
#  ('water seltzer sparkling water',
#   'nuts seeds dried fruit',
#   {'weight': 4435.0}),
#  ('fresh vegetables', 'honeys syrups nectars', {'weight': 4430.0}),
#  ('ice cream ice', 'cereal', {'weight': 4422.0}),
#  ('soup broth bouillon', 'frozen meals', {'weight': 4418.0}),
#  ('packaged cheese', 'frozen pizza', {'weight': 4401.0}),
#  ('milk', 'baking ingredients', {'weight': 4389.0}),
#  ('spreads', 'chips pretzels', {'weight': 4385.0}),
#  ('chips pretzels', 'frozen breakfast', {'weight': 4385.0}),
#  ('canned meat seafood', 'fresh fruits', {'weight': 4383.0}),
#  ('refrigerated', 'cereal', {'weight': 4373.0}),
#  ('lunch meat', 'soy lactosefree', {'weight': 4372.0}),
#  ('soy lactosefree', 'frozen meals', {'weight': 4371.0}),
#  ('frozen appetizers sides', 'chips pretzels', {'weight': 4365.0}),
#  ('fresh fruits', 'honeys syrups nectars', {'weight': 4356.0}),
#  ('packaged vegetables fruits', 'frozen vegan vegetarian', {'weight': 4351.0}),
#  ('fresh fruits', 'soap', {'weight': 4350.0}),
#  ('butter', 'milk', {'weight': 4331.0}),
#  ('packaged cheese', 'candy chocolate', {'weight': 4330.0}),
#  ('water seltzer sparkling water', 'cream', {'weight': 4330.0}),
#  ('bread', 'energy granola bars', {'weight': 4329.0}),
#  ('water seltzer sparkling water', 'soup broth bouillon', {'weight': 4294.0}),
#  ('yogurt', 'popcorn jerky', {'weight': 4282.0}),
#  ('fresh vegetables', 'laundry', {'weight': 4273.0}),
#  ('chips pretzels', 'breakfast bakery', {'weight': 4269.0}),
#  ('chips pretzels', 'dry pasta', {'weight': 4268.0}),
#  ('frozen breakfast', 'frozen meals', {'weight': 4265.0}),
#  ('fresh fruits', 'prepared soups salads', {'weight': 4242.0}),
#  ('canned meals beans', 'chips pretzels', {'weight': 4225.0}),
#  ('milk', 'soup broth bouillon', {'weight': 4224.0}),
#  ('milk', 'soft drinks', {'weight': 4223.0}),
#  ('fresh herbs', 'fresh herbs', {'weight': 4214.0}),
#  ('lunch meat', 'ice cream ice', {'weight': 4200.0}),
#  ('fresh herbs', 'canned jarred vegetables', {'weight': 4200.0}),
#  ('paper goods', 'chips pretzels', {'weight': 4194.0}),
#  ('canned meals beans', 'frozen produce', {'weight': 4184.0}),
#  ('water seltzer sparkling water', 'fresh herbs', {'weight': 4174.0}),
#  ('tea', 'tea', {'weight': 4167.0}),
#  ('chips pretzels', 'fruit vegetable snacks', {'weight': 4161.0}),
#  ('water seltzer sparkling water', 'baby food formula', {'weight': 4156.0}),
#  ('milk', 'dry pasta', {'weight': 4149.0}),
#  ('yogurt', 'spices seasonings', {'weight': 4143.0}),
#  ('bread', 'spreads', {'weight': 4139.0}),
#  ('yogurt', 'granola', {'weight': 4131.0}),
#  ('pasta sauce', 'dry pasta', {'weight': 4122.0}),
#  ('soy lactosefree', 'soup broth bouillon', {'weight': 4119.0}),
#  ('energy granola bars', 'cereal', {'weight': 4115.0}),
#  ('energy granola bars', 'frozen meals', {'weight': 4111.0}),
#  ('canned jarred vegetables', 'frozen produce', {'weight': 4104.0}),
#  ('lunch meat', 'eggs', {'weight': 4092.0}),
#  ('soy lactosefree', 'spreads', {'weight': 4063.0}),
#  ('lunch meat', 'frozen produce', {'weight': 4057.0}),
#  ('crackers', 'cookies cakes', {'weight': 4054.0}),
#  ('fresh dips tapenades', 'bread', {'weight': 4050.0}),
#  ('frozen produce', 'energy granola bars', {'weight': 4042.0}),
#  ('ice cream ice', 'eggs', {'weight': 4027.0}),
#  ('milk', 'spreads', {'weight': 4023.0}),
#  ('milk', 'instant foods', {'weight': 4011.0}),
#  ('cream', 'chips pretzels', {'weight': 3975.0}),
#  ('canned jarred vegetables', 'soup broth bouillon', {'weight': 3973.0}),
#  ('fresh vegetables', 'frozen meat seafood', {'weight': 3962.0}),
#  ('fresh dips tapenades', 'frozen produce', {'weight': 3961.0}),
#  ('hot dogs bacon sausage', 'bread', {'weight': 3944.0}),
#  ('popcorn jerky', 'chips pretzels', {'weight': 3942.0}),
#  ('water seltzer sparkling water', 'spreads', {'weight': 3934.0}),
#  ('lunch meat', 'frozen meals', {'weight': 3923.0}),
#  ('soy lactosefree', 'nuts seeds dried fruit', {'weight': 3917.0}),
#  ('yogurt', 'packaged produce', {'weight': 3916.0}),
#  ('packaged vegetables fruits', 'buns rolls', {'weight': 3916.0}),
#  ('frozen meals', 'cereal', {'weight': 3916.0}),
#  ('milk', 'frozen breakfast', {'weight': 3913.0}),
#  ('frozen pizza', 'frozen meals', {'weight': 3908.0}),
#  ('other creams cheeses', 'bread', {'weight': 3896.0}),
#  ('ice cream ice', 'energy granola bars', {'weight': 3886.0}),
#  ('frozen produce', 'baby food formula', {'weight': 3883.0}),
#  ('packaged cheese', 'missing', {'weight': 3881.0}),
#  ('crackers', 'eggs', {'weight': 3870.0}),
#  ('chips pretzels', 'baby food formula', {'weight': 3869.0}),
#  ('canned jarred vegetables', 'milk', {'weight': 3862.0}),
#  ('soy lactosefree', 'baking ingredients', {'weight': 3860.0}),
#  ('ice cream ice', 'juice nectars', {'weight': 3855.0}),
#  ('crackers', 'baby food formula', {'weight': 3843.0}),
#  ('refrigerated', 'soft drinks', {'weight': 3833.0}),
#  ('frozen produce', 'cereal', {'weight': 3833.0}),
#  ('refrigerated', 'soup broth bouillon', {'weight': 3829.0}),
#  ('packaged cheese', 'packaged produce', {'weight': 3824.0}),
#  ('refrigerated', 'fresh dips tapenades', {'weight': 3820.0}),
#  ('soup broth bouillon', 'bread', {'weight': 3817.0}),
#  ('water seltzer sparkling water',
#   'hot dogs bacon sausage',
#   {'weight': 3805.0}),
#  ('crackers', 'soft drinks', {'weight': 3799.0}),
#  ('soft drinks', 'frozen meals', {'weight': 3794.0}),
#  ('water seltzer sparkling water', 'coffee', {'weight': 3779.0}),
#  ('other creams cheeses', 'water seltzer sparkling water', {'weight': 3768.0}),
#  ('cat food care', 'cat food care', {'weight': 3759.0}),
#  ('fresh fruits', 'breakfast bars pastries', {'weight': 3758.0}),
#  ('packaged cheese', 'fruit vegetable snacks', {'weight': 3738.0}),
#  ('canned jarred vegetables', 'chips pretzels', {'weight': 3738.0}),
#  ('fresh herbs', 'chips pretzels', {'weight': 3736.0}),
#  ('milk', 'nuts seeds dried fruit', {'weight': 3729.0}),
#  ('energy granola bars', 'candy chocolate', {'weight': 3724.0}),
#  ('yogurt', 'grains rice dried goods', {'weight': 3710.0}),
#  ('preserved dips spreads', 'chips pretzels', {'weight': 3710.0}),
#  ('crackers', 'soup broth bouillon', {'weight': 3708.0}),
#  ('soy lactosefree', 'canned meals beans', {'weight': 3701.0}),
#  ('yogurt', 'asian foods', {'weight': 3699.0}),
#  ('fresh fruits', 'marinades meat preparation', {'weight': 3699.0}),
#  ('juice nectars', 'bread', {'weight': 3698.0}),
#  ('chips pretzels', 'frozen pizza', {'weight': 3695.0}),
#  ('soy lactosefree', 'juice nectars', {'weight': 3686.0}),
#  ('bread', 'dry pasta', {'weight': 3685.0}),
#  ('lunch meat', 'hot dogs bacon sausage', {'weight': 3675.0}),
#  ('fresh herbs', 'spices seasonings', {'weight': 3669.0}),
#  ('frozen appetizers sides', 'frozen meals', {'weight': 3669.0}),
#  ('energy granola bars', 'nuts seeds dried fruit', {'weight': 3665.0}),
#  ('milk', 'breakfast bakery', {'weight': 3662.0}),
#  ('chips pretzels', 'tea', {'weight': 3638.0}),
#  ('condiments', 'chips pretzels', {'weight': 3634.0}),
#  ('canned meals beans', 'milk', {'weight': 3627.0}),
#  ('soy lactosefree', 'baby food formula', {'weight': 3622.0}),
#  ('frozen produce', 'nuts seeds dried fruit', {'weight': 3619.0}),
#  ('milk', 'milk', {'weight': 3618.0}),
#  ('fresh vegetables', 'prepared soups salads', {'weight': 3597.0}),
#  ('canned meals beans', 'soup broth bouillon', {'weight': 3590.0}),
#  ('fresh herbs', 'eggs', {'weight': 3589.0}),
#  ('spreads', 'frozen produce', {'weight': 3581.0}),
#  ('packaged vegetables fruits', 'prepared meals', {'weight': 3569.0}),
#  ('hot dogs bacon sausage', 'eggs', {'weight': 3567.0}),
#  ('chips pretzels', 'pasta sauce', {'weight': 3550.0}),
#  ('specialty cheeses', 'packaged vegetables fruits', {'weight': 3546.0}),
#  ('bread', 'baby food formula', {'weight': 3544.0}),
#  ('fresh herbs', 'bread', {'weight': 3540.0}),
#  ('baking ingredients', 'chips pretzels', {'weight': 3538.0}),
#  ('lunch meat', 'cereal', {'weight': 3526.0}),
#  ('crackers', 'nuts seeds dried fruit', {'weight': 3520.0}),
#  ('lunch meat', 'energy granola bars', {'weight': 3513.0}),
#  ('milk', 'cookies cakes', {'weight': 3511.0}),
#  ('ice cream ice', 'soup broth bouillon', {'weight': 3499.0}),
#  ('crackers', 'juice nectars', {'weight': 3497.0}),
#  ('fresh herbs', 'soup broth bouillon', {'weight': 3493.0}),
#  ('water seltzer sparkling water', 'cookies cakes', {'weight': 3468.0}),
#  ('frozen meals', 'eggs', {'weight': 3446.0}),
#  ('fresh dips tapenades', 'ice cream ice', {'weight': 3445.0}),
#  ('canned jarred vegetables', 'soy lactosefree', {'weight': 3444.0}),
#  ('yogurt', 'canned fruit applesauce', {'weight': 3436.0}),
#  ('baking ingredients', 'frozen produce', {'weight': 3433.0}),
#  ('milk', 'pasta sauce', {'weight': 3431.0}),
#  ('lunch meat', 'fresh dips tapenades', {'weight': 3426.0}),
#  ('packaged vegetables fruits',
#   'doughs gelatins bake mixes',
#   {'weight': 3417.0}),
#  ('water seltzer sparkling water',
#   'canned jarred vegetables',
#   {'weight': 3415.0}),
#  ('packaged cheese', 'tea', {'weight': 3410.0}),
#  ('bread', 'breakfast bakery', {'weight': 3410.0}),
#  ('frozen produce', 'dry pasta', {'weight': 3410.0}),
#  ('butter', 'chips pretzels', {'weight': 3405.0}),
#  ('other creams cheeses', 'ice cream ice', {'weight': 3402.0}),
#  ('milk', 'paper goods', {'weight': 3396.0}),
#  ('water seltzer sparkling water', 'breakfast bakery', {'weight': 3395.0}),
#  ('packaged cheese', 'coffee', {'weight': 3391.0}),
#  ('refrigerated', 'tea', {'weight': 3390.0}),
#  ('tortillas flat bread', 'chips pretzels', {'weight': 3382.0}),
#  ('crackers', 'spreads', {'weight': 3377.0}),
#  ('packaged vegetables fruits', 'granola', {'weight': 3376.0}),
#  ('yogurt', 'packaged poultry', {'weight': 3372.0}),
#  ('ice cream ice', 'cookies cakes', {'weight': 3372.0}),
#  ('bread', 'soft drinks', {'weight': 3358.0}),
#  ('instant foods', 'frozen meals', {'weight': 3358.0}),
#  ('packaged vegetables fruits', 'canned fruit applesauce', {'weight': 3354.0}),
#  ('fresh fruits', 'oral hygiene', {'weight': 3350.0}),
#  ('fresh vegetables', 'food storage', {'weight': 3347.0}),
#  ('juice nectars', 'frozen produce', {'weight': 3329.0}),
#  ('water seltzer sparkling water', 'baking ingredients', {'weight': 3328.0}),
#  ('packaged vegetables fruits', 'latino foods', {'weight': 3321.0}),
#  ('other creams cheeses', 'crackers', {'weight': 3319.0}),
#  ('fresh vegetables', 'oral hygiene', {'weight': 3317.0}),
#  ('canned meals beans', 'bread', {'weight': 3302.0}),
#  ('frozen appetizers sides', 'milk', {'weight': 3290.0}),
#  ('refrigerated', 'hot dogs bacon sausage', {'weight': 3289.0}),
#  ('canned jarred vegetables', 'canned jarred vegetables', {'weight': 3280.0}),
#  ('hot dogs bacon sausage', 'frozen produce', {'weight': 3276.0}),
#  ('cereal', 'eggs', {'weight': 3275.0}),
#  ('bread', 'instant foods', {'weight': 3254.0}),
#  ('lunch meat', 'lunch meat', {'weight': 3246.0}),
#  ('butter', 'bread', {'weight': 3246.0}),
#  ('bread', 'frozen breakfast', {'weight': 3240.0}),
#  ('fresh vegetables', 'energy sports drinks', {'weight': 3236.0}),
#  ('energy granola bars', 'eggs', {'weight': 3232.0}),
#  ('packaged cheese', 'preserved dips spreads', {'weight': 3224.0}),
#  ('juice nectars', 'soft drinks', {'weight': 3220.0}),
#  ('fresh herbs', 'refrigerated', {'weight': 3219.0}),
#  ('water seltzer sparkling water', 'dry pasta', {'weight': 3210.0}),
#  ('fresh dips tapenades', 'eggs', {'weight': 3209.0}),
#  ('soy lactosefree', 'dry pasta', {'weight': 3204.0}),
#  ('bread', 'cream', {'weight': 3195.0}),
#  ('crackers', 'instant foods', {'weight': 3190.0}),
#  ('milk', 'packaged produce', {'weight': 3190.0}),
#  ('fresh dips tapenades', 'energy granola bars', {'weight': 3187.0}),
#  ('water seltzer sparkling water', 'canned meals beans', {'weight': 3185.0}),
#  ('fresh dips tapenades', 'frozen meals', {'weight': 3176.0}),
#  ('packaged cheese', 'asian foods', {'weight': 3175.0}),
#  ('crackers', 'hot dogs bacon sausage', {'weight': 3175.0}),
#  ('soup broth bouillon', 'eggs', {'weight': 3158.0}),
#  ('crackers', 'candy chocolate', {'weight': 3154.0}),
#  ('other creams cheeses', 'frozen produce', {'weight': 3151.0}),
#  ('other creams cheeses', 'eggs', {'weight': 3146.0}),
#  ('refrigerated', 'nuts seeds dried fruit', {'weight': 3145.0}),
#  ('chips pretzels', 'coffee', {'weight': 3143.0}),
#  ('crackers', 'frozen breakfast', {'weight': 3135.0}),
#  ('packaged cheese', 'pickled goods olives', {'weight': 3132.0}),
#  ('packaged cheese', 'popcorn jerky', {'weight': 3131.0}),
#  ('ice cream ice', 'candy chocolate', {'weight': 3131.0}),
#  ('soy lactosefree', 'cream', {'weight': 3130.0}),
#  ('canned jarred vegetables', 'dry pasta', {'weight': 3117.0}),
#  ('cleaning products', 'cleaning products', {'weight': 3111.0}),
#  ('baking ingredients', 'eggs', {'weight': 3108.0}),
#  ('water seltzer sparkling water', 'missing', {'weight': 3101.0}),
#  ('fresh herbs', 'canned meals beans', {'weight': 3099.0}),
#  ('packaged cheese', 'hot cereal pancake mixes', {'weight': 3097.0}),
#  ('butter', 'baking ingredients', {'weight': 3096.0}),
#  ('canned jarred vegetables', 'bread', {'weight': 3089.0}),
#  ('juice nectars', 'frozen meals', {'weight': 3083.0}),
#  ('water seltzer sparkling water', 'frozen breakfast', {'weight': 3073.0}),
#  ('milk', 'candy chocolate', {'weight': 3070.0}),
#  ('oils vinegars', 'soy lactosefree', {'weight': 3066.0}),
#  ('fresh fruits', 'food storage', {'weight': 3058.0}),
#  ('packaged cheese', 'packaged poultry', {'weight': 3052.0}),
#  ('water seltzer sparkling water', 'condiments', {'weight': 3042.0}),
#  ('hot dogs bacon sausage', 'frozen meals', {'weight': 3039.0}),
#  ('hot dogs bacon sausage', 'ice cream ice', {'weight': 3038.0}),
#  ('fresh herbs', 'baking ingredients', {'weight': 3028.0}),
#  ('energy granola bars', 'fruit vegetable snacks', {'weight': 3027.0}),
#  ('yogurt', 'poultry counter', {'weight': 3023.0}),
#  ('packaged cheese', 'salad dressing toppings', {'weight': 3023.0}),
#  ('refrigerated', 'candy chocolate', {'weight': 3015.0}),
#  ('packaged cheese', 'buns rolls', {'weight': 3014.0}),
#  ('bread', 'pasta sauce', {'weight': 3014.0}),
#  ('spreads', 'energy granola bars', {'weight': 3000.0}),
#  ('frozen produce', 'instant foods', {'weight': 2990.0}),
#  ('lunch meat', 'soup broth bouillon', {'weight': 2987.0}),
#  ('paper goods', 'soft drinks', {'weight': 2986.0}),
#  ('packaged vegetables fruits', 'cleaning products', {'weight': 2985.0}),
#  ('other creams cheeses', 'lunch meat', {'weight': 2984.0}),
#  ('ice cream ice', 'instant foods', {'weight': 2973.0}),
#  ('water seltzer sparkling water', 'oils vinegars', {'weight': 2970.0}),
#  ('other creams cheeses', 'soy lactosefree', {'weight': 2969.0}),
#  ('paper goods', 'cleaning products', {'weight': 2967.0}),
#  ('soy lactosefree', 'hot dogs bacon sausage', {'weight': 2964.0}),
#  ('water seltzer sparkling water', 'butter', {'weight': 2962.0}),
#  ('fresh vegetables', 'packaged meat', {'weight': 2958.0}),
#  ('yogurt', 'preserved dips spreads', {'weight': 2953.0}),
#  ('other creams cheeses', 'refrigerated', {'weight': 2948.0}),
#  ('paper goods', 'paper goods', {'weight': 2939.0}),
#  ('oils vinegars', 'frozen produce', {'weight': 2938.0}),
#  ('frozen produce', 'pasta sauce', {'weight': 2936.0}),
#  ('yogurt', 'tofu meat alternatives', {'weight': 2934.0}),
#  ('water seltzer sparkling water', 'instant foods', {'weight': 2928.0}),
#  ('milk', 'tortillas flat bread', {'weight': 2913.0}),
#  ('instant foods', 'instant foods', {'weight': 2912.0}),
#  ('crackers', 'dry pasta', {'weight': 2909.0}),
#  ('water seltzer sparkling water', 'packaged produce', {'weight': 2908.0}),
#  ('packaged vegetables fruits', 'meat counter', {'weight': 2907.0}),
#  ('water seltzer sparkling water', 'popcorn jerky', {'weight': 2896.0}),
#  ('canned jarred vegetables', 'eggs', {'weight': 2896.0}),
#  ('missing', 'chips pretzels', {'weight': 2894.0}),
#  ('yogurt', 'buns rolls', {'weight': 2891.0}),
#  ('condiments', 'bread', {'weight': 2891.0}),
#  ('packaged cheese', 'grains rice dried goods', {'weight': 2889.0}),
#  ('bread', 'nuts seeds dried fruit', {'weight': 2884.0}),
#  ('ice cream ice', 'paper goods', {'weight': 2879.0}),
#  ('lunch meat', 'juice nectars', {'weight': 2878.0}),
#  ('ice cream ice', 'baking ingredients', {'weight': 2877.0}),
#  ('water seltzer sparkling water', 'pasta sauce', {'weight': 2870.0}),
#  ('soy lactosefree', 'candy chocolate', {'weight': 2870.0}),
#  ('other creams cheeses', 'breakfast bakery', {'weight': 2867.0}),
#  ('bread', 'cookies cakes', {'weight': 2865.0}),
#  ('refrigerated', 'baby food formula', {'weight': 2854.0}),
#  ('crackers', 'paper goods', {'weight': 2854.0}),
#  ('oils vinegars', 'milk', {'weight': 2852.0}),
#  ('soy lactosefree', 'condiments', {'weight': 2842.0}),
#  ('frozen produce', 'frozen breakfast', {'weight': 2840.0}),
#  ('spices seasonings', 'spices seasonings', {'weight': 2839.0}),
#  ('oils vinegars', 'fresh herbs', {'weight': 2825.0}),
#  ('ice cream ice', 'cream', {'weight': 2825.0}),
#  ('paper goods', 'bread', {'weight': 2820.0}),
#  ('soy lactosefree', 'frozen breakfast', {'weight': 2818.0}),
#  ('refrigerated', 'frozen breakfast', {'weight': 2813.0}),
#  ('baking ingredients', 'bread', {'weight': 2811.0}),
#  ('fresh vegetables', 'seafood counter', {'weight': 2810.0}),
#  ('energy granola bars', 'baby food formula', {'weight': 2805.0}),
#  ('refrigerated', 'spreads', {'weight': 2803.0}),
#  ('spreads', 'cereal', {'weight': 2802.0}),
#  ('oils vinegars', 'chips pretzels', {'weight': 2795.0}),
#  ('milk', 'condiments', {'weight': 2794.0}),
#  ('packaged cheese', 'doughs gelatins bake mixes', {'weight': 2790.0}),
#  ('ice cream ice', 'missing', {'weight': 2787.0}),
#  ('juice nectars', 'cereal', {'weight': 2787.0}),
#  ('juice nectars', 'eggs', {'weight': 2785.0}),
#  ('tortillas flat bread', 'bread', {'weight': 2784.0}),
#  ('yogurt', 'doughs gelatins bake mixes', {'weight': 2783.0}),
#  ('crackers', 'breakfast bakery', {'weight': 2783.0}),
#  ('butter', 'eggs', {'weight': 2783.0}),
#  ('canned jarred vegetables', 'spices seasonings', {'weight': 2782.0}),
#  ('canned meals beans', 'frozen meals', {'weight': 2779.0}),
#  ('soft drinks', 'candy chocolate', {'weight': 2776.0}),
#  ('ice cream ice', 'frozen breakfast', {'weight': 2774.0}),
#  ('cream', 'eggs', {'weight': 2774.0}),
#  ('canned meat seafood', 'packaged vegetables fruits', {'weight': 2766.0}),
#  ('soy lactosefree', 'missing', {'weight': 2763.0}),
#  ('soy lactosefree', 'tea', {'weight': 2761.0}),
#  ('energy granola bars', 'cookies cakes', {'weight': 2758.0}),
#  ('soy lactosefree', 'pasta sauce', {'weight': 2747.0}),
#  ('fresh fruits', 'vitamins supplements', {'weight': 2746.0}),
#  ('water seltzer sparkling water',
#   'fruit vegetable snacks',
#   {'weight': 2745.0}),
#  ('eggs', 'baby food formula', {'weight': 2741.0}),
#  ('fresh dips tapenades', 'cereal', {'weight': 2736.0}),
#  ('baking ingredients', 'spices seasonings', {'weight': 2735.0}),
#  ('refrigerated', 'paper goods', {'weight': 2731.0}),
#  ('soft drinks', 'cookies cakes', {'weight': 2728.0}),
#  ('soup broth bouillon', 'instant foods', {'weight': 2724.0}),
#  ('butter', 'frozen produce', {'weight': 2721.0}),
#  ('cookies cakes', 'cereal', {'weight': 2719.0}),
#  ('cereal', 'baby food formula', {'weight': 2718.0}),
#  ('soft drinks', 'cereal', {'weight': 2708.0}),
#  ('cookies cakes', 'frozen meals', {'weight': 2707.0}),
#  ('fresh vegetables', 'frozen breads doughs', {'weight': 2705.0}),
#  ('frozen appetizers sides', 'ice cream ice', {'weight': 2704.0}),
#  ('frozen meals', 'baby food formula', {'weight': 2704.0}),
#  ('paper goods', 'frozen meals', {'weight': 2701.0}),
#  ('ice cream ice', 'dry pasta', {'weight': 2698.0}),
#  ('packaged cheese', 'tofu meat alternatives', {'weight': 2697.0}),
#  ('milk', 'frozen pizza', {'weight': 2694.0}),
#  ('fresh herbs', 'ice cream ice', {'weight': 2691.0}),
#  ('other creams cheeses', 'frozen meals', {'weight': 2690.0}),
#  ('packaged vegetables fruits', 'frozen meat seafood', {'weight': 2690.0}),
#  ('oils vinegars', 'baking ingredients', {'weight': 2676.0}),
#  ('crackers', 'canned meals beans', {'weight': 2664.0}),
#  ('soup broth bouillon', 'dry pasta', {'weight': 2661.0}),
#  ('packaged vegetables fruits', 'laundry', {'weight': 2657.0}),
#  ('canned meals beans', 'canned meals beans', {'weight': 2654.0}),
#  ('juice nectars', 'energy granola bars', {'weight': 2651.0}),
#  ('refrigerated', 'breakfast bakery', {'weight': 2650.0}),
#  ('ice cream ice', 'spreads', {'weight': 2650.0}),
#  ('instant foods', 'cereal', {'weight': 2650.0}),
#  ('fresh vegetables', 'vitamins supplements', {'weight': 2647.0}),
#  ('milk', 'fruit vegetable snacks', {'weight': 2644.0}),
#  ('milk', 'tea', {'weight': 2639.0}),
#  ('packaged cheese', 'poultry counter', {'weight': 2638.0}),
#  ('dry pasta', 'cereal', {'weight': 2635.0}),
#  ('refrigerated', 'cookies cakes', {'weight': 2631.0}),
#  ('packaged vegetables fruits', 'dish detergents', {'weight': 2627.0}),
#  ('frozen breakfast', 'cereal', {'weight': 2620.0}),
#  ('refrigerated', 'cream', {'weight': 2616.0}),
#  ('soup broth bouillon', 'cereal', {'weight': 2608.0}),
#  ('chips pretzels', 'packaged produce', {'weight': 2608.0}),
#  ('frozen appetizers sides', 'bread', {'weight': 2607.0}),
#  ('crackers', 'fruit vegetable snacks', {'weight': 2606.0}),
#  ('soy lactosefree', 'breakfast bakery', {'weight': 2603.0}),
#  ('packaged cheese', 'specialty cheeses', {'weight': 2598.0}),
#  ('canned meals beans', 'eggs', {'weight': 2598.0}),
#  ('yogurt', 'pickled goods olives', {'weight': 2593.0}),
#  ('energy granola bars', 'soft drinks', {'weight': 2592.0}),
#  ('dry pasta', 'eggs', {'weight': 2591.0}),
#  ('spices seasonings', 'frozen produce', {'weight': 2589.0}),
#  ('frozen appetizers sides', 'frozen produce', {'weight': 2587.0}),
#  ('crackers', 'frozen appetizers sides', {'weight': 2583.0}),
#  ('condiments', 'frozen produce', {'weight': 2577.0}),
#  ('cookies cakes', 'cookies cakes', {'weight': 2574.0}),
#  ('paper goods', 'cereal', {'weight': 2571.0}),
#  ('lunch meat', 'baby food formula', {'weight': 2570.0}),
#  ('hot dogs bacon sausage', 'cereal', {'weight': 2568.0}),
#  ('other creams cheeses', 'fresh herbs', {'weight': 2567.0}),
#  ('fresh vegetables', 'other', {'weight': 2566.0}),
#  ('spreads', 'eggs', {'weight': 2565.0}),
#  ('refrigerated', 'instant foods', {'weight': 2563.0}),
#  ('yogurt', 'frozen vegan vegetarian', {'weight': 2562.0}),
#  ('yogurt', 'energy sports drinks', {'weight': 2561.0}),
#  ('fresh vegetables', 'fresh pasta', {'weight': 2556.0}),
#  ('energy granola bars', 'tea', {'weight': 2553.0}),
#  ('lunch meat', 'instant foods', {'weight': 2544.0}),
#  ('juice nectars', 'juice nectars', {'weight': 2541.0}),
#  ('lunch meat', 'soft drinks', {'weight': 2537.0}),
#  ('cream', 'frozen produce', {'weight': 2536.0}),
#  ('frozen breakfast', 'baby food formula', {'weight': 2536.0}),
#  ('soy lactosefree', 'paper goods', {'weight': 2531.0}),
#  ('butter', 'ice cream ice', {'weight': 2531.0}),
#  ('packaged cheese', 'frozen vegan vegetarian', {'weight': 2530.0}),
#  ('crackers', 'cream', {'weight': 2529.0}),
#  ('fresh fruits', 'frozen breads doughs', {'weight': 2528.0}),
#  ('fresh herbs', 'dry pasta', {'weight': 2528.0}),
#  ('other creams cheeses', 'cereal', {'weight': 2524.0}),
#  ('cereal', 'breakfast bakery', {'weight': 2524.0}),
#  ('refrigerated', 'baking ingredients', {'weight': 2519.0}),
#  ('ice cream ice', 'breakfast bakery', {'weight': 2518.0}),
#  ('nuts seeds dried fruit', 'nuts seeds dried fruit', {'weight': 2510.0}),
#  ('packaged cheese', 'latino foods', {'weight': 2509.0}),
#  ('fresh vegetables', 'breakfast bars pastries', {'weight': 2508.0}),
#  ('milk', 'coffee', {'weight': 2508.0}),
#  ('nuts seeds dried fruit', 'candy chocolate', {'weight': 2506.0}),
#  ('spices seasonings', 'chips pretzels', {'weight': 2503.0}),
#  ('refrigerated', 'dry pasta', {'weight': 2496.0}),
#  ('missing', 'energy granola bars', {'weight': 2496.0}),
#  ('fresh fruits', 'fresh pasta', {'weight': 2494.0}),
#  ('water seltzer sparkling water', 'frozen pizza', {'weight': 2494.0}),
#  ('milk', 'missing', {'weight': 2493.0}),
#  ('lunch meat', 'frozen breakfast', {'weight': 2490.0}),
#  ('ice cream ice', 'frozen pizza', {'weight': 2478.0}),
#  ('yogurt', 'cleaning products', {'weight': 2477.0}),
#  ('soy lactosefree', 'butter', {'weight': 2477.0}),
#  ('frozen produce', 'packaged produce', {'weight': 2476.0}),
#  ('packaged cheese', 'canned fruit applesauce', {'weight': 2475.0}),
#  ('packaged vegetables fruits', 'energy sports drinks', {'weight': 2475.0}),
#  ('water seltzer sparkling water',
#   'frozen appetizers sides',
#   {'weight': 2473.0}),
#  ('soy lactosefree', 'tofu meat alternatives', {'weight': 2468.0}),
#  ('ice cream ice', 'nuts seeds dried fruit', {'weight': 2465.0}),
#  ('yogurt', 'prepared meals', {'weight': 2462.0}),
#  ('packaged vegetables fruits', 'prepared soups salads', {'weight': 2462.0}),
#  ('lunch meat', 'spreads', {'weight': 2461.0}),
#  ('crackers', 'baking ingredients', {'weight': 2459.0}),
#  ('fresh dips tapenades', 'canned meals beans', {'weight': 2458.0}),
#  ('cereal', 'nuts seeds dried fruit', {'weight': 2458.0}),
#  ('hot dogs bacon sausage', 'soup broth bouillon', {'weight': 2457.0}),
#  ('milk', 'spices seasonings', {'weight': 2457.0}),
#  ('paper goods', 'eggs', {'weight': 2457.0}),
#  ('other creams cheeses', 'canned jarred vegetables', {'weight': 2455.0}),
#  ('soy lactosefree', 'spices seasonings', {'weight': 2452.0}),
#  ('refrigerated', 'canned meals beans', {'weight': 2451.0}),
#  ('bread', 'frozen pizza', {'weight': 2451.0}),
#  ('refrigerated', 'canned jarred vegetables', {'weight': 2450.0}),
#  ('lunch meat', 'fresh herbs', {'weight': 2448.0}),
#  ('refrigerated', 'missing', {'weight': 2446.0}),
#  ('soup broth bouillon', 'juice nectars', {'weight': 2437.0}),
#  ('yogurt', 'breakfast bars pastries', {'weight': 2434.0}),
#  ('bread', 'candy chocolate', {'weight': 2429.0}),
#  ('other creams cheeses', 'soup broth bouillon', {'weight': 2428.0}),
#  ('spreads', 'frozen meals', {'weight': 2426.0}),
#  ('water seltzer sparkling water', 'spices seasonings', {'weight': 2425.0}),
#  ('packaged vegetables fruits',
#   'marinades meat preparation',
#   {'weight': 2421.0}),
#  ('yogurt', 'salad dressing toppings', {'weight': 2417.0}),
#  ('fresh dips tapenades', 'soup broth bouillon', {'weight': 2414.0}),
#  ('refrigerated', 'coffee', {'weight': 2413.0}),
#  ('lunch meat', 'cream', {'weight': 2408.0}),
#  ('ice cream ice', 'pasta sauce', {'weight': 2404.0}),
#  ('baking ingredients', 'nuts seeds dried fruit', {'weight': 2403.0}),
#  ('soup broth bouillon', 'energy granola bars', {'weight': 2402.0}),
#  ('chips pretzels', 'buns rolls', {'weight': 2402.0}),
#  ('soy lactosefree', 'soft drinks', {'weight': 2401.0}),
#  ('ice cream ice', 'baby food formula', {'weight': 2401.0}),
#  ('packaged vegetables fruits', 'soap', {'weight': 2392.0}),
#  ('lunch meat', 'breakfast bakery', {'weight': 2391.0}),
#  ('refrigerated', 'frozen appetizers sides', {'weight': 2388.0}),
#  ('other creams cheeses', 'baking ingredients', {'weight': 2386.0}),
#  ('energy granola bars', 'frozen breakfast', {'weight': 2382.0}),
#  ('baking ingredients', 'cream', {'weight': 2377.0}),
#  ('bread', 'bread', {'weight': 2373.0}),
#  ('canned meals beans', 'ice cream ice', {'weight': 2371.0}),
#  ('water seltzer sparkling water', 'tortillas flat bread', {'weight': 2362.0}),
#  ('asian foods', 'chips pretzels', {'weight': 2360.0}),
#  ('refrigerated', 'pasta sauce', {'weight': 2358.0}),
#  ('eggs', 'nuts seeds dried fruit', {'weight': 2354.0}),
#  ('crackers', 'popcorn jerky', {'weight': 2353.0}),
#  ('missing', 'baby food formula', {'weight': 2351.0}),
#  ('pasta sauce', 'eggs', {'weight': 2351.0}),
#  ('breakfast bakery', 'eggs', {'weight': 2350.0}),
#  ('lunch meat', 'dry pasta', {'weight': 2344.0}),
#  ('fresh fruits', 'other', {'weight': 2331.0}),
#  ('cookies cakes', 'candy chocolate', {'weight': 2330.0}),
#  ('refrigerated', 'butter', {'weight': 2329.0}),
#  ('fresh herbs', 'nuts seeds dried fruit', {'weight': 2323.0}),
#  ('popcorn jerky', 'energy granola bars', {'weight': 2320.0}),
#  ('frozen produce', 'soft drinks', {'weight': 2320.0}),
#  ('baking ingredients', 'soup broth bouillon', {'weight': 2317.0}),
#  ('refrigerated', 'condiments', {'weight': 2316.0}),
#  ('fresh herbs', 'fresh dips tapenades', {'weight': 2315.0}),
#  ('frozen meals', 'candy chocolate', {'weight': 2314.0}),
#  ('canned jarred vegetables', 'ice cream ice', {'weight': 2310.0}),
#  ('canned jarred vegetables', 'baking ingredients', {'weight': 2310.0}),
#  ('soft drinks', 'eggs', {'weight': 2303.0}),
#  ('canned jarred vegetables', 'crackers', {'weight': 2302.0}),
#  ('crackers', 'pasta sauce', {'weight': 2291.0}),
#  ('lunch meat', 'condiments', {'weight': 2290.0}),
#  ('fresh herbs', 'crackers', {'weight': 2290.0}),
#  ('soy lactosefree', 'tortillas flat bread', {'weight': 2290.0}),
#  ('lunch meat', 'pasta sauce', {'weight': 2289.0}),
#  ('oils vinegars', 'bread', {'weight': 2283.0}),
#  ('soy lactosefree', 'instant foods', {'weight': 2283.0}),
#  ('soy lactosefree', 'asian foods', {'weight': 2281.0}),
#  ('fresh dips tapenades', 'juice nectars', {'weight': 2281.0}),
#  ('crackers', 'tortillas flat bread', {'weight': 2278.0}),
#  ('frozen meals', 'breakfast bakery', {'weight': 2278.0}),
#  ('milk', 'hot cereal pancake mixes', {'weight': 2276.0}),
#  ('soup broth bouillon', 'soft drinks', {'weight': 2276.0}),
#  ('pasta sauce', 'frozen meals', {'weight': 2276.0}),
#  ('oils vinegars', 'eggs', {'weight': 2275.0}),
#  ('yogurt', 'specialty cheeses', {'weight': 2272.0}),
#  ('missing', 'frozen produce', {'weight': 2269.0}),
#  ('canned meals beans', 'cereal', {'weight': 2267.0}),
#  ('baking ingredients', 'cereal', {'weight': 2264.0}),
#  ('instant foods', 'eggs', {'weight': 2264.0}),
#  ('soup broth bouillon', 'spices seasonings', {'weight': 2263.0}),
#  ('other creams cheeses', 'hot dogs bacon sausage', {'weight': 2259.0}),
#  ('bread', 'coffee', {'weight': 2259.0}),
#  ('oils vinegars', 'spices seasonings', {'weight': 2256.0}),
#  ('cream', 'energy granola bars', {'weight': 2256.0}),
#  ('other creams cheeses', 'cream', {'weight': 2254.0}),
#  ('other creams cheeses', 'fresh dips tapenades', {'weight': 2248.0}),
#  ('lunch meat', 'butter', {'weight': 2246.0}),
#  ('fresh dips tapenades', 'baby food formula', {'weight': 2245.0}),
#  ('ice cream ice', 'condiments', {'weight': 2244.0}),
#  ('fresh fruits', 'refrigerated pudding desserts', {'weight': 2238.0}),
#  ('frozen breakfast', 'eggs', {'weight': 2238.0}),
#  ('grains rice dried goods', 'frozen produce', {'weight': 2237.0}),
#  ('water seltzer sparkling water', 'energy sports drinks', {'weight': 2234.0}),
#  ('crackers', 'butter', {'weight': 2232.0}),
#  ('fresh dips tapenades', 'spreads', {'weight': 2232.0}),
#  ('instant foods', 'dry pasta', {'weight': 2231.0}),
#  ('fresh fruits', 'packaged meat', {'weight': 2229.0}),
#  ('fresh herbs', 'butter', {'weight': 2223.0}),
#  ('other creams cheeses', 'canned meals beans', {'weight': 2221.0}),
#  ('canned meals beans', 'dry pasta', {'weight': 2221.0}),
#  ('dry pasta', 'dry pasta', {'weight': 2214.0}),
#  ('dry pasta', 'frozen meals', {'weight': 2212.0}),
#  ('lunch meat', 'canned jarred vegetables', {'weight': 2207.0}),
#  ('yogurt', 'latino foods', {'weight': 2201.0}),
#  ('hot cereal pancake mixes', 'chips pretzels', {'weight': 2196.0}),
#  ('paper goods', 'frozen produce', {'weight': 2195.0}),
#  ('hot dogs bacon sausage', 'frozen breakfast', {'weight': 2193.0}),
#  ('soy lactosefree', 'hot cereal pancake mixes', {'weight': 2189.0}),
#  ('fresh fruits', 'seafood counter', {'weight': 2187.0}),
#  ('lunch meat', 'frozen appetizers sides', {'weight': 2183.0}),
#  ('soy lactosefree', 'cookies cakes', {'weight': 2183.0}),
#  ('soy lactosefree', 'frozen appetizers sides', {'weight': 2181.0}),
#  ('crackers', 'frozen pizza', {'weight': 2180.0}),
#  ('energy granola bars', 'breakfast bakery', {'weight': 2173.0}),
#  ('tortillas flat bread', 'eggs', {'weight': 2171.0}),
#  ('yogurt', 'dish detergents', {'weight': 2170.0}),
#  ('hot dogs bacon sausage', 'instant foods', {'weight': 2170.0}),
#  ('canned meals beans', 'instant foods', {'weight': 2169.0}),
#  ('packaged vegetables fruits', 'honeys syrups nectars', {'weight': 2167.0}),
#  ('fresh fruits', 'cat food care', {'weight': 2161.0}),
#  ('hot dogs bacon sausage', 'energy granola bars', {'weight': 2161.0}),
#  ('crackers', 'condiments', {'weight': 2159.0}),
#  ('hot dogs bacon sausage', 'soft drinks', {'weight': 2159.0}),
#  ('soup broth bouillon', 'pasta sauce', {'weight': 2156.0}),
#  ('soy lactosefree', 'frozen vegan vegetarian', {'weight': 2154.0}),
#  ('bread', 'tea', {'weight': 2152.0}),
#  ('frozen appetizers sides', 'frozen breakfast', {'weight': 2151.0}),
#  ('hot dogs bacon sausage', 'juice nectars', {'weight': 2150.0}),
#  ('chips pretzels', 'doughs gelatins bake mixes', {'weight': 2148.0}),
#  ('fresh fruits', 'protein meal replacements', {'weight': 2147.0}),
#  ('soy lactosefree', 'coffee', {'weight': 2147.0}),
#  ('oils vinegars', 'canned jarred vegetables', {'weight': 2143.0}),
#  ('fresh vegetables', 'cat food care', {'weight': 2138.0}),
#  ('frozen produce', 'breakfast bakery', {'weight': 2135.0}),
#  ('other creams cheeses', 'soft drinks', {'weight': 2132.0}),
#  ('juice nectars', 'baby food formula', {'weight': 2132.0}),
#  ('fresh herbs', 'cream', {'weight': 2131.0}),
#  ('frozen appetizers sides', 'instant foods', {'weight': 2130.0}),
#  ('spreads', 'nuts seeds dried fruit', {'weight': 2125.0}),
#  ('fresh dips tapenades', 'nuts seeds dried fruit', {'weight': 2124.0}),
#  ('other creams cheeses', 'butter', {'weight': 2120.0}),
#  ('lunch meat', 'cookies cakes', {'weight': 2119.0}),
#  ('oils vinegars', 'refrigerated', {'weight': 2119.0}),
#  ('refrigerated', 'fruit vegetable snacks', {'weight': 2116.0}),
#  ('asian foods', 'frozen produce', {'weight': 2116.0}),
#  ('canned jarred vegetables', 'hot dogs bacon sausage', {'weight': 2109.0}),
#  ('condiments', 'eggs', {'weight': 2109.0}),
#  ('dry pasta', 'baby food formula', {'weight': 2109.0}),
#  ('canned jarred vegetables', 'pasta sauce', {'weight': 2108.0}),
#  ('laundry', 'paper goods', {'weight': 2103.0}),
#  ('fresh herbs', 'asian foods', {'weight': 2097.0}),
#  ('tortillas flat bread', 'frozen produce', {'weight': 2097.0}),
#  ('other creams cheeses', 'energy granola bars', {'weight': 2095.0}),
#  ('packaged cheese', 'cleaning products', {'weight': 2095.0}),
#  ('hot dogs bacon sausage', 'dry pasta', {'weight': 2093.0}),
#  ('yogurt', 'laundry', {'weight': 2092.0}),
#  ('cream', 'cereal', {'weight': 2089.0}),
#  ('other creams cheeses', 'dry pasta', {'weight': 2088.0}),
#  ('lunch meat', 'nuts seeds dried fruit', {'weight': 2082.0}),
#  ('baking ingredients', 'spreads', {'weight': 2081.0}),
#  ('lunch meat', 'canned meals beans', {'weight': 2080.0}),
#  ('soft drinks', 'instant foods', {'weight': 2077.0}),
#  ('chips pretzels', 'energy sports drinks', {'weight': 2071.0}),
#  ...]

# %%
popular_pairings = []

for pair in weight_list:
    if pair[0] != pair[1]:
        popular_pairings.append(pair)

# %%
popular_pairings
# Out:
# [('fresh vegetables', 'fresh fruits', {'weight': 308105.0}),
#  ('fresh vegetables', 'packaged vegetables fruits', {'weight': 169766.0}),
#  ('fresh fruits', 'packaged vegetables fruits', {'weight': 158522.0}),
#  ('yogurt', 'fresh fruits', {'weight': 101020.0}),
#  ('yogurt', 'fresh vegetables', {'weight': 87211.0}),
#  ('fresh vegetables', 'packaged cheese', {'weight': 73818.0}),
#  ('fresh fruits', 'packaged cheese', {'weight': 69250.0}),
#  ('fresh vegetables', 'fresh herbs', {'weight': 53544.0}),
#  ('fresh fruits', 'milk', {'weight': 53092.0}),
#  ('yogurt', 'packaged vegetables fruits', {'weight': 50196.0}),
#  ('fresh vegetables', 'milk', {'weight': 46253.0}),
#  ('fresh fruits', 'water seltzer sparkling water', {'weight': 45582.0}),
#  ('fresh fruits', 'chips pretzels', {'weight': 45322.0}),
#  ('fresh vegetables', 'soy lactosefree', {'weight': 45295.0}),
#  ('fresh fruits', 'soy lactosefree', {'weight': 44034.0}),
#  ('fresh vegetables', 'frozen produce', {'weight': 43945.0}),
#  ('fresh fruits', 'frozen produce', {'weight': 40511.0}),
#  ('fresh vegetables', 'water seltzer sparkling water', {'weight': 40130.0}),
#  ('fresh vegetables', 'chips pretzels', {'weight': 39960.0}),
#  ('packaged cheese', 'packaged vegetables fruits', {'weight': 39294.0}),
#  ('fresh fruits', 'bread', {'weight': 38799.0}),
#  ('fresh vegetables', 'bread', {'weight': 37027.0}),
#  ('fresh vegetables', 'eggs', {'weight': 35955.0}),
#  ('fresh fruits', 'refrigerated', {'weight': 35660.0}),
#  ('fresh fruits', 'eggs', {'weight': 32481.0}),
#  ('fresh vegetables', 'canned jarred vegetables', {'weight': 32446.0}),
#  ('fresh fruits', 'fresh herbs', {'weight': 31861.0}),
#  ('fresh vegetables', 'refrigerated', {'weight': 31532.0}),
#  ('fresh fruits', 'crackers', {'weight': 30509.0}),
#  ('fresh vegetables', 'soup broth bouillon', {'weight': 29873.0}),
#  ('fresh fruits', 'ice cream ice', {'weight': 29788.0}),
#  ('fresh fruits', 'energy granola bars', {'weight': 29319.0}),
#  ('yogurt', 'packaged cheese', {'weight': 29156.0}),
#  ('fresh fruits', 'lunch meat', {'weight': 28733.0}),
#  ('fresh vegetables', 'canned meals beans', {'weight': 27839.0}),
#  ('fresh vegetables', 'ice cream ice', {'weight': 27579.0}),
#  ('fresh vegetables', 'lunch meat', {'weight': 27297.0}),
#  ('packaged vegetables fruits', 'milk', {'weight': 25999.0}),
#  ('fresh vegetables', 'crackers', {'weight': 25988.0}),
#  ('fresh vegetables', 'fresh dips tapenades', {'weight': 25731.0}),
#  ('fresh fruits', 'fresh dips tapenades', {'weight': 25621.0}),
#  ('fresh fruits', 'baby food formula', {'weight': 25306.0}),
#  ('fresh fruits', 'cereal', {'weight': 24233.0}),
#  ('packaged vegetables fruits', 'chips pretzels', {'weight': 24152.0}),
#  ('water seltzer sparkling water',
#   'packaged vegetables fruits',
#   {'weight': 23608.0}),
#  ('packaged vegetables fruits', 'frozen produce', {'weight': 23602.0}),
#  ('packaged vegetables fruits', 'soy lactosefree', {'weight': 23537.0}),
#  ('yogurt', 'milk', {'weight': 23360.0}),
#  ('fresh vegetables', 'dry pasta', {'weight': 22716.0}),
#  ('fresh vegetables', 'energy granola bars', {'weight': 22361.0}),
#  ('other creams cheeses', 'fresh vegetables', {'weight': 22278.0}),
#  ('fresh fruits', 'frozen meals', {'weight': 22119.0}),
#  ('fresh vegetables', 'spices seasonings', {'weight': 21709.0}),
#  ('fresh vegetables', 'baking ingredients', {'weight': 21702.0}),
#  ('fresh vegetables', 'oils vinegars', {'weight': 21614.0}),
#  ('fresh fruits', 'nuts seeds dried fruit', {'weight': 21404.0}),
#  ('fresh fruits', 'juice nectars', {'weight': 21374.0}),
#  ('fresh fruits', 'soup broth bouillon', {'weight': 21367.0}),
#  ('fresh vegetables', 'baby food formula', {'weight': 20635.0}),
#  ('fresh vegetables', 'hot dogs bacon sausage', {'weight': 20540.0}),
#  ('fresh vegetables', 'nuts seeds dried fruit', {'weight': 20319.0}),
#  ('packaged vegetables fruits', 'bread', {'weight': 20076.0}),
#  ('yogurt', 'chips pretzels', {'weight': 19995.0}),
#  ('fresh fruits', 'canned meals beans', {'weight': 19962.0}),
#  ('fresh vegetables', 'cereal', {'weight': 19919.0}),
#  ('fresh fruits', 'canned jarred vegetables', {'weight': 19896.0}),
#  ('fresh fruits', 'packaged produce', {'weight': 19860.0}),
#  ('other creams cheeses', 'fresh fruits', {'weight': 19794.0}),
#  ('fresh fruits', 'spreads', {'weight': 19477.0}),
#  ('fresh vegetables', 'frozen meals', {'weight': 19328.0}),
#  ('fresh fruits', 'hot dogs bacon sausage', {'weight': 18980.0}),
#  ('fresh vegetables', 'pasta sauce', {'weight': 18749.0}),
#  ('fresh vegetables', 'juice nectars', {'weight': 18676.0}),
#  ('yogurt', 'water seltzer sparkling water', {'weight': 18640.0}),
#  ('fresh vegetables', 'butter', {'weight': 18550.0}),
#  ('fresh fruits', 'dry pasta', {'weight': 18461.0}),
#  ('packaged vegetables fruits', 'eggs', {'weight': 18410.0}),
#  ('packaged vegetables fruits', 'refrigerated', {'weight': 18261.0}),
#  ('fresh fruits', 'cream', {'weight': 17789.0}),
#  ('fresh vegetables', 'cream', {'weight': 17757.0}),
#  ('fresh fruits', 'baking ingredients', {'weight': 17722.0}),
#  ('packaged vegetables fruits', 'fresh herbs', {'weight': 17618.0}),
#  ('fresh vegetables', 'condiments', {'weight': 17599.0}),
#  ('fresh vegetables', 'spreads', {'weight': 17527.0}),
#  ('packaged cheese', 'chips pretzels', {'weight': 16610.0}),
#  ('fresh vegetables', 'tortillas flat bread', {'weight': 16257.0}),
#  ('packaged vegetables fruits', 'crackers', {'weight': 16222.0}),
#  ('packaged vegetables fruits', 'lunch meat', {'weight': 16143.0}),
#  ('fresh fruits', 'butter', {'weight': 16048.0}),
#  ('packaged cheese', 'milk', {'weight': 16042.0}),
#  ('yogurt', 'soy lactosefree', {'weight': 15993.0}),
#  ('fresh fruits', 'oils vinegars', {'weight': 15834.0}),
#  ('yogurt', 'bread', {'weight': 15711.0}),
#  ('fresh fruits', 'frozen breakfast', {'weight': 15654.0}),
#  ('packaged vegetables fruits', 'ice cream ice', {'weight': 15576.0}),
#  ('fresh fruits', 'pasta sauce', {'weight': 15559.0}),
#  ('packaged vegetables fruits', 'fresh dips tapenades', {'weight': 15477.0}),
#  ('fresh vegetables', 'asian foods', {'weight': 15316.0}),
#  ('yogurt', 'refrigerated', {'weight': 15031.0}),
#  ('fresh fruits', 'breakfast bakery', {'weight': 15020.0}),
#  ('fresh vegetables', 'grains rice dried goods', {'weight': 14963.0}),
#  ('fresh vegetables', 'missing', {'weight': 14799.0}),
#  ('fresh fruits', 'soft drinks', {'weight': 14445.0}),
#  ('yogurt', 'frozen produce', {'weight': 14444.0}),
#  ('fresh fruits', 'instant foods', {'weight': 14366.0}),
#  ('yogurt', 'energy granola bars', {'weight': 14165.0}),
#  ('fresh fruits', 'tortillas flat bread', {'weight': 14133.0}),
#  ('packaged vegetables fruits', 'energy granola bars', {'weight': 14097.0}),
#  ('fresh vegetables', 'instant foods', {'weight': 14021.0}),
#  ('fresh fruits', 'candy chocolate', {'weight': 14016.0}),
#  ('yogurt', 'ice cream ice', {'weight': 13743.0}),
#  ('fresh fruits', 'missing', {'weight': 13743.0}),
#  ('yogurt', 'crackers', {'weight': 13512.0}),
#  ('fresh fruits', 'spices seasonings', {'weight': 13354.0}),
#  ('packaged cheese', 'bread', {'weight': 13288.0}),
#  ('fresh fruits', 'condiments', {'weight': 13252.0}),
#  ('yogurt', 'baby food formula', {'weight': 13057.0}),
#  ('fresh vegetables', 'soft drinks', {'weight': 13046.0}),
#  ('packaged cheese', 'water seltzer sparkling water', {'weight': 13036.0}),
#  ('packaged vegetables fruits', 'frozen meals', {'weight': 13014.0}),
#  ('fresh vegetables', 'frozen breakfast', {'weight': 12984.0}),
#  ('fresh fruits', 'paper goods', {'weight': 12917.0}),
#  ('packaged vegetables fruits', 'soup broth bouillon', {'weight': 12895.0}),
#  ('fresh fruits', 'frozen appetizers sides', {'weight': 12836.0}),
#  ('fresh vegetables', 'breakfast bakery', {'weight': 12785.0}),
#  ('fresh vegetables', 'poultry counter', {'weight': 12704.0}),
#  ('fresh vegetables', 'paper goods', {'weight': 12676.0}),
#  ('fresh fruits', 'cookies cakes', {'weight': 12595.0}),
#  ('fresh fruits', 'tea', {'weight': 12527.0}),
#  ('packaged vegetables fruits', 'cereal', {'weight': 12475.0}),
#  ('water seltzer sparkling water', 'chips pretzels', {'weight': 12438.0}),
#  ('packaged cheese', 'lunch meat', {'weight': 12350.0}),
#  ('yogurt', 'cereal', {'weight': 12281.0}),
#  ('fresh vegetables', 'packaged produce', {'weight': 12260.0}),
#  ('fresh vegetables', 'tofu meat alternatives', {'weight': 12169.0}),
#  ('fresh vegetables', 'frozen appetizers sides', {'weight': 12095.0}),
#  ('packaged vegetables fruits',
#   'canned jarred vegetables',
#   {'weight': 12095.0}),
#  ('fresh fruits', 'fruit vegetable snacks', {'weight': 12065.0}),
#  ('packaged vegetables fruits', 'baby food formula', {'weight': 12055.0}),
#  ('packaged cheese', 'crackers', {'weight': 11965.0}),
#  ('yogurt', 'lunch meat', {'weight': 11884.0}),
#  ('yogurt', 'eggs', {'weight': 11859.0}),
#  ('yogurt', 'frozen meals', {'weight': 11661.0}),
#  ('fresh vegetables', 'candy chocolate', {'weight': 11661.0}),
#  ('packaged vegetables fruits', 'nuts seeds dried fruit', {'weight': 11423.0}),
#  ('fresh vegetables', 'packaged poultry', {'weight': 11391.0}),
#  ('fresh vegetables', 'tea', {'weight': 11277.0}),
#  ('packaged vegetables fruits', 'canned meals beans', {'weight': 11216.0}),
#  ('packaged vegetables fruits', 'hot dogs bacon sausage', {'weight': 10888.0}),
#  ('crackers', 'chips pretzels', {'weight': 10881.0}),
#  ('packaged vegetables fruits', 'juice nectars', {'weight': 10840.0}),
#  ('other creams cheeses', 'packaged vegetables fruits', {'weight': 10739.0}),
#  ('packaged cheese', 'frozen produce', {'weight': 10665.0}),
#  ('fresh fruits', 'grains rice dried goods', {'weight': 10618.0}),
#  ('fresh fruits', 'hot cereal pancake mixes', {'weight': 10618.0}),
#  ('packaged vegetables fruits', 'dry pasta', {'weight': 10532.0}),
#  ('fresh fruits', 'asian foods', {'weight': 10481.0}),
#  ('fresh fruits', 'frozen pizza', {'weight': 10444.0}),
#  ('packaged cheese', 'soy lactosefree', {'weight': 10311.0}),
#  ('fresh vegetables', 'pickled goods olives', {'weight': 10108.0}),
#  ('packaged vegetables fruits', 'spreads', {'weight': 10057.0}),
#  ('fresh fruits', 'coffee', {'weight': 10050.0}),
#  ('milk', 'chips pretzels', {'weight': 10046.0}),
#  ('packaged cheese', 'ice cream ice', {'weight': 10033.0}),
#  ('yogurt', 'fresh dips tapenades', {'weight': 10030.0}),
#  ('packaged cheese', 'eggs', {'weight': 9851.0}),
#  ('packaged vegetables fruits', 'packaged produce', {'weight': 9806.0}),
#  ('fresh fruits', 'popcorn jerky', {'weight': 9787.0}),
#  ('fresh vegetables', 'hot cereal pancake mixes', {'weight': 9775.0}),
#  ('fresh vegetables', 'cookies cakes', {'weight': 9730.0}),
#  ('water seltzer sparkling water', 'milk', {'weight': 9620.0}),
#  ('packaged cheese', 'refrigerated', {'weight': 9606.0}),
#  ('energy granola bars', 'chips pretzels', {'weight': 9582.0}),
#  ('milk', 'bread', {'weight': 9504.0}),
#  ('fresh fruits', 'poultry counter', {'weight': 9325.0}),
#  ('fresh vegetables', 'frozen pizza', {'weight': 9318.0}),
#  ('packaged vegetables fruits', 'pasta sauce', {'weight': 9316.0}),
#  ('packaged vegetables fruits', 'baking ingredients', {'weight': 9300.0}),
#  ('packaged vegetables fruits', 'cream', {'weight': 9104.0}),
#  ('bread', 'chips pretzels', {'weight': 9086.0}),
#  ('packaged vegetables fruits', 'oils vinegars', {'weight': 9076.0}),
#  ('other creams cheeses', 'packaged cheese', {'weight': 9032.0}),
#  ('fresh dips tapenades', 'chips pretzels', {'weight': 9031.0}),
#  ('fresh vegetables', 'fruit vegetable snacks', {'weight': 8997.0}),
#  ('ice cream ice', 'chips pretzels', {'weight': 8994.0}),
#  ('fresh vegetables', 'coffee', {'weight': 8956.0}),
#  ('water seltzer sparkling water', 'refrigerated', {'weight': 8919.0}),
#  ('refrigerated', 'chips pretzels', {'weight': 8916.0}),
#  ('packaged cheese', 'frozen meals', {'weight': 8804.0}),
#  ('yogurt', 'juice nectars', {'weight': 8777.0}),
#  ('fresh vegetables', 'preserved dips spreads', {'weight': 8680.0}),
#  ('fresh fruits', 'packaged poultry', {'weight': 8629.0}),
#  ('yogurt', 'soup broth bouillon', {'weight': 8619.0}),
#  ('fresh fruits', 'tofu meat alternatives', {'weight': 8613.0}),
#  ('yogurt', 'other creams cheeses', {'weight': 8576.0}),
#  ('water seltzer sparkling water', 'soy lactosefree', {'weight': 8482.0}),
#  ('fresh vegetables', 'salad dressing toppings', {'weight': 8447.0}),
#  ('packaged vegetables fruits', 'frozen breakfast', {'weight': 8407.0}),
#  ('soy lactosefree', 'frozen produce', {'weight': 8371.0}),
#  ('packaged vegetables fruits', 'instant foods', {'weight': 8290.0}),
#  ('packaged vegetables fruits', 'butter', {'weight': 8254.0}),
#  ('yogurt', 'fresh herbs', {'weight': 8181.0}),
#  ('packaged cheese', 'cereal', {'weight': 8066.0}),
#  ('fresh vegetables', 'frozen vegan vegetarian', {'weight': 8017.0}),
#  ('packaged vegetables fruits', 'spices seasonings', {'weight': 7988.0}),
#  ('water seltzer sparkling water', 'soft drinks', {'weight': 7972.0}),
#  ('soy lactosefree', 'chips pretzels', {'weight': 7967.0}),
#  ('packaged cheese', 'fresh dips tapenades', {'weight': 7963.0}),
#  ('packaged vegetables fruits', 'condiments', {'weight': 7933.0}),
#  ('packaged cheese', 'energy granola bars', {'weight': 7930.0}),
#  ('yogurt', 'nuts seeds dried fruit', {'weight': 7883.0}),
#  ('water seltzer sparkling water', 'energy granola bars', {'weight': 7839.0}),
#  ('yogurt', 'frozen breakfast', {'weight': 7821.0}),
#  ('packaged cheese', 'fresh herbs', {'weight': 7813.0}),
#  ('yogurt', 'spreads', {'weight': 7811.0}),
#  ('yogurt', 'cream', {'weight': 7794.0}),
#  ('packaged vegetables fruits', 'breakfast bakery', {'weight': 7790.0}),
#  ('packaged vegetables fruits', 'tortillas flat bread', {'weight': 7779.0}),
#  ('packaged vegetables fruits', 'missing', {'weight': 7769.0}),
#  ('fresh vegetables', 'meat counter', {'weight': 7755.0}),
#  ('packaged cheese', 'hot dogs bacon sausage', {'weight': 7729.0}),
#  ('fresh vegetables', 'latino foods', {'weight': 7665.0}),
#  ('packaged cheese', 'baby food formula', {'weight': 7654.0}),
#  ('refrigerated', 'milk', {'weight': 7626.0}),
#  ('packaged cheese', 'dry pasta', {'weight': 7578.0}),
#  ('packaged vegetables fruits', 'soft drinks', {'weight': 7559.0}),
#  ('packaged cheese', 'canned jarred vegetables', {'weight': 7557.0}),
#  ('fresh vegetables', 'popcorn jerky', {'weight': 7552.0}),
#  ('fresh fruits', 'preserved dips spreads', {'weight': 7473.0}),
#  ('chips pretzels', 'frozen meals', {'weight': 7470.0}),
#  ('fresh vegetables', 'specialty cheeses', {'weight': 7438.0}),
#  ('chips pretzels', 'cereal', {'weight': 7381.0}),
#  ('lunch meat', 'chips pretzels', {'weight': 7355.0}),
#  ('packaged cheese', 'soup broth bouillon', {'weight': 7335.0}),
#  ('yogurt', 'hot dogs bacon sausage', {'weight': 7327.0}),
#  ('yogurt', 'canned meals beans', {'weight': 7324.0}),
#  ('fresh fruits', 'pickled goods olives', {'weight': 7286.0}),
#  ('packaged vegetables fruits', 'frozen appetizers sides', {'weight': 7281.0}),
#  ('fresh vegetables', 'buns rolls', {'weight': 7272.0}),
#  ('milk', 'eggs', {'weight': 7264.0}),
#  ('yogurt', 'dry pasta', {'weight': 7223.0}),
#  ('milk', 'cereal', {'weight': 7220.0}),
#  ('yogurt', 'canned jarred vegetables', {'weight': 7174.0}),
#  ('water seltzer sparkling water', 'ice cream ice', {'weight': 7157.0}),
#  ('packaged vegetables fruits', 'paper goods', {'weight': 7151.0}),
#  ('yogurt', 'instant foods', {'weight': 7113.0}),
#  ('water seltzer sparkling water', 'crackers', {'weight': 7105.0}),
#  ('milk', 'frozen produce', {'weight': 7066.0}),
#  ('packaged vegetables fruits', 'candy chocolate', {'weight': 7038.0}),
#  ('fresh fruits', 'buns rolls', {'weight': 7030.0}),
#  ('yogurt', 'breakfast bakery', {'weight': 6984.0}),
#  ('ice cream ice', 'milk', {'weight': 6949.0}),
#  ('refrigerated', 'soy lactosefree', {'weight': 6933.0}),
#  ('chips pretzels', 'soft drinks', {'weight': 6905.0}),
#  ('yogurt', 'soft drinks', {'weight': 6894.0}),
#  ('yogurt', 'candy chocolate', {'weight': 6856.0}),
#  ('packaged cheese', 'pasta sauce', {'weight': 6816.0}),
#  ('water seltzer sparkling water', 'bread', {'weight': 6797.0}),
#  ('crackers', 'milk', {'weight': 6754.0}),
#  ('packaged cheese', 'canned meals beans', {'weight': 6742.0}),
#  ('fresh fruits', 'granola', {'weight': 6702.0}),
#  ('fresh fruits', 'frozen vegan vegetarian', {'weight': 6681.0}),
#  ('lunch meat', 'bread', {'weight': 6624.0}),
#  ('fresh fruits', 'canned fruit applesauce', {'weight': 6586.0}),
#  ('soy lactosefree', 'milk', {'weight': 6571.0}),
#  ('yogurt', 'missing', {'weight': 6567.0}),
#  ('frozen produce', 'chips pretzels', {'weight': 6509.0}),
#  ('milk', 'baby food formula', {'weight': 6496.0}),
#  ('lunch meat', 'milk', {'weight': 6479.0}),
#  ('fresh fruits', 'specialty cheeses', {'weight': 6446.0}),
#  ('chips pretzels', 'cookies cakes', {'weight': 6434.0}),
#  ('packaged vegetables fruits', 'cookies cakes', {'weight': 6389.0}),
#  ('fresh fruits', 'salad dressing toppings', {'weight': 6377.0}),
#  ('yogurt', 'baking ingredients', {'weight': 6337.0}),
#  ('yogurt', 'pasta sauce', {'weight': 6327.0}),
#  ('soy lactosefree', 'bread', {'weight': 6311.0}),
#  ('fresh fruits', 'prepared meals', {'weight': 6292.0}),
#  ('packaged cheese', 'juice nectars', {'weight': 6264.0}),
#  ('packaged vegetables fruits', 'tea', {'weight': 6253.0}),
#  ('packaged cheese', 'instant foods', {'weight': 6232.0}),
#  ('packaged vegetables fruits', 'asian foods', {'weight': 6181.0}),
#  ('packaged cheese', 'cream', {'weight': 6150.0}),
#  ('yogurt', 'butter', {'weight': 6108.0}),
#  ('yogurt', 'cookies cakes', {'weight': 6083.0}),
#  ('fresh fruits', 'doughs gelatins bake mixes', {'weight': 6076.0}),
#  ('packaged vegetables fruits', 'grains rice dried goods', {'weight': 6076.0}),
#  ('packaged cheese', 'soft drinks', {'weight': 6022.0}),
#  ('packaged vegetables fruits', 'fruit vegetable snacks', {'weight': 6021.0}),
#  ('refrigerated', 'ice cream ice', {'weight': 6005.0}),
#  ('crackers', 'bread', {'weight': 5997.0}),
#  ('bread', 'eggs', {'weight': 5985.0}),
#  ('chips pretzels', 'candy chocolate', {'weight': 5979.0}),
#  ('yogurt', 'paper goods', {'weight': 5954.0}),
#  ('water seltzer sparkling water', 'frozen produce', {'weight': 5943.0}),
#  ('fresh vegetables', 'doughs gelatins bake mixes', {'weight': 5942.0}),
#  ('chips pretzels', 'eggs', {'weight': 5940.0}),
#  ('packaged cheese', 'tortillas flat bread', {'weight': 5937.0}),
#  ('soy lactosefree', 'ice cream ice', {'weight': 5906.0}),
#  ('water seltzer sparkling water', 'eggs', {'weight': 5883.0}),
#  ('fresh fruits', 'latino foods', {'weight': 5874.0}),
#  ('packaged cheese', 'nuts seeds dried fruit', {'weight': 5873.0}),
#  ('water seltzer sparkling water', 'frozen meals', {'weight': 5871.0}),
#  ('fresh vegetables', 'canned meat seafood', {'weight': 5867.0}),
#  ('packaged cheese', 'spreads', {'weight': 5865.0}),
#  ('ice cream ice', 'frozen meals', {'weight': 5828.0}),
#  ('refrigerated', 'bread', {'weight': 5803.0}),
#  ('packaged cheese', 'butter', {'weight': 5747.0}),
#  ('packaged cheese', 'baking ingredients', {'weight': 5709.0}),
#  ('milk', 'energy granola bars', {'weight': 5685.0}),
#  ('water seltzer sparkling water', 'juice nectars', {'weight': 5669.0}),
#  ('soy lactosefree', 'energy granola bars', {'weight': 5651.0}),
#  ('refrigerated', 'energy granola bars', {'weight': 5647.0}),
#  ('refrigerated', 'juice nectars', {'weight': 5628.0}),
#  ('juice nectars', 'chips pretzels', {'weight': 5624.0}),
#  ('packaged vegetables fruits', 'frozen pizza', {'weight': 5621.0}),
#  ('fresh vegetables', 'marinades meat preparation', {'weight': 5556.0}),
#  ('packaged cheese', 'breakfast bakery', {'weight': 5545.0}),
#  ('packaged vegetables fruits', 'packaged poultry', {'weight': 5522.0}),
#  ('soy lactosefree', 'eggs', {'weight': 5521.0}),
#  ('water seltzer sparkling water', 'cereal', {'weight': 5518.0}),
#  ('crackers', 'energy granola bars', {'weight': 5518.0}),
#  ('yogurt', 'frozen appetizers sides', {'weight': 5510.0}),
#  ('yogurt', 'tea', {'weight': 5484.0}),
#  ('milk', 'frozen meals', {'weight': 5477.0}),
#  ('ice cream ice', 'bread', {'weight': 5475.0}),
#  ('packaged cheese', 'frozen breakfast', {'weight': 5458.0}),
#  ('packaged cheese', 'frozen appetizers sides', {'weight': 5446.0}),
#  ('fresh vegetables', 'granola', {'weight': 5444.0}),
#  ('packaged vegetables fruits', 'coffee', {'weight': 5436.0}),
#  ('packaged vegetables fruits',
#   'hot cereal pancake mixes',
#   {'weight': 5410.0}),
#  ('fresh fruits', 'cleaning products', {'weight': 5394.0}),
#  ('bread', 'frozen produce', {'weight': 5387.0}),
#  ('fresh fruits', 'meat counter', {'weight': 5368.0}),
#  ('crackers', 'cereal', {'weight': 5364.0}),
#  ('packaged vegetables fruits', 'poultry counter', {'weight': 5359.0}),
#  ('yogurt', 'fruit vegetable snacks', {'weight': 5332.0}),
#  ('bread', 'cereal', {'weight': 5326.0}),
#  ('soy lactosefree', 'cereal', {'weight': 5316.0}),
#  ('fresh vegetables', 'canned fruit applesauce', {'weight': 5308.0}),
#  ('water seltzer sparkling water', 'lunch meat', {'weight': 5299.0}),
#  ('water seltzer sparkling water', 'paper goods', {'weight': 5281.0}),
#  ('fresh vegetables', 'prepared meals', {'weight': 5264.0}),
#  ('packaged cheese', 'condiments', {'weight': 5252.0}),
#  ('water seltzer sparkling water', 'fresh dips tapenades', {'weight': 5229.0}),
#  ('yogurt', 'tortillas flat bread', {'weight': 5201.0}),
#  ('packaged vegetables fruits', 'popcorn jerky', {'weight': 5185.0}),
#  ('packaged vegetables fruits', 'salad dressing toppings', {'weight': 5165.0}),
#  ('packaged vegetables fruits', 'tofu meat alternatives', {'weight': 5145.0}),
#  ('fresh vegetables', 'dish detergents', {'weight': 5142.0}),
#  ('hot dogs bacon sausage', 'chips pretzels', {'weight': 5127.0}),
#  ('fresh fruits', 'dish detergents', {'weight': 5090.0}),
#  ('packaged cheese', 'paper goods', {'weight': 5073.0}),
#  ('refrigerated', 'frozen produce', {'weight': 5070.0}),
#  ('other creams cheeses', 'chips pretzels', {'weight': 5061.0}),
#  ('fresh vegetables', 'cleaning products', {'weight': 5046.0}),
#  ('yogurt', 'oils vinegars', {'weight': 5039.0}),
#  ('soy lactosefree', 'crackers', {'weight': 5037.0}),
#  ('crackers', 'ice cream ice', {'weight': 5001.0}),
#  ('yogurt', 'condiments', {'weight': 4978.0}),
#  ('milk', 'cream', {'weight': 4972.0}),
#  ('soup broth bouillon', 'chips pretzels', {'weight': 4959.0}),
#  ('other creams cheeses', 'milk', {'weight': 4953.0}),
#  ('lunch meat', 'crackers', {'weight': 4944.0}),
#  ('chips pretzels', 'nuts seeds dried fruit', {'weight': 4939.0}),
#  ('bread', 'frozen meals', {'weight': 4911.0}),
#  ('milk', 'juice nectars', {'weight': 4896.0}),
#  ('refrigerated', 'crackers', {'weight': 4837.0}),
#  ('frozen produce', 'eggs', {'weight': 4837.0}),
#  ('yogurt', 'coffee', {'weight': 4820.0}),
#  ('canned jarred vegetables', 'canned meals beans', {'weight': 4803.0}),
#  ('ice cream ice', 'frozen produce', {'weight': 4794.0}),
#  ('frozen produce', 'frozen meals', {'weight': 4775.0}),
#  ('fresh herbs', 'soy lactosefree', {'weight': 4763.0}),
#  ('refrigerated', 'frozen meals', {'weight': 4752.0}),
#  ('packaged cheese', 'oils vinegars', {'weight': 4732.0}),
#  ('refrigerated', 'eggs', {'weight': 4717.0}),
#  ('packaged cheese', 'cookies cakes', {'weight': 4692.0}),
#  ('chips pretzels', 'instant foods', {'weight': 4683.0}),
#  ('yogurt', 'frozen pizza', {'weight': 4673.0}),
#  ('water seltzer sparkling water', 'candy chocolate', {'weight': 4671.0}),
#  ('crackers', 'frozen meals', {'weight': 4667.0}),
#  ('fresh fruits', 'laundry', {'weight': 4658.0}),
#  ('crackers', 'frozen produce', {'weight': 4657.0}),
#  ('crackers', 'fresh dips tapenades', {'weight': 4640.0}),
#  ('fresh herbs', 'milk', {'weight': 4611.0}),
#  ('soup broth bouillon', 'frozen produce', {'weight': 4554.0}),
#  ('yogurt', 'hot cereal pancake mixes', {'weight': 4543.0}),
#  ('fresh fruits', 'frozen meat seafood', {'weight': 4542.0}),
#  ('fresh dips tapenades', 'milk', {'weight': 4531.0}),
#  ('soy lactosefree', 'fresh dips tapenades', {'weight': 4520.0}),
#  ('packaged cheese', 'spices seasonings', {'weight': 4509.0}),
#  ('packaged vegetables fruits', 'pickled goods olives', {'weight': 4493.0}),
#  ('packaged vegetables fruits', 'preserved dips spreads', {'weight': 4480.0}),
#  ('ice cream ice', 'soft drinks', {'weight': 4474.0}),
#  ('hot dogs bacon sausage', 'milk', {'weight': 4470.0}),
#  ('water seltzer sparkling water', 'tea', {'weight': 4468.0}),
#  ('fresh herbs', 'frozen produce', {'weight': 4464.0}),
#  ('fresh fruits', 'energy sports drinks', {'weight': 4450.0}),
#  ('lunch meat', 'refrigerated', {'weight': 4446.0}),
#  ('fresh vegetables', 'soap', {'weight': 4435.0}),
#  ('water seltzer sparkling water',
#   'nuts seeds dried fruit',
#   {'weight': 4435.0}),
#  ('fresh vegetables', 'honeys syrups nectars', {'weight': 4430.0}),
#  ('ice cream ice', 'cereal', {'weight': 4422.0}),
#  ('soup broth bouillon', 'frozen meals', {'weight': 4418.0}),
#  ('packaged cheese', 'frozen pizza', {'weight': 4401.0}),
#  ('milk', 'baking ingredients', {'weight': 4389.0}),
#  ('spreads', 'chips pretzels', {'weight': 4385.0}),
#  ('chips pretzels', 'frozen breakfast', {'weight': 4385.0}),
#  ('canned meat seafood', 'fresh fruits', {'weight': 4383.0}),
#  ('refrigerated', 'cereal', {'weight': 4373.0}),
#  ('lunch meat', 'soy lactosefree', {'weight': 4372.0}),
#  ('soy lactosefree', 'frozen meals', {'weight': 4371.0}),
#  ('frozen appetizers sides', 'chips pretzels', {'weight': 4365.0}),
#  ('fresh fruits', 'honeys syrups nectars', {'weight': 4356.0}),
#  ('packaged vegetables fruits', 'frozen vegan vegetarian', {'weight': 4351.0}),
#  ('fresh fruits', 'soap', {'weight': 4350.0}),
#  ('butter', 'milk', {'weight': 4331.0}),
#  ('packaged cheese', 'candy chocolate', {'weight': 4330.0}),
#  ('water seltzer sparkling water', 'cream', {'weight': 4330.0}),
#  ('bread', 'energy granola bars', {'weight': 4329.0}),
#  ('water seltzer sparkling water', 'soup broth bouillon', {'weight': 4294.0}),
#  ('yogurt', 'popcorn jerky', {'weight': 4282.0}),
#  ('fresh vegetables', 'laundry', {'weight': 4273.0}),
#  ('chips pretzels', 'breakfast bakery', {'weight': 4269.0}),
#  ('chips pretzels', 'dry pasta', {'weight': 4268.0}),
#  ('frozen breakfast', 'frozen meals', {'weight': 4265.0}),
#  ('fresh fruits', 'prepared soups salads', {'weight': 4242.0}),
#  ('canned meals beans', 'chips pretzels', {'weight': 4225.0}),
#  ('milk', 'soup broth bouillon', {'weight': 4224.0}),
#  ('milk', 'soft drinks', {'weight': 4223.0}),
#  ('lunch meat', 'ice cream ice', {'weight': 4200.0}),
#  ('fresh herbs', 'canned jarred vegetables', {'weight': 4200.0}),
#  ('paper goods', 'chips pretzels', {'weight': 4194.0}),
#  ('canned meals beans', 'frozen produce', {'weight': 4184.0}),
#  ('water seltzer sparkling water', 'fresh herbs', {'weight': 4174.0}),
#  ('chips pretzels', 'fruit vegetable snacks', {'weight': 4161.0}),
#  ('water seltzer sparkling water', 'baby food formula', {'weight': 4156.0}),
#  ('milk', 'dry pasta', {'weight': 4149.0}),
#  ('yogurt', 'spices seasonings', {'weight': 4143.0}),
#  ('bread', 'spreads', {'weight': 4139.0}),
#  ('yogurt', 'granola', {'weight': 4131.0}),
#  ('pasta sauce', 'dry pasta', {'weight': 4122.0}),
#  ('soy lactosefree', 'soup broth bouillon', {'weight': 4119.0}),
#  ('energy granola bars', 'cereal', {'weight': 4115.0}),
#  ('energy granola bars', 'frozen meals', {'weight': 4111.0}),
#  ('canned jarred vegetables', 'frozen produce', {'weight': 4104.0}),
#  ('lunch meat', 'eggs', {'weight': 4092.0}),
#  ('soy lactosefree', 'spreads', {'weight': 4063.0}),
#  ('lunch meat', 'frozen produce', {'weight': 4057.0}),
#  ('crackers', 'cookies cakes', {'weight': 4054.0}),
#  ('fresh dips tapenades', 'bread', {'weight': 4050.0}),
#  ('frozen produce', 'energy granola bars', {'weight': 4042.0}),
#  ('ice cream ice', 'eggs', {'weight': 4027.0}),
#  ('milk', 'spreads', {'weight': 4023.0}),
#  ('milk', 'instant foods', {'weight': 4011.0}),
#  ('cream', 'chips pretzels', {'weight': 3975.0}),
#  ('canned jarred vegetables', 'soup broth bouillon', {'weight': 3973.0}),
#  ('fresh vegetables', 'frozen meat seafood', {'weight': 3962.0}),
#  ('fresh dips tapenades', 'frozen produce', {'weight': 3961.0}),
#  ('hot dogs bacon sausage', 'bread', {'weight': 3944.0}),
#  ('popcorn jerky', 'chips pretzels', {'weight': 3942.0}),
#  ('water seltzer sparkling water', 'spreads', {'weight': 3934.0}),
#  ('lunch meat', 'frozen meals', {'weight': 3923.0}),
#  ('soy lactosefree', 'nuts seeds dried fruit', {'weight': 3917.0}),
#  ('yogurt', 'packaged produce', {'weight': 3916.0}),
#  ('packaged vegetables fruits', 'buns rolls', {'weight': 3916.0}),
#  ('frozen meals', 'cereal', {'weight': 3916.0}),
#  ('milk', 'frozen breakfast', {'weight': 3913.0}),
#  ('frozen pizza', 'frozen meals', {'weight': 3908.0}),
#  ('other creams cheeses', 'bread', {'weight': 3896.0}),
#  ('ice cream ice', 'energy granola bars', {'weight': 3886.0}),
#  ('frozen produce', 'baby food formula', {'weight': 3883.0}),
#  ('packaged cheese', 'missing', {'weight': 3881.0}),
#  ('crackers', 'eggs', {'weight': 3870.0}),
#  ('chips pretzels', 'baby food formula', {'weight': 3869.0}),
#  ('canned jarred vegetables', 'milk', {'weight': 3862.0}),
#  ('soy lactosefree', 'baking ingredients', {'weight': 3860.0}),
#  ('ice cream ice', 'juice nectars', {'weight': 3855.0}),
#  ('crackers', 'baby food formula', {'weight': 3843.0}),
#  ('refrigerated', 'soft drinks', {'weight': 3833.0}),
#  ('frozen produce', 'cereal', {'weight': 3833.0}),
#  ('refrigerated', 'soup broth bouillon', {'weight': 3829.0}),
#  ('packaged cheese', 'packaged produce', {'weight': 3824.0}),
#  ('refrigerated', 'fresh dips tapenades', {'weight': 3820.0}),
#  ('soup broth bouillon', 'bread', {'weight': 3817.0}),
#  ('water seltzer sparkling water',
#   'hot dogs bacon sausage',
#   {'weight': 3805.0}),
#  ('crackers', 'soft drinks', {'weight': 3799.0}),
#  ('soft drinks', 'frozen meals', {'weight': 3794.0}),
#  ('water seltzer sparkling water', 'coffee', {'weight': 3779.0}),
#  ('other creams cheeses', 'water seltzer sparkling water', {'weight': 3768.0}),
#  ('fresh fruits', 'breakfast bars pastries', {'weight': 3758.0}),
#  ('packaged cheese', 'fruit vegetable snacks', {'weight': 3738.0}),
#  ('canned jarred vegetables', 'chips pretzels', {'weight': 3738.0}),
#  ('fresh herbs', 'chips pretzels', {'weight': 3736.0}),
#  ('milk', 'nuts seeds dried fruit', {'weight': 3729.0}),
#  ('energy granola bars', 'candy chocolate', {'weight': 3724.0}),
#  ('yogurt', 'grains rice dried goods', {'weight': 3710.0}),
#  ('preserved dips spreads', 'chips pretzels', {'weight': 3710.0}),
#  ('crackers', 'soup broth bouillon', {'weight': 3708.0}),
#  ('soy lactosefree', 'canned meals beans', {'weight': 3701.0}),
#  ('yogurt', 'asian foods', {'weight': 3699.0}),
#  ('fresh fruits', 'marinades meat preparation', {'weight': 3699.0}),
#  ('juice nectars', 'bread', {'weight': 3698.0}),
#  ('chips pretzels', 'frozen pizza', {'weight': 3695.0}),
#  ('soy lactosefree', 'juice nectars', {'weight': 3686.0}),
#  ('bread', 'dry pasta', {'weight': 3685.0}),
#  ('lunch meat', 'hot dogs bacon sausage', {'weight': 3675.0}),
#  ('fresh herbs', 'spices seasonings', {'weight': 3669.0}),
#  ('frozen appetizers sides', 'frozen meals', {'weight': 3669.0}),
#  ('energy granola bars', 'nuts seeds dried fruit', {'weight': 3665.0}),
#  ('milk', 'breakfast bakery', {'weight': 3662.0}),
#  ('chips pretzels', 'tea', {'weight': 3638.0}),
#  ('condiments', 'chips pretzels', {'weight': 3634.0}),
#  ('canned meals beans', 'milk', {'weight': 3627.0}),
#  ('soy lactosefree', 'baby food formula', {'weight': 3622.0}),
#  ('frozen produce', 'nuts seeds dried fruit', {'weight': 3619.0}),
#  ('fresh vegetables', 'prepared soups salads', {'weight': 3597.0}),
#  ('canned meals beans', 'soup broth bouillon', {'weight': 3590.0}),
#  ('fresh herbs', 'eggs', {'weight': 3589.0}),
#  ('spreads', 'frozen produce', {'weight': 3581.0}),
#  ('packaged vegetables fruits', 'prepared meals', {'weight': 3569.0}),
#  ('hot dogs bacon sausage', 'eggs', {'weight': 3567.0}),
#  ('chips pretzels', 'pasta sauce', {'weight': 3550.0}),
#  ('specialty cheeses', 'packaged vegetables fruits', {'weight': 3546.0}),
#  ('bread', 'baby food formula', {'weight': 3544.0}),
#  ('fresh herbs', 'bread', {'weight': 3540.0}),
#  ('baking ingredients', 'chips pretzels', {'weight': 3538.0}),
#  ('lunch meat', 'cereal', {'weight': 3526.0}),
#  ('crackers', 'nuts seeds dried fruit', {'weight': 3520.0}),
#  ('lunch meat', 'energy granola bars', {'weight': 3513.0}),
#  ('milk', 'cookies cakes', {'weight': 3511.0}),
#  ('ice cream ice', 'soup broth bouillon', {'weight': 3499.0}),
#  ('crackers', 'juice nectars', {'weight': 3497.0}),
#  ('fresh herbs', 'soup broth bouillon', {'weight': 3493.0}),
#  ('water seltzer sparkling water', 'cookies cakes', {'weight': 3468.0}),
#  ('frozen meals', 'eggs', {'weight': 3446.0}),
#  ('fresh dips tapenades', 'ice cream ice', {'weight': 3445.0}),
#  ('canned jarred vegetables', 'soy lactosefree', {'weight': 3444.0}),
#  ('yogurt', 'canned fruit applesauce', {'weight': 3436.0}),
#  ('baking ingredients', 'frozen produce', {'weight': 3433.0}),
#  ('milk', 'pasta sauce', {'weight': 3431.0}),
#  ('lunch meat', 'fresh dips tapenades', {'weight': 3426.0}),
#  ('packaged vegetables fruits',
#   'doughs gelatins bake mixes',
#   {'weight': 3417.0}),
#  ('water seltzer sparkling water',
#   'canned jarred vegetables',
#   {'weight': 3415.0}),
#  ('packaged cheese', 'tea', {'weight': 3410.0}),
#  ('bread', 'breakfast bakery', {'weight': 3410.0}),
#  ('frozen produce', 'dry pasta', {'weight': 3410.0}),
#  ('butter', 'chips pretzels', {'weight': 3405.0}),
#  ('other creams cheeses', 'ice cream ice', {'weight': 3402.0}),
#  ('milk', 'paper goods', {'weight': 3396.0}),
#  ('water seltzer sparkling water', 'breakfast bakery', {'weight': 3395.0}),
#  ('packaged cheese', 'coffee', {'weight': 3391.0}),
#  ('refrigerated', 'tea', {'weight': 3390.0}),
#  ('tortillas flat bread', 'chips pretzels', {'weight': 3382.0}),
#  ('crackers', 'spreads', {'weight': 3377.0}),
#  ('packaged vegetables fruits', 'granola', {'weight': 3376.0}),
#  ('yogurt', 'packaged poultry', {'weight': 3372.0}),
#  ('ice cream ice', 'cookies cakes', {'weight': 3372.0}),
#  ('bread', 'soft drinks', {'weight': 3358.0}),
#  ('instant foods', 'frozen meals', {'weight': 3358.0}),
#  ('packaged vegetables fruits', 'canned fruit applesauce', {'weight': 3354.0}),
#  ('fresh fruits', 'oral hygiene', {'weight': 3350.0}),
#  ('fresh vegetables', 'food storage', {'weight': 3347.0}),
#  ('juice nectars', 'frozen produce', {'weight': 3329.0}),
#  ('water seltzer sparkling water', 'baking ingredients', {'weight': 3328.0}),
#  ('packaged vegetables fruits', 'latino foods', {'weight': 3321.0}),
#  ('other creams cheeses', 'crackers', {'weight': 3319.0}),
#  ('fresh vegetables', 'oral hygiene', {'weight': 3317.0}),
#  ('canned meals beans', 'bread', {'weight': 3302.0}),
#  ('frozen appetizers sides', 'milk', {'weight': 3290.0}),
#  ('refrigerated', 'hot dogs bacon sausage', {'weight': 3289.0}),
#  ('hot dogs bacon sausage', 'frozen produce', {'weight': 3276.0}),
#  ('cereal', 'eggs', {'weight': 3275.0}),
#  ('bread', 'instant foods', {'weight': 3254.0}),
#  ('butter', 'bread', {'weight': 3246.0}),
#  ('bread', 'frozen breakfast', {'weight': 3240.0}),
#  ('fresh vegetables', 'energy sports drinks', {'weight': 3236.0}),
#  ('energy granola bars', 'eggs', {'weight': 3232.0}),
#  ('packaged cheese', 'preserved dips spreads', {'weight': 3224.0}),
#  ('juice nectars', 'soft drinks', {'weight': 3220.0}),
#  ('fresh herbs', 'refrigerated', {'weight': 3219.0}),
#  ('water seltzer sparkling water', 'dry pasta', {'weight': 3210.0}),
#  ('fresh dips tapenades', 'eggs', {'weight': 3209.0}),
#  ('soy lactosefree', 'dry pasta', {'weight': 3204.0}),
#  ('bread', 'cream', {'weight': 3195.0}),
#  ('crackers', 'instant foods', {'weight': 3190.0}),
#  ('milk', 'packaged produce', {'weight': 3190.0}),
#  ('fresh dips tapenades', 'energy granola bars', {'weight': 3187.0}),
#  ('water seltzer sparkling water', 'canned meals beans', {'weight': 3185.0}),
#  ('fresh dips tapenades', 'frozen meals', {'weight': 3176.0}),
#  ('packaged cheese', 'asian foods', {'weight': 3175.0}),
#  ('crackers', 'hot dogs bacon sausage', {'weight': 3175.0}),
#  ('soup broth bouillon', 'eggs', {'weight': 3158.0}),
#  ('crackers', 'candy chocolate', {'weight': 3154.0}),
#  ('other creams cheeses', 'frozen produce', {'weight': 3151.0}),
#  ('other creams cheeses', 'eggs', {'weight': 3146.0}),
#  ('refrigerated', 'nuts seeds dried fruit', {'weight': 3145.0}),
#  ('chips pretzels', 'coffee', {'weight': 3143.0}),
#  ('crackers', 'frozen breakfast', {'weight': 3135.0}),
#  ('packaged cheese', 'pickled goods olives', {'weight': 3132.0}),
#  ('packaged cheese', 'popcorn jerky', {'weight': 3131.0}),
#  ('ice cream ice', 'candy chocolate', {'weight': 3131.0}),
#  ('soy lactosefree', 'cream', {'weight': 3130.0}),
#  ('canned jarred vegetables', 'dry pasta', {'weight': 3117.0}),
#  ('baking ingredients', 'eggs', {'weight': 3108.0}),
#  ('water seltzer sparkling water', 'missing', {'weight': 3101.0}),
#  ('fresh herbs', 'canned meals beans', {'weight': 3099.0}),
#  ('packaged cheese', 'hot cereal pancake mixes', {'weight': 3097.0}),
#  ('butter', 'baking ingredients', {'weight': 3096.0}),
#  ('canned jarred vegetables', 'bread', {'weight': 3089.0}),
#  ('juice nectars', 'frozen meals', {'weight': 3083.0}),
#  ('water seltzer sparkling water', 'frozen breakfast', {'weight': 3073.0}),
#  ('milk', 'candy chocolate', {'weight': 3070.0}),
#  ('oils vinegars', 'soy lactosefree', {'weight': 3066.0}),
#  ('fresh fruits', 'food storage', {'weight': 3058.0}),
#  ('packaged cheese', 'packaged poultry', {'weight': 3052.0}),
#  ('water seltzer sparkling water', 'condiments', {'weight': 3042.0}),
#  ('hot dogs bacon sausage', 'frozen meals', {'weight': 3039.0}),
#  ('hot dogs bacon sausage', 'ice cream ice', {'weight': 3038.0}),
#  ('fresh herbs', 'baking ingredients', {'weight': 3028.0}),
#  ('energy granola bars', 'fruit vegetable snacks', {'weight': 3027.0}),
#  ('yogurt', 'poultry counter', {'weight': 3023.0}),
#  ('packaged cheese', 'salad dressing toppings', {'weight': 3023.0}),
#  ('refrigerated', 'candy chocolate', {'weight': 3015.0}),
#  ('packaged cheese', 'buns rolls', {'weight': 3014.0}),
#  ('bread', 'pasta sauce', {'weight': 3014.0}),
#  ('spreads', 'energy granola bars', {'weight': 3000.0}),
#  ('frozen produce', 'instant foods', {'weight': 2990.0}),
#  ('lunch meat', 'soup broth bouillon', {'weight': 2987.0}),
#  ('paper goods', 'soft drinks', {'weight': 2986.0}),
#  ('packaged vegetables fruits', 'cleaning products', {'weight': 2985.0}),
#  ('other creams cheeses', 'lunch meat', {'weight': 2984.0}),
#  ('ice cream ice', 'instant foods', {'weight': 2973.0}),
#  ('water seltzer sparkling water', 'oils vinegars', {'weight': 2970.0}),
#  ('other creams cheeses', 'soy lactosefree', {'weight': 2969.0}),
#  ('paper goods', 'cleaning products', {'weight': 2967.0}),
#  ('soy lactosefree', 'hot dogs bacon sausage', {'weight': 2964.0}),
#  ('water seltzer sparkling water', 'butter', {'weight': 2962.0}),
#  ('fresh vegetables', 'packaged meat', {'weight': 2958.0}),
#  ('yogurt', 'preserved dips spreads', {'weight': 2953.0}),
#  ('other creams cheeses', 'refrigerated', {'weight': 2948.0}),
#  ('oils vinegars', 'frozen produce', {'weight': 2938.0}),
#  ('frozen produce', 'pasta sauce', {'weight': 2936.0}),
#  ('yogurt', 'tofu meat alternatives', {'weight': 2934.0}),
#  ('water seltzer sparkling water', 'instant foods', {'weight': 2928.0}),
#  ('milk', 'tortillas flat bread', {'weight': 2913.0}),
#  ('crackers', 'dry pasta', {'weight': 2909.0}),
#  ('water seltzer sparkling water', 'packaged produce', {'weight': 2908.0}),
#  ('packaged vegetables fruits', 'meat counter', {'weight': 2907.0}),
#  ('water seltzer sparkling water', 'popcorn jerky', {'weight': 2896.0}),
#  ('canned jarred vegetables', 'eggs', {'weight': 2896.0}),
#  ('missing', 'chips pretzels', {'weight': 2894.0}),
#  ('yogurt', 'buns rolls', {'weight': 2891.0}),
#  ('condiments', 'bread', {'weight': 2891.0}),
#  ('packaged cheese', 'grains rice dried goods', {'weight': 2889.0}),
#  ('bread', 'nuts seeds dried fruit', {'weight': 2884.0}),
#  ('ice cream ice', 'paper goods', {'weight': 2879.0}),
#  ('lunch meat', 'juice nectars', {'weight': 2878.0}),
#  ('ice cream ice', 'baking ingredients', {'weight': 2877.0}),
#  ('water seltzer sparkling water', 'pasta sauce', {'weight': 2870.0}),
#  ('soy lactosefree', 'candy chocolate', {'weight': 2870.0}),
#  ('other creams cheeses', 'breakfast bakery', {'weight': 2867.0}),
#  ('bread', 'cookies cakes', {'weight': 2865.0}),
#  ('refrigerated', 'baby food formula', {'weight': 2854.0}),
#  ('crackers', 'paper goods', {'weight': 2854.0}),
#  ('oils vinegars', 'milk', {'weight': 2852.0}),
#  ('soy lactosefree', 'condiments', {'weight': 2842.0}),
#  ('frozen produce', 'frozen breakfast', {'weight': 2840.0}),
#  ('oils vinegars', 'fresh herbs', {'weight': 2825.0}),
#  ('ice cream ice', 'cream', {'weight': 2825.0}),
#  ('paper goods', 'bread', {'weight': 2820.0}),
#  ('soy lactosefree', 'frozen breakfast', {'weight': 2818.0}),
#  ('refrigerated', 'frozen breakfast', {'weight': 2813.0}),
#  ('baking ingredients', 'bread', {'weight': 2811.0}),
#  ('fresh vegetables', 'seafood counter', {'weight': 2810.0}),
#  ('energy granola bars', 'baby food formula', {'weight': 2805.0}),
#  ('refrigerated', 'spreads', {'weight': 2803.0}),
#  ('spreads', 'cereal', {'weight': 2802.0}),
#  ('oils vinegars', 'chips pretzels', {'weight': 2795.0}),
#  ('milk', 'condiments', {'weight': 2794.0}),
#  ('packaged cheese', 'doughs gelatins bake mixes', {'weight': 2790.0}),
#  ('ice cream ice', 'missing', {'weight': 2787.0}),
#  ('juice nectars', 'cereal', {'weight': 2787.0}),
#  ('juice nectars', 'eggs', {'weight': 2785.0}),
#  ('tortillas flat bread', 'bread', {'weight': 2784.0}),
#  ('yogurt', 'doughs gelatins bake mixes', {'weight': 2783.0}),
#  ('crackers', 'breakfast bakery', {'weight': 2783.0}),
#  ('butter', 'eggs', {'weight': 2783.0}),
#  ('canned jarred vegetables', 'spices seasonings', {'weight': 2782.0}),
#  ('canned meals beans', 'frozen meals', {'weight': 2779.0}),
#  ('soft drinks', 'candy chocolate', {'weight': 2776.0}),
#  ('ice cream ice', 'frozen breakfast', {'weight': 2774.0}),
#  ('cream', 'eggs', {'weight': 2774.0}),
#  ('canned meat seafood', 'packaged vegetables fruits', {'weight': 2766.0}),
#  ('soy lactosefree', 'missing', {'weight': 2763.0}),
#  ('soy lactosefree', 'tea', {'weight': 2761.0}),
#  ('energy granola bars', 'cookies cakes', {'weight': 2758.0}),
#  ('soy lactosefree', 'pasta sauce', {'weight': 2747.0}),
#  ('fresh fruits', 'vitamins supplements', {'weight': 2746.0}),
#  ('water seltzer sparkling water',
#   'fruit vegetable snacks',
#   {'weight': 2745.0}),
#  ('eggs', 'baby food formula', {'weight': 2741.0}),
#  ('fresh dips tapenades', 'cereal', {'weight': 2736.0}),
#  ('baking ingredients', 'spices seasonings', {'weight': 2735.0}),
#  ('refrigerated', 'paper goods', {'weight': 2731.0}),
#  ('soft drinks', 'cookies cakes', {'weight': 2728.0}),
#  ('soup broth bouillon', 'instant foods', {'weight': 2724.0}),
#  ('butter', 'frozen produce', {'weight': 2721.0}),
#  ('cookies cakes', 'cereal', {'weight': 2719.0}),
#  ('cereal', 'baby food formula', {'weight': 2718.0}),
#  ('soft drinks', 'cereal', {'weight': 2708.0}),
#  ('cookies cakes', 'frozen meals', {'weight': 2707.0}),
#  ('fresh vegetables', 'frozen breads doughs', {'weight': 2705.0}),
#  ('frozen appetizers sides', 'ice cream ice', {'weight': 2704.0}),
#  ('frozen meals', 'baby food formula', {'weight': 2704.0}),
#  ('paper goods', 'frozen meals', {'weight': 2701.0}),
#  ('ice cream ice', 'dry pasta', {'weight': 2698.0}),
#  ('packaged cheese', 'tofu meat alternatives', {'weight': 2697.0}),
#  ('milk', 'frozen pizza', {'weight': 2694.0}),
#  ('fresh herbs', 'ice cream ice', {'weight': 2691.0}),
#  ('other creams cheeses', 'frozen meals', {'weight': 2690.0}),
#  ('packaged vegetables fruits', 'frozen meat seafood', {'weight': 2690.0}),
#  ('oils vinegars', 'baking ingredients', {'weight': 2676.0}),
#  ('crackers', 'canned meals beans', {'weight': 2664.0}),
#  ('soup broth bouillon', 'dry pasta', {'weight': 2661.0}),
#  ('packaged vegetables fruits', 'laundry', {'weight': 2657.0}),
#  ('juice nectars', 'energy granola bars', {'weight': 2651.0}),
#  ('refrigerated', 'breakfast bakery', {'weight': 2650.0}),
#  ('ice cream ice', 'spreads', {'weight': 2650.0}),
#  ('instant foods', 'cereal', {'weight': 2650.0}),
#  ('fresh vegetables', 'vitamins supplements', {'weight': 2647.0}),
#  ('milk', 'fruit vegetable snacks', {'weight': 2644.0}),
#  ('milk', 'tea', {'weight': 2639.0}),
#  ('packaged cheese', 'poultry counter', {'weight': 2638.0}),
#  ('dry pasta', 'cereal', {'weight': 2635.0}),
#  ('refrigerated', 'cookies cakes', {'weight': 2631.0}),
#  ('packaged vegetables fruits', 'dish detergents', {'weight': 2627.0}),
#  ('frozen breakfast', 'cereal', {'weight': 2620.0}),
#  ('refrigerated', 'cream', {'weight': 2616.0}),
#  ('soup broth bouillon', 'cereal', {'weight': 2608.0}),
#  ('chips pretzels', 'packaged produce', {'weight': 2608.0}),
#  ('frozen appetizers sides', 'bread', {'weight': 2607.0}),
#  ('crackers', 'fruit vegetable snacks', {'weight': 2606.0}),
#  ('soy lactosefree', 'breakfast bakery', {'weight': 2603.0}),
#  ('packaged cheese', 'specialty cheeses', {'weight': 2598.0}),
#  ('canned meals beans', 'eggs', {'weight': 2598.0}),
#  ('yogurt', 'pickled goods olives', {'weight': 2593.0}),
#  ('energy granola bars', 'soft drinks', {'weight': 2592.0}),
#  ('dry pasta', 'eggs', {'weight': 2591.0}),
#  ('spices seasonings', 'frozen produce', {'weight': 2589.0}),
#  ('frozen appetizers sides', 'frozen produce', {'weight': 2587.0}),
#  ('crackers', 'frozen appetizers sides', {'weight': 2583.0}),
#  ('condiments', 'frozen produce', {'weight': 2577.0}),
#  ('paper goods', 'cereal', {'weight': 2571.0}),
#  ('lunch meat', 'baby food formula', {'weight': 2570.0}),
#  ('hot dogs bacon sausage', 'cereal', {'weight': 2568.0}),
#  ('other creams cheeses', 'fresh herbs', {'weight': 2567.0}),
#  ('fresh vegetables', 'other', {'weight': 2566.0}),
#  ('spreads', 'eggs', {'weight': 2565.0}),
#  ('refrigerated', 'instant foods', {'weight': 2563.0}),
#  ('yogurt', 'frozen vegan vegetarian', {'weight': 2562.0}),
#  ('yogurt', 'energy sports drinks', {'weight': 2561.0}),
#  ('fresh vegetables', 'fresh pasta', {'weight': 2556.0}),
#  ('energy granola bars', 'tea', {'weight': 2553.0}),
#  ('lunch meat', 'instant foods', {'weight': 2544.0}),
#  ('lunch meat', 'soft drinks', {'weight': 2537.0}),
#  ('cream', 'frozen produce', {'weight': 2536.0}),
#  ('frozen breakfast', 'baby food formula', {'weight': 2536.0}),
#  ('soy lactosefree', 'paper goods', {'weight': 2531.0}),
#  ('butter', 'ice cream ice', {'weight': 2531.0}),
#  ('packaged cheese', 'frozen vegan vegetarian', {'weight': 2530.0}),
#  ('crackers', 'cream', {'weight': 2529.0}),
#  ('fresh fruits', 'frozen breads doughs', {'weight': 2528.0}),
#  ('fresh herbs', 'dry pasta', {'weight': 2528.0}),
#  ('other creams cheeses', 'cereal', {'weight': 2524.0}),
#  ('cereal', 'breakfast bakery', {'weight': 2524.0}),
#  ('refrigerated', 'baking ingredients', {'weight': 2519.0}),
#  ('ice cream ice', 'breakfast bakery', {'weight': 2518.0}),
#  ('packaged cheese', 'latino foods', {'weight': 2509.0}),
#  ('fresh vegetables', 'breakfast bars pastries', {'weight': 2508.0}),
#  ('milk', 'coffee', {'weight': 2508.0}),
#  ('nuts seeds dried fruit', 'candy chocolate', {'weight': 2506.0}),
#  ('spices seasonings', 'chips pretzels', {'weight': 2503.0}),
#  ('refrigerated', 'dry pasta', {'weight': 2496.0}),
#  ('missing', 'energy granola bars', {'weight': 2496.0}),
#  ('fresh fruits', 'fresh pasta', {'weight': 2494.0}),
#  ('water seltzer sparkling water', 'frozen pizza', {'weight': 2494.0}),
#  ('milk', 'missing', {'weight': 2493.0}),
#  ('lunch meat', 'frozen breakfast', {'weight': 2490.0}),
#  ('ice cream ice', 'frozen pizza', {'weight': 2478.0}),
#  ('yogurt', 'cleaning products', {'weight': 2477.0}),
#  ('soy lactosefree', 'butter', {'weight': 2477.0}),
#  ('frozen produce', 'packaged produce', {'weight': 2476.0}),
#  ('packaged cheese', 'canned fruit applesauce', {'weight': 2475.0}),
#  ('packaged vegetables fruits', 'energy sports drinks', {'weight': 2475.0}),
#  ('water seltzer sparkling water',
#   'frozen appetizers sides',
#   {'weight': 2473.0}),
#  ('soy lactosefree', 'tofu meat alternatives', {'weight': 2468.0}),
#  ('ice cream ice', 'nuts seeds dried fruit', {'weight': 2465.0}),
#  ('yogurt', 'prepared meals', {'weight': 2462.0}),
#  ('packaged vegetables fruits', 'prepared soups salads', {'weight': 2462.0}),
#  ('lunch meat', 'spreads', {'weight': 2461.0}),
#  ('crackers', 'baking ingredients', {'weight': 2459.0}),
#  ('fresh dips tapenades', 'canned meals beans', {'weight': 2458.0}),
#  ('cereal', 'nuts seeds dried fruit', {'weight': 2458.0}),
#  ('hot dogs bacon sausage', 'soup broth bouillon', {'weight': 2457.0}),
#  ('milk', 'spices seasonings', {'weight': 2457.0}),
#  ('paper goods', 'eggs', {'weight': 2457.0}),
#  ('other creams cheeses', 'canned jarred vegetables', {'weight': 2455.0}),
#  ('soy lactosefree', 'spices seasonings', {'weight': 2452.0}),
#  ('refrigerated', 'canned meals beans', {'weight': 2451.0}),
#  ('bread', 'frozen pizza', {'weight': 2451.0}),
#  ('refrigerated', 'canned jarred vegetables', {'weight': 2450.0}),
#  ('lunch meat', 'fresh herbs', {'weight': 2448.0}),
#  ('refrigerated', 'missing', {'weight': 2446.0}),
#  ('soup broth bouillon', 'juice nectars', {'weight': 2437.0}),
#  ('yogurt', 'breakfast bars pastries', {'weight': 2434.0}),
#  ('bread', 'candy chocolate', {'weight': 2429.0}),
#  ('other creams cheeses', 'soup broth bouillon', {'weight': 2428.0}),
#  ('spreads', 'frozen meals', {'weight': 2426.0}),
#  ('water seltzer sparkling water', 'spices seasonings', {'weight': 2425.0}),
#  ('packaged vegetables fruits',
#   'marinades meat preparation',
#   {'weight': 2421.0}),
#  ('yogurt', 'salad dressing toppings', {'weight': 2417.0}),
#  ('fresh dips tapenades', 'soup broth bouillon', {'weight': 2414.0}),
#  ('refrigerated', 'coffee', {'weight': 2413.0}),
#  ('lunch meat', 'cream', {'weight': 2408.0}),
#  ('ice cream ice', 'pasta sauce', {'weight': 2404.0}),
#  ('baking ingredients', 'nuts seeds dried fruit', {'weight': 2403.0}),
#  ('soup broth bouillon', 'energy granola bars', {'weight': 2402.0}),
#  ('chips pretzels', 'buns rolls', {'weight': 2402.0}),
#  ('soy lactosefree', 'soft drinks', {'weight': 2401.0}),
#  ('ice cream ice', 'baby food formula', {'weight': 2401.0}),
#  ('packaged vegetables fruits', 'soap', {'weight': 2392.0}),
#  ('lunch meat', 'breakfast bakery', {'weight': 2391.0}),
#  ('refrigerated', 'frozen appetizers sides', {'weight': 2388.0}),
#  ('other creams cheeses', 'baking ingredients', {'weight': 2386.0}),
#  ('energy granola bars', 'frozen breakfast', {'weight': 2382.0}),
#  ('baking ingredients', 'cream', {'weight': 2377.0}),
#  ('canned meals beans', 'ice cream ice', {'weight': 2371.0}),
#  ('water seltzer sparkling water', 'tortillas flat bread', {'weight': 2362.0}),
#  ('asian foods', 'chips pretzels', {'weight': 2360.0}),
#  ('refrigerated', 'pasta sauce', {'weight': 2358.0}),
#  ('eggs', 'nuts seeds dried fruit', {'weight': 2354.0}),
#  ('crackers', 'popcorn jerky', {'weight': 2353.0}),
#  ('missing', 'baby food formula', {'weight': 2351.0}),
#  ('pasta sauce', 'eggs', {'weight': 2351.0}),
#  ('breakfast bakery', 'eggs', {'weight': 2350.0}),
#  ('lunch meat', 'dry pasta', {'weight': 2344.0}),
#  ('fresh fruits', 'other', {'weight': 2331.0}),
#  ('cookies cakes', 'candy chocolate', {'weight': 2330.0}),
#  ('refrigerated', 'butter', {'weight': 2329.0}),
#  ('fresh herbs', 'nuts seeds dried fruit', {'weight': 2323.0}),
#  ('popcorn jerky', 'energy granola bars', {'weight': 2320.0}),
#  ('frozen produce', 'soft drinks', {'weight': 2320.0}),
#  ('baking ingredients', 'soup broth bouillon', {'weight': 2317.0}),
#  ('refrigerated', 'condiments', {'weight': 2316.0}),
#  ('fresh herbs', 'fresh dips tapenades', {'weight': 2315.0}),
#  ('frozen meals', 'candy chocolate', {'weight': 2314.0}),
#  ('canned jarred vegetables', 'ice cream ice', {'weight': 2310.0}),
#  ('canned jarred vegetables', 'baking ingredients', {'weight': 2310.0}),
#  ('soft drinks', 'eggs', {'weight': 2303.0}),
#  ('canned jarred vegetables', 'crackers', {'weight': 2302.0}),
#  ('crackers', 'pasta sauce', {'weight': 2291.0}),
#  ('lunch meat', 'condiments', {'weight': 2290.0}),
#  ('fresh herbs', 'crackers', {'weight': 2290.0}),
#  ('soy lactosefree', 'tortillas flat bread', {'weight': 2290.0}),
#  ('lunch meat', 'pasta sauce', {'weight': 2289.0}),
#  ('oils vinegars', 'bread', {'weight': 2283.0}),
#  ('soy lactosefree', 'instant foods', {'weight': 2283.0}),
#  ('soy lactosefree', 'asian foods', {'weight': 2281.0}),
#  ('fresh dips tapenades', 'juice nectars', {'weight': 2281.0}),
#  ('crackers', 'tortillas flat bread', {'weight': 2278.0}),
#  ('frozen meals', 'breakfast bakery', {'weight': 2278.0}),
#  ('milk', 'hot cereal pancake mixes', {'weight': 2276.0}),
#  ('soup broth bouillon', 'soft drinks', {'weight': 2276.0}),
#  ('pasta sauce', 'frozen meals', {'weight': 2276.0}),
#  ('oils vinegars', 'eggs', {'weight': 2275.0}),
#  ('yogurt', 'specialty cheeses', {'weight': 2272.0}),
#  ('missing', 'frozen produce', {'weight': 2269.0}),
#  ('canned meals beans', 'cereal', {'weight': 2267.0}),
#  ('baking ingredients', 'cereal', {'weight': 2264.0}),
#  ('instant foods', 'eggs', {'weight': 2264.0}),
#  ('soup broth bouillon', 'spices seasonings', {'weight': 2263.0}),
#  ('other creams cheeses', 'hot dogs bacon sausage', {'weight': 2259.0}),
#  ('bread', 'coffee', {'weight': 2259.0}),
#  ('oils vinegars', 'spices seasonings', {'weight': 2256.0}),
#  ('cream', 'energy granola bars', {'weight': 2256.0}),
#  ('other creams cheeses', 'cream', {'weight': 2254.0}),
#  ('other creams cheeses', 'fresh dips tapenades', {'weight': 2248.0}),
#  ('lunch meat', 'butter', {'weight': 2246.0}),
#  ('fresh dips tapenades', 'baby food formula', {'weight': 2245.0}),
#  ('ice cream ice', 'condiments', {'weight': 2244.0}),
#  ('fresh fruits', 'refrigerated pudding desserts', {'weight': 2238.0}),
#  ('frozen breakfast', 'eggs', {'weight': 2238.0}),
#  ('grains rice dried goods', 'frozen produce', {'weight': 2237.0}),
#  ('water seltzer sparkling water', 'energy sports drinks', {'weight': 2234.0}),
#  ('crackers', 'butter', {'weight': 2232.0}),
#  ('fresh dips tapenades', 'spreads', {'weight': 2232.0}),
#  ('instant foods', 'dry pasta', {'weight': 2231.0}),
#  ('fresh fruits', 'packaged meat', {'weight': 2229.0}),
#  ('fresh herbs', 'butter', {'weight': 2223.0}),
#  ('other creams cheeses', 'canned meals beans', {'weight': 2221.0}),
#  ('canned meals beans', 'dry pasta', {'weight': 2221.0}),
#  ('dry pasta', 'frozen meals', {'weight': 2212.0}),
#  ('lunch meat', 'canned jarred vegetables', {'weight': 2207.0}),
#  ('yogurt', 'latino foods', {'weight': 2201.0}),
#  ('hot cereal pancake mixes', 'chips pretzels', {'weight': 2196.0}),
#  ('paper goods', 'frozen produce', {'weight': 2195.0}),
#  ('hot dogs bacon sausage', 'frozen breakfast', {'weight': 2193.0}),
#  ('soy lactosefree', 'hot cereal pancake mixes', {'weight': 2189.0}),
#  ('fresh fruits', 'seafood counter', {'weight': 2187.0}),
#  ('lunch meat', 'frozen appetizers sides', {'weight': 2183.0}),
#  ('soy lactosefree', 'cookies cakes', {'weight': 2183.0}),
#  ('soy lactosefree', 'frozen appetizers sides', {'weight': 2181.0}),
#  ('crackers', 'frozen pizza', {'weight': 2180.0}),
#  ('energy granola bars', 'breakfast bakery', {'weight': 2173.0}),
#  ('tortillas flat bread', 'eggs', {'weight': 2171.0}),
#  ('yogurt', 'dish detergents', {'weight': 2170.0}),
#  ('hot dogs bacon sausage', 'instant foods', {'weight': 2170.0}),
#  ('canned meals beans', 'instant foods', {'weight': 2169.0}),
#  ('packaged vegetables fruits', 'honeys syrups nectars', {'weight': 2167.0}),
#  ('fresh fruits', 'cat food care', {'weight': 2161.0}),
#  ('hot dogs bacon sausage', 'energy granola bars', {'weight': 2161.0}),
#  ('crackers', 'condiments', {'weight': 2159.0}),
#  ('hot dogs bacon sausage', 'soft drinks', {'weight': 2159.0}),
#  ('soup broth bouillon', 'pasta sauce', {'weight': 2156.0}),
#  ('soy lactosefree', 'frozen vegan vegetarian', {'weight': 2154.0}),
#  ('bread', 'tea', {'weight': 2152.0}),
#  ('frozen appetizers sides', 'frozen breakfast', {'weight': 2151.0}),
#  ('hot dogs bacon sausage', 'juice nectars', {'weight': 2150.0}),
#  ('chips pretzels', 'doughs gelatins bake mixes', {'weight': 2148.0}),
#  ('fresh fruits', 'protein meal replacements', {'weight': 2147.0}),
#  ('soy lactosefree', 'coffee', {'weight': 2147.0}),
#  ('oils vinegars', 'canned jarred vegetables', {'weight': 2143.0}),
#  ('fresh vegetables', 'cat food care', {'weight': 2138.0}),
#  ('frozen produce', 'breakfast bakery', {'weight': 2135.0}),
#  ('other creams cheeses', 'soft drinks', {'weight': 2132.0}),
#  ('juice nectars', 'baby food formula', {'weight': 2132.0}),
#  ('fresh herbs', 'cream', {'weight': 2131.0}),
#  ('frozen appetizers sides', 'instant foods', {'weight': 2130.0}),
#  ('spreads', 'nuts seeds dried fruit', {'weight': 2125.0}),
#  ('fresh dips tapenades', 'nuts seeds dried fruit', {'weight': 2124.0}),
#  ('other creams cheeses', 'butter', {'weight': 2120.0}),
#  ('lunch meat', 'cookies cakes', {'weight': 2119.0}),
#  ('oils vinegars', 'refrigerated', {'weight': 2119.0}),
#  ('refrigerated', 'fruit vegetable snacks', {'weight': 2116.0}),
#  ('asian foods', 'frozen produce', {'weight': 2116.0}),
#  ('canned jarred vegetables', 'hot dogs bacon sausage', {'weight': 2109.0}),
#  ('condiments', 'eggs', {'weight': 2109.0}),
#  ('dry pasta', 'baby food formula', {'weight': 2109.0}),
#  ('canned jarred vegetables', 'pasta sauce', {'weight': 2108.0}),
#  ('laundry', 'paper goods', {'weight': 2103.0}),
#  ('fresh herbs', 'asian foods', {'weight': 2097.0}),
#  ('tortillas flat bread', 'frozen produce', {'weight': 2097.0}),
#  ('other creams cheeses', 'energy granola bars', {'weight': 2095.0}),
#  ('packaged cheese', 'cleaning products', {'weight': 2095.0}),
#  ('hot dogs bacon sausage', 'dry pasta', {'weight': 2093.0}),
#  ('yogurt', 'laundry', {'weight': 2092.0}),
#  ('cream', 'cereal', {'weight': 2089.0}),
#  ('other creams cheeses', 'dry pasta', {'weight': 2088.0}),
#  ('lunch meat', 'nuts seeds dried fruit', {'weight': 2082.0}),
#  ('baking ingredients', 'spreads', {'weight': 2081.0}),
#  ('lunch meat', 'canned meals beans', {'weight': 2080.0}),
#  ('soft drinks', 'instant foods', {'weight': 2077.0}),
#  ('chips pretzels', 'energy sports drinks', {'weight': 2071.0}),
#  ('water seltzer sparkling water', 'cleaning products', {'weight': 2067.0}),
#  ('frozen meals', 'frozen vegan vegetarian', {'weight': 2066.0}),
#  ('soup broth bouillon', 'paper goods', {'weight': 2063.0}),
#  ('soy lactosefree', 'grains rice dried goods', {'weight': 2061.0}),
#  ('canned meals beans', 'tortillas flat bread', {'weight': 2061.0}),
#  ('hot dogs bacon sausage', 'frozen appetizers sides', {'weight': 2057.0}),
#  ('frozen appetizers sides', 'baby food formula', {'weight': 2054.0}),
#  ('cereal', 'candy chocolate', {'weight': 2050.0}),
#  ('lunch meat', 'tortillas flat bread', {'weight': 2047.0}),
#  ('milk', 'popcorn jerky', {'weight': 2042.0}),
#  ('chips pretzels', 'salad dressing toppings', {'weight': 2042.0}),
#  ('fresh herbs', 'condiments', {'weight': 2040.0}),
#  ('ice cream ice', 'tea', {'weight': 2037.0}),
#  ('energy granola bars', 'instant foods', {'weight': 2036.0}),
#  ('instant foods', 'baby food formula', {'weight': 2036.0}),
#  ('canned jarred vegetables', 'fresh dips tapenades', {'weight': 2023.0}),
#  ('juice nectars', 'paper goods', {'weight': 2023.0}),
#  ('cream', 'frozen meals', {'weight': 2018.0}),
#  ('butter', 'cream', {'weight': 2017.0}),
#  ('frozen produce', 'candy chocolate', {'weight': 2016.0}),
#  ('soup broth bouillon', 'baby food formula', {'weight': 2014.0}),
#  ('pasta sauce', 'cereal', {'weight': 2008.0}),
#  ('cream', 'soft drinks', {'weight': 2003.0}),
#  ('crackers', 'tea', {'weight': 2002.0}),
#  ('frozen meals', 'nuts seeds dried fruit', {'weight': 2000.0}),
#  ('frozen produce', 'tofu meat alternatives', {'weight': 1999.0}),
#  ('canned meals beans', 'spices seasonings', {'weight': 1997.0}),
#  ('bread', 'packaged produce', {'weight': 1997.0}),
#  ('nuts seeds dried fruit', 'baby food formula', {'weight': 1996.0}),
#  ('hot dogs bacon sausage', 'fresh dips tapenades', {'weight': 1990.0}),
#  ('fruit vegetable snacks', 'baby food formula', {'weight': 1989.0}),
#  ('water seltzer sparkling water', 'asian foods', {'weight': 1988.0}),
#  ('juice nectars', 'cookies cakes', {'weight': 1986.0}),
#  ('refrigerated', 'frozen pizza', {'weight': 1982.0}),
#  ('canned meals beans', 'energy granola bars', {'weight': 1977.0}),
#  ('packaged cheese', 'prepared meals', {'weight': 1976.0}),
#  ('fresh dips tapenades', 'soft drinks', {'weight': 1974.0}),
#  ...]

# %%
import dill as pickle
pickle.dump(popular_pairings, open('pop_pair_smol.pkl', 'wb'))

# %%
import dill as pickle
popular_pairings = pickle.load(open('pop_pair_smol.pkl', 'rb'))

# %%
popular_pairings[:50]
# Out:
# [('fresh vegetables', 'fresh fruits', {'weight': 308105.0}),
#  ('fresh vegetables', 'packaged vegetables fruits', {'weight': 169766.0}),
#  ('fresh fruits', 'packaged vegetables fruits', {'weight': 158522.0}),
#  ('yogurt', 'fresh fruits', {'weight': 101020.0}),
#  ('yogurt', 'fresh vegetables', {'weight': 87211.0}),
#  ('fresh vegetables', 'packaged cheese', {'weight': 73818.0}),
#  ('fresh fruits', 'packaged cheese', {'weight': 69250.0}),
#  ('fresh vegetables', 'fresh herbs', {'weight': 53544.0}),
#  ('fresh fruits', 'milk', {'weight': 53092.0}),
#  ('yogurt', 'packaged vegetables fruits', {'weight': 50196.0}),
#  ('fresh vegetables', 'milk', {'weight': 46253.0}),
#  ('fresh fruits', 'water seltzer sparkling water', {'weight': 45582.0}),
#  ('fresh fruits', 'chips pretzels', {'weight': 45322.0}),
#  ('fresh vegetables', 'soy lactosefree', {'weight': 45295.0}),
#  ('fresh fruits', 'soy lactosefree', {'weight': 44034.0}),
#  ('fresh vegetables', 'frozen produce', {'weight': 43945.0}),
#  ('fresh fruits', 'frozen produce', {'weight': 40511.0}),
#  ('fresh vegetables', 'water seltzer sparkling water', {'weight': 40130.0}),
#  ('fresh vegetables', 'chips pretzels', {'weight': 39960.0}),
#  ('packaged cheese', 'packaged vegetables fruits', {'weight': 39294.0}),
#  ('fresh fruits', 'bread', {'weight': 38799.0}),
#  ('fresh vegetables', 'bread', {'weight': 37027.0}),
#  ('fresh vegetables', 'eggs', {'weight': 35955.0}),
#  ('fresh fruits', 'refrigerated', {'weight': 35660.0}),
#  ('fresh fruits', 'eggs', {'weight': 32481.0}),
#  ('fresh vegetables', 'canned jarred vegetables', {'weight': 32446.0}),
#  ('fresh fruits', 'fresh herbs', {'weight': 31861.0}),
#  ('fresh vegetables', 'refrigerated', {'weight': 31532.0}),
#  ('fresh fruits', 'crackers', {'weight': 30509.0}),
#  ('fresh vegetables', 'soup broth bouillon', {'weight': 29873.0}),
#  ('fresh fruits', 'ice cream ice', {'weight': 29788.0}),
#  ('fresh fruits', 'energy granola bars', {'weight': 29319.0}),
#  ('yogurt', 'packaged cheese', {'weight': 29156.0}),
#  ('fresh fruits', 'lunch meat', {'weight': 28733.0}),
#  ('fresh vegetables', 'canned meals beans', {'weight': 27839.0}),
#  ('fresh vegetables', 'ice cream ice', {'weight': 27579.0}),
#  ('fresh vegetables', 'lunch meat', {'weight': 27297.0}),
#  ('packaged vegetables fruits', 'milk', {'weight': 25999.0}),
#  ('fresh vegetables', 'crackers', {'weight': 25988.0}),
#  ('fresh vegetables', 'fresh dips tapenades', {'weight': 25731.0}),
#  ('fresh fruits', 'fresh dips tapenades', {'weight': 25621.0}),
#  ('fresh fruits', 'baby food formula', {'weight': 25306.0}),
#  ('fresh fruits', 'cereal', {'weight': 24233.0}),
#  ('packaged vegetables fruits', 'chips pretzels', {'weight': 24152.0}),
#  ('water seltzer sparkling water',
#   'packaged vegetables fruits',
#   {'weight': 23608.0}),
#  ('packaged vegetables fruits', 'frozen produce', {'weight': 23602.0}),
#  ('packaged vegetables fruits', 'soy lactosefree', {'weight': 23537.0}),
#  ('yogurt', 'milk', {'weight': 23360.0}),
#  ('fresh vegetables', 'dry pasta', {'weight': 22716.0}),
#  ('fresh vegetables', 'energy granola bars', {'weight': 22361.0})]

# %%
popular_pairings[-50:]
# Out:
# [('bulk grains rice dried goods', 'baby accessories', {'weight': 1.0}),
#  ('bulk grains rice dried goods', 'shave needs', {'weight': 1.0}),
#  ('bulk grains rice dried goods', 'baby bath body care', {'weight': 1.0}),
#  ('bulk grains rice dried goods', 'kitchen supplies', {'weight': 1.0}),
#  ('bulk grains rice dried goods', 'body lotions soap', {'weight': 1.0}),
#  ('bulk grains rice dried goods', 'red wines', {'weight': 1.0}),
#  ('tofu meat alternatives', 'specialty wines champagnes', {'weight': 1.0}),
#  ('shave needs', 'seafood counter', {'weight': 1.0}),
#  ('shave needs', 'bulk dried fruits vegetables', {'weight': 1.0}),
#  ('packaged seafood', 'muscles joints pain relief', {'weight': 1.0}),
#  ('packaged seafood', 'beauty', {'weight': 1.0}),
#  ('indian foods', 'specialty wines champagnes', {'weight': 1.0}),
#  ('indian foods', 'facial care', {'weight': 1.0}),
#  ('indian foods', 'spirits', {'weight': 1.0}),
#  ('indian foods', 'red wines', {'weight': 1.0}),
#  ('mint gum', 'kosher foods', {'weight': 1.0}),
#  ('mint gum', 'frozen juice', {'weight': 1.0}),
#  ('vitamins supplements', 'spirits', {'weight': 1.0}),
#  ('white wines', 'baby accessories', {'weight': 1.0}),
#  ('white wines', 'beauty', {'weight': 1.0}),
#  ('seafood counter', 'baby accessories', {'weight': 1.0}),
#  ('seafood counter', 'beers coolers', {'weight': 1.0}),
#  ('seafood counter', 'first aid', {'weight': 1.0}),
#  ('seafood counter', 'red wines', {'weight': 1.0}),
#  ('seafood counter', 'beauty', {'weight': 1.0}),
#  ('ice cream toppings', 'kitchen supplies', {'weight': 1.0}),
#  ('ice cream toppings', 'baby bath body care', {'weight': 1.0}),
#  ('specialty wines champagnes', 'muscles joints pain relief', {'weight': 1.0}),
#  ('specialty wines champagnes', 'trail mix snack mix', {'weight': 1.0}),
#  ('cold flu allergy', 'kitchen supplies', {'weight': 1.0}),
#  ('cold flu allergy', 'frozen juice', {'weight': 1.0}),
#  ('more household', 'baby bath body care', {'weight': 1.0}),
#  ('first aid', 'red wines', {'weight': 1.0}),
#  ('kitchen supplies', 'baby accessories', {'weight': 1.0}),
#  ('kitchen supplies', 'frozen juice', {'weight': 1.0}),
#  ('kitchen supplies', 'eye ear care', {'weight': 1.0}),
#  ('kitchen supplies', 'bulk dried fruits vegetables', {'weight': 1.0}),
#  ('frozen dessert', 'skin care', {'weight': 1.0}),
#  ('frozen dessert', 'baby bath body care', {'weight': 1.0}),
#  ('facial care', 'bulk dried fruits vegetables', {'weight': 1.0}),
#  ('bulk dried fruits vegetables', 'baby accessories', {'weight': 1.0}),
#  ('beers coolers', 'baby accessories', {'weight': 1.0}),
#  ('skin care', 'red wines', {'weight': 1.0}),
#  ('trail mix snack mix', 'red wines', {'weight': 1.0}),
#  ('kosher foods', 'muscles joints pain relief', {'weight': 1.0}),
#  ('kosher foods', 'frozen juice', {'weight': 1.0}),
#  ('kosher foods', 'eye ear care', {'weight': 1.0}),
#  ('bakery desserts', 'eye ear care', {'weight': 1.0}),
#  ('red wines', 'baby accessories', {'weight': 1.0}),
#  ('baby accessories', 'beauty', {'weight': 1.0})]

# %%
print("it worked out")

# %% [markdown]
# Maybe instead first do a big list first, then add edges from it
